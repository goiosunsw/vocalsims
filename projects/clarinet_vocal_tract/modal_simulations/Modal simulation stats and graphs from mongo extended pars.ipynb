# %%
# %pylab inline
from sshtunnel import SSHTunnelForwarder
import pymongo
import os
import stat
import json
import datetime
import paramiko
import pandas
import seaborn as sns

pkey=os.path.join(os.environ['HOME'],'.ssh/id_rsa')
key=paramiko.RSAKey.from_private_key_file(pkey)

MONGO_HOST = "129.94.162.112"
MONGO_USER = "goios"
MONGO_DB = "test2"
MONGO_COLLECTION = "ls-remote"
local_port = 26017

# define ssh tunnel
with SSHTunnelForwarder(
    MONGO_HOST,
    ssh_username=MONGO_USER,
    ssh_pkey=key,
    remote_bind_address=('localhost', 27017),
    local_bind_address=('localhost',local_port)
) as server:
    connection = pymongo.MongoClient('localhost', local_port)
    # close ssh tunnel
    connection.close()
    server.stop()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
MONGO_DB = "modal-2duct-simulations"
#MONGO_DB = "test2"
MONGO_COLLECTION = "modal-vt-bore-many-pars"
with SSHTunnelForwarder(    
    MONGO_HOST,
    ssh_username=MONGO_USER,
    ssh_pkey="~/.ssh/id_rsa",
    remote_bind_address=('localhost', 27017),
    local_bind_address=('localhost',local_port)
) as server:
    with pymongo.MongoClient('localhost', local_port) as connection:
        db = connection[MONGO_DB]
        collection = db[MONGO_COLLECTION]
        print (db)
        print(json.dumps(connection.list_database_names(),indent=2))
        print(json.dumps(db.list_collection_names(), indent=2))
# Out:
# Database(MongoClient(host=['localhost:26017'], document_class=dict, tz_aware=False, connect=True), 'modal-2duct-simulations')
# [
#   "admin",
#   "config",
#   "local",
#   "modal-2duct-simulations",
#   "test1",
#   "test2"
# ]
# [
#   "random-runs-var-gamma",
#   "random-runs-1",
#   "random-runs-var-gamma-pert-time",
#   "modal-vt-bore-many-pars",
#   "modal-vt-bore-var-gamma-nlstiff-bad-analysis",
#   "modal-tests",
#   "modal-vt-bore-jumps-2",
#   "modal-vt-bore-jumps",
#   "modal-vt-bore-var-gamma-nlstiff"
# ]

# %%
with SSHTunnelForwarder(    
    MONGO_HOST,
    ssh_username=MONGO_USER,
    ssh_pkey="~/.ssh/id_rsa",
    remote_bind_address=('localhost', 27017),
    local_bind_address=('localhost',local_port)
) as server:
    with pymongo.MongoClient('localhost', local_port) as connection:
        db = connection[MONGO_DB]
        collection = db[MONGO_COLLECTION]
        #collection.drop()
        print(collection.count())
        print(json.dumps(db.command("dbstats"),indent=2))
#         for d in collection.find():
#             err = "Ok"
#             try:
#                 d['simulation']['error']
#                 err='Error in simulation'
#             except KeyError:
#                 pass
#             try:
#                 d['analysis']['error']
#                 err='Error in analysis'
#             except KeyError:
#                 pass
                
#             print(d['_id'],d['simulation']['start'],d['simulation']['end'],err)
        #ll = list(collection.find({'analysis.b1_abs_fin': {'$exists':True}}))
        ll = list(collection.find({'simulation.params.gamma.sustain_val': {'$gt':.5, '$lt':.8},'simulation.params.zeta': {'$gt':.2, '$lt':.8}}))
        #ll = list(collection.aggregate([ {'$match':{'simulation.params.gamma.sustain_val': {'$gt':.6, '$lt':.7}}}, { "$sample": { "size": 1000 } } ]))
    print(len(ll))
# Out:
# 93893
# {
#   "db": "modal-2duct-simulations",
#   "collections": 9,
#   "views": 0,
#   "objects": 309578,
#   "avgObjSize": 5242.339319977517,
#   "dataSize": 1622912922.0,
#   "storageSize": 1006870528.0,
#   "numExtents": 0,
#   "indexes": 9,
#   "indexSize": 5816320.0,
#   "fsUsedSize": 27489218560.0,
#   "fsTotalSize": 44780494848.0,
#   "ok": 1.0
# }
# 21118

# %%
import six

def list_dict_items(obj):
    try:
        for k, v in obj.items():
            yield k, v
    except AttributeError:
        if not isinstance(obj, six.string_types):
            for k, v in enumerate(obj):
                yield k, v

def json_flatten(js,root=""):
    try:
        for k,v in list_dict_items(js):
            yield from json_flatten(v,root=root+"/"+str(k))
    except TypeError:
        yield root[1:], js

def json_array_flatten(js):
    for ii, el in enumerate(js):
        yield {k:v for k,v in json_flatten(el)}

# %%
{k:v for k,v in json_flatten({'a':1,'b':[0,2,{'a':-1,"b":"hello"}]})}
# Out:
# {'a': 1, 'b/0': 0, 'b/1': 2, 'b/2/a': -1}

# %%
dfo=pandas.DataFrame(json_array_flatten(ll))
df=dfo

# %%
df['gets larger than perturbation'] = df['analysis/b1_abs_fin'] > df['analysis/b1_abs_pert']

# %%
df['finishes close to max'] = df['analysis/b1_abs_fin'] > df['analysis/b1_abs_max']/2

# %%
df['trans dur']=df['analysis/t_trans_end']-df['analysis/t_trans_start']

# %%
df['starts after pert'] = df['analysis/t_trans_start'] - df['analysis/pert_time'] >-0.002
df['starts after pert'].value_counts()
# Out:
# False    18014
# True      3104
# Name: starts after pert, dtype: int64

# %%
df.pivot_table(index=['finishes close to max','gets larger than perturbation'],
               columns='starts after pert', values='analysis/f0', aggfunc='count')
# Out:
# starts after pert                                     False   True
# finishes close to max gets larger than perturbation
# False                 False                          1800.0    63.0
#                       True                             22.0     4.0
# True                  False                          6718.0     NaN
#                       True                           9326.0  3033.0

# %%
from scipy.optimize import fmin

from functools import partial

def resonance(x,f=100,q=10,a=1):
    omegar=2*pi*f
    s = 1j*x*2*pi
    #fs = (a*omegar*q)**0*s**0/(s**2+s*omegar/q+omegar**2)
    fs = omegar*s/(s**2+s*omegar/q+omegar**2)
    return(np.abs(fs))

def impedance(x, fvec, qvec, avec):
    ret = 0*x
    for f, q, a in zip(fvec,qvec,avec):
        ret += resonance(x, f, q, a)
    return ret

fsrch = lambda x: -impedance(x, fvec, qvec, avec)

dbps_to_alpha_fact = log(10)/20

def impedance_info(row):
    zbore = partial(resonance,f=row['simulation/params/bore/frequencies/0'],
                              q=row['simulation/params/bore/qs/0'],
                              a=row['simulation/params/bore/amplitudes/0'])
    zvt = partial(resonance,f=row['simulation/params/vocal/frequencies/0'],
                              q=row['simulation/params/vocal/qs/0'],
                              a=row['simulation/params/vocal/amplitudes/0'])
    ztotal = lambda x: zbore(x)+zvt(x)
    zrat = lambda x: zbore(x)/zvt(x)
    zbore_max_f = fmin(lambda x: -zbore(x),row['simulation/params/bore/frequencies/0'],disp=False)[0]
    zbore_max = zbore(row['analysis/f0'])
    zvt_max_f = fmin(lambda x: -zvt(x),row['simulation/params/bore/frequencies/0'],disp=False)[0]
    zvt_max = zvt(row['analysis/f0'])
    if zvt_max>zbore_max:
        zsum_max_f = zvt_max_f
        zsum_max = zvt_max
    else:
        zsum_max_f = zbore_max_f
        zsum_max = zbore_max
    zrat_f0 = zrat(row['analysis/f0'])
    zrat_f_sus = zbore(row['analysis/fb1_abs_sus'])/zvt(row['analysis/fvt1_abs_sus'])
    zrat_f_trans = zbore(row['analysis/fb1_abs_trans'])/zvt(row['analysis/fvt1_abs_trans'])
    srat_f_trans = (zbore(row['analysis/fb1_abs_trans']-1j*row['analysis/b1_rate']*dbps_to_alpha_fact)/
                    zvt(row['analysis/fvt1_abs_trans']-1j*row['analysis/vt1_rate']*dbps_to_alpha_fact))

    return pandas.Series({"zb_max_f":zbore_max_f,"zb_max_val":zbore_max,
                          "zvt_max_f":zvt_max_f,"zvt_max_val":zvt_max,
                          "zt_max_f":zsum_max_f,"zt_max_val":zsum_max,
                          "zrat_f0":zrat_f0,
                          "zrat_f_sus": zrat_f_sus, "zrat_f_trans": zrat_f_trans,
                          "srat_f_trans": srat_f_trans})

# %%
row = df.sample().iloc[0]
row['analysis/f0']
# Out:
# 801.4950011678188

# %%
impedance_info(row)
# Out:
# zb_max_f        695.566013
# zb_max_val        3.400545
# zvt_max_f       419.048248
# zvt_max_val       0.717616
# zt_max_f        695.566013
# zt_max_val        3.400545
# zrat_f0           4.738672
# zrat_f_sus        4.754427
# zrat_f_trans     11.658568
# srat_f_trans      2.304118
# dtype: float64

# %%
dfc=df.apply(impedance_info,axis=1)

# %%
df=pandas.concat((dfo,dfc),axis=1)

# %%
figure()
#sns.scatterplot(data=df,x='simulation/params/bore/frequencies/0',y=df['analysis/t_trans_end']-df['analysis/t_trans_start'],hue='starts after pert',alpha=.3)
sns.scatterplot(data=df.sample(2000),x='simulation/params/gamma/sustain_val',y='simulation/params/zeta',hue='gets larger than perturbation',alpha=.3)
legend(loc=' upper left',bbox_to_anchor=(1,1))

# %%
figure()
#sns.scatterplot(data=df,x='simulation/params/bore/frequencies/0',y=df['analysis/t_trans_end']-df['analysis/t_trans_start'],hue='starts after pert',alpha=.3)
sns.scatterplot(data=df.sample(4000),x='simulation/params/gamma/sustain_val',y='simulation/params/zeta',hue='starts after pert',alpha=.3)
legend(loc=' upper left',bbox_to_anchor=(1,1))

# %%
df1 = df[df['starts after pert'] & (df['trans dur']>0.005)]

# %%
import seaborn as sns
sns.scatterplot(data=df,x='simulation/params/bore/frequencies/0',y='analysis/f0',hue='simulation/params/reed/frequency')
figure()
sns.scatterplot(data=df,x='simulation/params/bore/frequencies/0',y='analysis/f0',hue='simulation/params/bore/qs/0',alpha=.1,palette='viridis')

# %%
figure()
sns.scatterplot(data=df1,x='analysis/hrat1_abs_trans',
                y='analysis/b1_rate',
                hue='simulation/params/bore/frequencies/0',
                alpha=.1,palette='viridis')
yscale('log')
ylim(1e2,1e4)
legend(loc='upper left',bbox_to_anchor=(1,1))

# %%
figure()
sns.scatterplot(data=df,x=-20*np.log10(df['zrat_f0']),y='analysis/hrat1_abs_fin',
                hue='analysis/b1_abs_fin',alpha=.1,palette='viridis')
grid()

# %%
figure()
sns.scatterplot(data=df1,y=-20*np.log10(df['srat_f_trans'])-df['analysis/hrat1_abs_trans'],
                x='simulation/params/bore/frequencies/0',
                hue='simulation/params/reed/frequency',
                size='simulation/params/vocal/frequencies/0',alpha=.5,palette='viridis')
legend(bbox_to_anchor=(1,1))
grid()

# %%
from sklearn.feature_selection import SelectKBest, mutual_info_regression

dep = -20*np.log10(df1['srat_f_trans'])-df1['analysis/hrat1_abs_trans']
idx = ~dep.isna()
df2 = df1.loc[idx,df1.columns.str.contains('params')]
pandas.Series(mutual_info_regression(df2[idx],dep[idx]),index=df2.columns)
# Out:
# simulation/params/tmax                          1.221245e-15
# simulation/params/gamma/sustain_val             5.701293e-02
# simulation/params/gamma/time_const              1.776357e-15
# simulation/params/gamma/exp_limit_multiplier    1.326260e-03
# simulation/params/zeta                          2.092655e-02
# simulation/params/reed/frequency                1.344391e-01
# simulation/params/reed/q                        0.000000e+00
# simulation/params/reed/amplitude                0.000000e+00
# simulation/params/bore/frequencies/0            1.956869e-01
# simulation/params/bore/qs/0                     5.448867e-02
# simulation/params/bore/amplitudes/0             5.448867e-02
# simulation/params/vocal/frequencies/0           1.800219e-01
# simulation/params/vocal/qs/0                    1.527897e-02
# simulation/params/vocal/amplitudes/0            1.527897e-02
# simulation/params/nlfunc/nl_start               1.221245e-15
# simulation/params/nlfunc/nl_ev                  6.631300e-04
# simulation/params/perturbation/multiplier       1.657825e-04
# simulation/params/perturbation/duration         2.943465e-02
# simulation/params/simulation/sample rate        1.340353e-01
# dtype: float64

# %%
figure()
sns.scatterplot(data=df1,x=-20*np.log10(df['zrat_f0']),y='analysis/hrat1_abs_trans',
                hue='simulation/params/gamma/sustain_val',alpha=.05,palette='viridis')

# %%
figure()
sns.scatterplot(data=df,x='analysis/hrat1_abs_fin',y='analysis/hrat1_abs_trans',hue='analysis/f0',alpha=.05,palette='viridis')

# %%
figure()
sns.scatterplot(data=df1,x=-20*np.log10(df['zrat_f0']),y='analysis/hrat1_abs_trans',hue='analysis/trans_f0_avg',alpha=.2,palette="viridis")

# %%
figure()
sns.scatterplot(data=df1,y='analysis/b1_jump',x='analysis/vt1_jump',
                hue='simulation/params/gamma/sustain_val',alpha=.1,palette='viridis')
legend(bbox_to_anchor=(1,1))
grid()

# %%
figure()
rat_imbalance =-20*np.log10(df['zrat_f0'])-df['analysis/hrat1_abs_fin']
sns.distplot(rat_imbalance.dropna(),bins=50)

# %%
figure()
sns.scatterplot(data=df1,hue='simulation/params/vocal/frequencies/0',y='analysis/f0',x='simulation/params/bore/frequencies/0',palette='viridis',alpha=.5)
legend(loc='upper left',bbox_to_anchor=(1,1))

# %%
figure()
sns.scatterplot(data=df1,y='analysis/f0',x='zt_max_f',hue='simulation/params/reed/frequency',palette='viridis',alpha=.5)
grid(True)
legend(loc='upper left',bbox_to_anchor=(1,1))

# %%
figure()
sns.scatterplot(data=df1,x='analysis/sus_f0_avg',y='analysis/trans_f0_avg',hue='simulation/params/reed/frequency',alpha=0.1,palette='viridis',vmax=0.1)
legend(bbox_to_anchor=(1,1),loc='upper left')
grid()

# %%
figure()
df2 = df1[df1['analysis/f0']<900]
sns.scatterplot(data=df2,x=10**(df1['analysis/hrat1_abs_trans']/20),
                y='analysis/b1_rate',
                hue='simulation/params/reed/frequency',
                alpha=.1,palette='viridis')
xscale('log')
xlim(1e-2,1e1)
ylim(1e2,1e4)
yscale('log')
legend(loc='upper left',bbox_to_anchor=(1,1))
grid()

# %%
figure()
sns.scatterplot(data=df1,x='analysis/hrat1_abs_trans',
                y=20*np.log10(df1['analysis/vt1_abs_trans']/df1['analysis/b1_abs_trans']),
                hue='simulation/params/bore/qs/0',
                alpha=.1,palette='viridis')

# %%
import seaborn as sns
figure()
sns.scatterplot(data=df1,x='simulation/params/bore/frequencies/0',y='trans dur',hue='simulation/params/gamma/sustain_val')

# %%
figure()
sns.scatterplot(data=df1,hue='simulation/params/bore/qs/0',y='trans dur',x='simulation/params/gamma/sustain_val')

# %%
figure()
sns.scatterplot(data=df1,x='simulation/params/bore/frequencies/0',y='trans dur',hue='analysis/b1_abs_fin')

# %%
figure()
sns.scatterplot(data=df1,y='analysis/vt1_abs_fin',x='analysis/b1_abs_fin',hue='simulation/params/bore/frequencies/0')

# %%
figure()
sns.scatterplot(data=df1,hue='analysis/t_trans_start',y='analysis/hrat1_abs_trans',x='simulation/params/bore/qs/0')

# %%
figure()
sns.distplot(df1['analysis/t_trans_start'],norm_hist=False)
sns.distplot(df1['analysis/pert_time'],norm_hist=False)

# %%
figure()
sns.scatterplot(data=df1,x='analysis/hrat1_abs_fin',y='analysis/hrat1_abs_trans',hue='simulation/params/gamma/sustain_val',alpha=.05,palette='viridis')

# %%
figure()
sns.scatterplot(data=df1,x='analysis/hrat1_abs_fin',y='analysis/hrat1_abs_trans',
                hue='simulation/params/bore/frequencies/0',palette='viridis',alpha=0.05)

# %%
figure()
sns.scatterplot(data=df1,x='analysis/hrat1_abs_fin',y='analysis/hrat1_abs_trans',
                hue='simulation/params/perturbation/duration',palette='viridis',alpha=0.05)

# %%
figure()
sns.scatterplot(data=df1,y='analysis/hrat1_abs_fin',hue='simulation/params/gamma/sustain_val',x='simulation/params/bore/frequencies/0',
                palette='viridis',alpha=0.05)

# %%
figure()
sns.scatterplot(data=df1,y='analysis/hrat1_abs_trans',hue='simulation/params/gamma/sustain_val',
                x='simulation/params/bore/frequencies/0',
                palette='viridis',alpha=0.05)

# %%
figure()
sns.scatterplot(data=df1,y='analysis/hrat1_abs_sus',hue='analysis/f0',
                x='simulation/params/bore/frequencies/0',
                palette='viridis',alpha=0.05)

# %%
figure()
sns.scatterplot(data=df1,y='analysis/fb1_abs_sus',hue='analysis/f0',
                x='analysis/fb1_abs_trans',
                palette='viridis',alpha=0.05)

# %%
{col:len(df[col].unique())for col in df.columns}
# Out:
# {'_id': 2110,
#  'simulation/start': 2110,
#  'simulation/params/tmax': 1,
#  'simulation/params/gamma/sustain_val': 2110,
#  'simulation/params/gamma/time_const': 1,
#  'simulation/params/gamma/exp_limit_multiplier': 1,
#  'simulation/params/zeta': 2110,
#  'simulation/params/reed/frequency': 2110,
#  'simulation/params/reed/q': 2110,
#  'simulation/params/reed/amplitude': 2110,
#  'simulation/params/bore/frequencies/0': 2110,
#  'simulation/params/bore/qs/0': 2110,
#  'simulation/params/bore/amplitudes/0': 2110,
#  'simulation/params/vocal/frequencies/0': 2110,
#  'simulation/params/vocal/qs/0': 2110,
#  'simulation/params/vocal/amplitudes/0': 2110,
#  'simulation/params/nlfunc/nl_start': 1,
#  'simulation/params/nlfunc/nl_ev': 1,
#  'simulation/params/perturbation/multiplier': 1,
#  'simulation/params/perturbation/duration': 2110,
#  'simulation/params/simulation/sample rate': 2110,
#  'simulation/end': 2110,
#  'analysis/pert_time': 2110,
#  'analysis/initial amplitude': 2110,
#  'analysis/final amplitude': 2110,
#  'analysis/f0': 2096,
#  'analysis/f_0': 2,
#  'analysis/b0_t_min': 2096,
#  'analysis/b0_t_max': 2096,
#  'analysis/b0_abs_min': 2096,
#  'analysis/b0_abs_max': 2096,
#  'analysis/b0_abs_fin': 2096,
#  'analysis/b0_abs_pert': 2096,
#  'analysis/f_n1': 837,
#  'analysis/bn1_t_min': 851,
#  'analysis/bn1_t_max': 851,
#  'analysis/bn1_abs_min': 851,
#  'analysis/bn1_abs_max': 851,
#  'analysis/bn1_abs_fin': 851,
#  'analysis/bn1_abs_pert': 851,
#  'analysis/f_1': 1925,
#  'analysis/b1_t_min': 1925,
#  'analysis/b1_t_max': 1925,
#  'analysis/b1_abs_min': 1925,
#  'analysis/b1_abs_max': 1925,
#  'analysis/b1_abs_fin': 1925,
#  'analysis/b1_abs_pert': 1925,
#  'analysis/f_n2': 712,
#  'analysis/bn2_t_min': 712,
#  'analysis/bn2_t_max': 712,
#  'analysis/bn2_abs_min': 712,
#  'analysis/bn2_abs_max': 712,
#  'analysis/bn2_abs_fin': 712,
#  'analysis/bn2_abs_pert': 712,
#  'analysis/f_2': 1806,
#  'analysis/b2_t_min': 1806,
#  'analysis/b2_t_max': 1806,
#  'analysis/b2_abs_min': 1806,
#  'analysis/b2_abs_max': 1806,
#  'analysis/b2_abs_fin': 1806,
#  'analysis/b2_abs_pert': 1806,
#  'analysis/f_n3': 579,
#  'analysis/bn3_t_min': 579,
#  'analysis/bn3_t_max': 579,
#  'analysis/bn3_abs_min': 579,
#  'analysis/bn3_abs_max': 579,
#  'analysis/bn3_abs_fin': 579,
#  'analysis/bn3_abs_pert': 579,
#  'analysis/f_3': 1541,
#  'analysis/b3_t_min': 1541,
#  'analysis/b3_t_max': 1541,
#  'analysis/b3_abs_min': 1541,
#  'analysis/b3_abs_max': 1541,
#  'analysis/b3_abs_fin': 1541,
#  'analysis/b3_abs_pert': 1541,
#  'analysis/f_n4': 370,
#  'analysis/bn4_t_min': 370,
#  'analysis/bn4_t_max': 370,
#  'analysis/bn4_abs_min': 370,
#  'analysis/bn4_abs_max': 370,
#  'analysis/bn4_abs_fin': 370,
#  'analysis/bn4_abs_pert': 370,
#  'analysis/vt0_t_min': 2096,
#  'analysis/vt0_t_max': 2096,
#  'analysis/vt0_abs_min': 2096,
#  'analysis/vt0_abs_max': 2096,
#  'analysis/vt0_abs_fin': 2096,
#  'analysis/vt0_abs_pert': 2096,
#  'analysis/vtn1_t_min': 851,
#  'analysis/vtn1_t_max': 851,
#  'analysis/vtn1_abs_min': 851,
#  'analysis/vtn1_abs_max': 851,
#  'analysis/vtn1_abs_fin': 851,
#  'analysis/vtn1_abs_pert': 851,
#  'analysis/vt1_t_min': 1925,
#  'analysis/vt1_t_max': 1925,
#  'analysis/vt1_abs_min': 1925,
#  'analysis/vt1_abs_max': 1925,
#  'analysis/vt1_abs_fin': 1925,
#  'analysis/vt1_abs_pert': 1925,
#  'analysis/vtn2_t_min': 712,
#  'analysis/vtn2_t_max': 712,
#  'analysis/vtn2_abs_min': 712,
#  'analysis/vtn2_abs_max': 712,
#  'analysis/vtn2_abs_fin': 712,
#  'analysis/vtn2_abs_pert': 712,
#  'analysis/vt2_t_min': 1806,
#  'analysis/vt2_t_max': 1806,
#  'analysis/vt2_abs_min': 1806,
#  'analysis/vt2_abs_max': 1806,
#  'analysis/vt2_abs_fin': 1806,
#  'analysis/vt2_abs_pert': 1806,
#  'analysis/vtn3_t_min': 579,
#  'analysis/vtn3_t_max': 579,
#  'analysis/vtn3_abs_min': 579,
#  'analysis/vtn3_abs_max': 579,
#  'analysis/vtn3_abs_fin': 579,
#  'analysis/vtn3_abs_pert': 579,
#  'analysis/vt3_t_min': 1541,
#  'analysis/vt3_t_max': 1541,
#  'analysis/vt3_abs_min': 1541,
#  'analysis/vt3_abs_max': 1541,
#  'analysis/vt3_abs_fin': 1541,
#  'analysis/vt3_abs_pert': 1541,
#  'analysis/vtn4_t_min': 370,
#  'analysis/vtn4_t_max': 370,
#  'analysis/vtn4_abs_min': 370,
#  'analysis/vtn4_abs_max': 370,
#  'analysis/vtn4_abs_fin': 370,
#  'analysis/vtn4_abs_pert': 370,
#  'analysis/t_trans_start': 2110,
#  'analysis/t_trans_end': 2110,
#  'analysis/sus_f0_avg': 2084,
#  'analysis/sus_f0_std': 2084,
#  'analysis/trans_f0_avg': 2083,
#  'analysis/trans_f0_std': 2080,
#  'analysis/b0_abs_sus': 2096,
#  'analysis/b0_abs_sus_var': 2096,
#  'analysis/b0_abs_trans': 2096,
#  'analysis/b0_abs_trans_var': 2096,
#  'analysis/bn1_abs_sus': 851,
#  'analysis/bn1_abs_sus_var': 851,
#  'analysis/bn1_abs_trans': 851,
#  'analysis/bn1_abs_trans_var': 851,
#  'analysis/b1_abs_sus': 1925,
#  'analysis/b1_abs_sus_var': 1925,
#  'analysis/b1_abs_trans': 1925,
#  'analysis/b1_abs_trans_var': 1925,
#  'analysis/bn2_abs_sus': 712,
#  'analysis/bn2_abs_sus_var': 712,
#  'analysis/bn2_abs_trans': 712,
#  'analysis/bn2_abs_trans_var': 712,
#  'analysis/b2_abs_sus': 1806,
#  'analysis/b2_abs_sus_var': 1806,
#  'analysis/b2_abs_trans': 1806,
#  'analysis/b2_abs_trans_var': 1806,
#  'analysis/bn3_abs_sus': 579,
#  'analysis/bn3_abs_sus_var': 579,
#  'analysis/bn3_abs_trans': 579,
#  'analysis/bn3_abs_trans_var': 579,
#  'analysis/b3_abs_sus': 1541,
#  'analysis/b3_abs_sus_var': 1541,
#  'analysis/b3_abs_trans': 1541,
#  'analysis/b3_abs_trans_var': 1541,
#  'analysis/bn4_abs_sus': 370,
#  'analysis/bn4_abs_sus_var': 370,
#  'analysis/bn4_abs_trans': 370,
#  'analysis/bn4_abs_trans_var': 370,
#  'analysis/bn4_trans_rate_pct25': 110,
#  'analysis/bn4_trans_rate_pct50': 110,
#  'analysis/bn4_trans_rate_pct75': 110,
#  'analysis/vt0_abs_sus': 2096,
#  'analysis/vt0_abs_sus_var': 2096,
#  'analysis/vt0_abs_trans': 2096,
#  'analysis/vt0_abs_trans_var': 2096,
#  'analysis/vtn1_abs_sus': 851,
#  'analysis/vtn1_abs_sus_var': 851,
#  'analysis/vtn1_abs_trans': 851,
#  'analysis/vtn1_abs_trans_var': 851,
#  'analysis/vt1_abs_sus': 1925,
#  'analysis/vt1_abs_sus_var': 1925,
#  'analysis/vt1_abs_trans': 1925,
#  'analysis/vt1_abs_trans_var': 1925,
#  'analysis/vtn2_abs_sus': 712,
#  'analysis/vtn2_abs_sus_var': 712,
#  'analysis/vtn2_abs_trans': 712,
#  'analysis/vtn2_abs_trans_var': 712,
#  'analysis/vt2_abs_sus': 1806,
#  'analysis/vt2_abs_sus_var': 1806,
#  'analysis/vt2_abs_trans': 1806,
#  'analysis/vt2_abs_trans_var': 1806,
#  'analysis/vtn3_abs_sus': 579,
#  'analysis/vtn3_abs_sus_var': 579,
#  'analysis/vtn3_abs_trans': 579,
#  'analysis/vtn3_abs_trans_var': 579,
#  'analysis/vt3_abs_sus': 1541,
#  'analysis/vt3_abs_sus_var': 1541,
#  'analysis/vt3_abs_trans': 1541,
#  'analysis/vt3_abs_trans_var': 1541,
#  'analysis/vtn4_abs_sus': 370,
#  'analysis/vtn4_abs_sus_var': 370,
#  'analysis/vtn4_abs_trans': 370,
#  'analysis/vtn4_abs_trans_var': 370,
#  'analysis/vtn4_trans_rate_pct25': 110,
#  'analysis/vtn4_trans_rate_pct50': 110,
#  'analysis/vtn4_trans_rate_pct75': 110,
#  'analysis/fb0_abs_sus': 2,
#  'analysis/fb0_abs_sus_var': 9,
#  'analysis/fb0_abs_trans': 3,
#  'analysis/fb0_abs_trans_var': 2,
#  'analysis/fbn1_abs_sus': 837,
#  'analysis/fbn1_abs_sus_var': 837,
#  'analysis/fbn1_abs_trans': 837,
#  'analysis/fbn1_abs_trans_var': 834,
#  'analysis/fb1_abs_sus': 1925,
#  'analysis/fb1_abs_sus_var': 1925,
#  'analysis/fb1_abs_trans': 1925,
#  'analysis/fb1_abs_trans_var': 1923,
#  'analysis/fbn2_abs_sus': 712,
#  'analysis/fbn2_abs_sus_var': 712,
#  'analysis/fbn2_abs_trans': 712,
#  'analysis/fbn2_abs_trans_var': 696,
#  'analysis/fb2_abs_sus': 1806,
#  'analysis/fb2_abs_sus_var': 1806,
#  'analysis/fb2_abs_trans': 1806,
#  'analysis/fb2_abs_trans_var': 1806,
#  'analysis/fbn3_abs_sus': 579,
#  'analysis/fbn3_abs_sus_var': 579,
#  'analysis/fbn3_abs_trans': 579,
#  'analysis/fbn3_abs_trans_var': 575,
#  'analysis/fb3_abs_sus': 1541,
#  'analysis/fb3_abs_sus_var': 1541,
#  'analysis/fb3_abs_trans': 1541,
#  'analysis/fb3_abs_trans_var': 1540,
#  'analysis/fbn4_abs_sus': 370,
#  'analysis/fbn4_abs_sus_var': 370,
#  'analysis/fbn4_abs_trans': 370,
#  'analysis/fbn4_abs_trans_var': 369,
#  'analysis/fvt0_abs_sus': 2,
#  'analysis/fvt0_abs_sus_var': 2,
#  'analysis/fvt0_abs_trans': 2,
#  'analysis/fvt0_abs_trans_var': 2,
#  'analysis/fvtn1_abs_sus': 837,
#  'analysis/fvtn1_abs_sus_var': 837,
#  'analysis/fvtn1_abs_trans': 837,
#  'analysis/fvtn1_abs_trans_var': 834,
#  'analysis/fvt1_abs_sus': 1925,
#  'analysis/fvt1_abs_sus_var': 1925,
#  'analysis/fvt1_abs_trans': 1925,
#  'analysis/fvt1_abs_trans_var': 1923,
#  'analysis/fvtn2_abs_sus': 712,
#  'analysis/fvtn2_abs_sus_var': 712,
#  'analysis/fvtn2_abs_trans': 712,
#  'analysis/fvtn2_abs_trans_var': 696,
#  'analysis/fvt2_abs_sus': 1806,
#  'analysis/fvt2_abs_sus_var': 1806,
#  'analysis/fvt2_abs_trans': 1806,
#  'analysis/fvt2_abs_trans_var': 1806,
#  'analysis/fvtn3_abs_sus': 579,
#  'analysis/fvtn3_abs_sus_var': 579,
#  'analysis/fvtn3_abs_trans': 579,
#  'analysis/fvtn3_abs_trans_var': 575,
#  'analysis/fvt3_abs_sus': 1541,
#  'analysis/fvt3_abs_sus_var': 1541,
#  'analysis/fvt3_abs_trans': 1541,
#  'analysis/fvt3_abs_trans_var': 1540,
#  'analysis/fvtn4_abs_sus': 370,
#  'analysis/fvtn4_abs_sus_var': 370,
#  'analysis/fvtn4_abs_trans': 370,
#  'analysis/fvtn4_abs_trans_var': 369,
#  'analysis/hrat0_abs_sus': 2096,
#  'analysis/hrat0_abs_sus_var': 2096,
#  'analysis/hrat0_abs_trans': 2096,
#  'analysis/hrat0_abs_trans_var': 2093,
#  'analysis/hrat0_abs_fin': 2096,
#  'analysis/arat0_arg_sus': 2,
#  'analysis/arat0_arg_sus_var': 4,
#  'analysis/arat0_arg_trans': 2,
#  'analysis/arat0_arg_trans_var': 4,
#  'analysis/arat0_arg_trans_trend': 2096,
#  'analysis/hrat0_arg_fin': 3,
#  'analysis/hrat0_abs_pert': 2096,
#  'analysis/hratn1_abs_sus': 851,
#  'analysis/hratn1_abs_sus_var': 851,
#  'analysis/hratn1_abs_trans': 851,
#  'analysis/hratn1_abs_trans_var': 834,
#  'analysis/hratn1_abs_fin': 851,
#  'analysis/aratn1_arg_sus': 837,
#  'analysis/aratn1_arg_sus_var': 837,
#  'analysis/aratn1_arg_trans': 837,
#  'analysis/aratn1_arg_trans_var': 834,
#  'analysis/aratn1_arg_trans_trend': 851,
#  'analysis/hratn1_arg_fin': 837,
#  'analysis/hratn1_abs_pert': 851,
#  'analysis/hrat1_abs_sus': 1925,
#  'analysis/hrat1_abs_sus_var': 1925,
#  'analysis/hrat1_abs_trans': 1925,
#  'analysis/hrat1_abs_trans_var': 1923,
#  'analysis/hrat1_abs_fin': 1925,
#  'analysis/arat1_arg_sus': 1925,
#  'analysis/arat1_arg_sus_var': 1925,
#  'analysis/arat1_arg_trans': 1925,
#  'analysis/arat1_arg_trans_var': 1923,
#  'analysis/arat1_arg_trans_trend': 1925,
#  'analysis/hrat1_arg_fin': 1925,
#  'analysis/hrat1_abs_pert': 1925,
#  'analysis/hratn2_abs_sus': 712,
#  'analysis/hratn2_abs_sus_var': 712,
#  'analysis/hratn2_abs_trans': 712,
#  'analysis/hratn2_abs_trans_var': 696,
#  'analysis/hratn2_abs_fin': 712,
#  'analysis/aratn2_arg_sus': 712,
#  'analysis/aratn2_arg_sus_var': 712,
#  'analysis/aratn2_arg_trans': 712,
#  'analysis/aratn2_arg_trans_var': 696,
#  'analysis/aratn2_arg_trans_trend': 712,
#  'analysis/hratn2_arg_fin': 712,
#  'analysis/hratn2_abs_pert': 712,
#  'analysis/hrat2_abs_sus': 1806,
#  'analysis/hrat2_abs_sus_var': 1806,
#  'analysis/hrat2_abs_trans': 1806,
#  'analysis/hrat2_abs_trans_var': 1806,
#  'analysis/hrat2_abs_fin': 1806,
#  'analysis/arat2_arg_sus': 1806,
#  'analysis/arat2_arg_sus_var': 1806,
#  'analysis/arat2_arg_trans': 1806,
#  'analysis/arat2_arg_trans_var': 1806,
#  'analysis/arat2_arg_trans_trend': 1806,
#  'analysis/hrat2_arg_fin': 1806,
#  'analysis/hrat2_abs_pert': 1806,
#  'analysis/hratn3_abs_sus': 579,
#  'analysis/hratn3_abs_sus_var': 579,
#  'analysis/hratn3_abs_trans': 579,
#  'analysis/hratn3_abs_trans_var': 575,
#  'analysis/hratn3_abs_fin': 579,
#  'analysis/aratn3_arg_sus': 579,
#  'analysis/aratn3_arg_sus_var': 579,
#  'analysis/aratn3_arg_trans': 579,
#  'analysis/aratn3_arg_trans_var': 575,
#  'analysis/aratn3_arg_trans_trend': 579,
#  'analysis/hratn3_arg_fin': 579,
#  'analysis/hratn3_abs_pert': 579,
#  'analysis/hrat3_abs_sus': 1541,
#  'analysis/hrat3_abs_sus_var': 1541,
#  'analysis/hrat3_abs_trans': 1541,
#  'analysis/hrat3_abs_trans_var': 1540,
#  'analysis/hrat3_abs_fin': 1541,
#  'analysis/arat3_arg_sus': 1541,
#  'analysis/arat3_arg_sus_var': 1541,
#  'analysis/arat3_arg_trans': 1541,
#  'analysis/arat3_arg_trans_var': 1540,
#  'analysis/arat3_arg_trans_trend': 1541,
#  'analysis/hrat3_arg_fin': 1541,
#  'analysis/hrat3_abs_pert': 1541,
#  'analysis/hratn4_abs_sus': 370,
#  'analysis/hratn4_abs_sus_var': 370,
#  'analysis/hratn4_abs_trans': 370,
#  'analysis/hratn4_abs_trans_var': 369,
#  'analysis/hratn4_abs_fin': 370,
#  'analysis/aratn4_arg_sus': 370,
#  'analysis/aratn4_arg_sus_var': 370,
#  'analysis/aratn4_arg_trans': 370,
#  'analysis/aratn4_arg_trans_var': 369,
#  'analysis/aratn4_arg_trans_trend': 370,
#  'analysis/hratn4_arg_fin': 370,
#  'analysis/hratn4_abs_pert': 370,
#  'analysis/bn1_rate': 836,
#  'analysis/bn1_jump': 822,
#  'analysis/bn1_t_before_jump': 822,
#  'analysis/b1_rate': 1925,
#  'analysis/b1_jump': 1827,
#  'analysis/b1_t_before_jump': 1827,
#  'analysis/bn2_rate': 711,
#  'analysis/bn2_jump': 701,
#  'analysis/bn2_t_before_jump': 701,
#  'analysis/b2_rate': 1806,
#  'analysis/b2_jump': 1729,
#  'analysis/b2_t_before_jump': 1729,
#  'analysis/bn3_rate': 579,
#  'analysis/bn3_jump': 573,
#  'analysis/bn3_t_before_jump': 573,
#  'analysis/b3_rate': 1541,
#  'analysis/b3_jump': 1475,
#  'analysis/b3_t_before_jump': 1475,
#  'analysis/bn4_rate': 370,
#  'analysis/bn4_jump': 366,
#  'analysis/bn4_t_before_jump': 366,
#  'analysis/vtn1_rate': 838,
#  'analysis/vtn1_jump': 820,
#  'analysis/vtn1_t_before_jump': 820,
#  'analysis/vt1_rate': 1925,
#  'analysis/vt1_jump': 1821,
#  'analysis/vt1_t_before_jump': 1821,
#  'analysis/vtn2_rate': 712,
#  'analysis/vtn2_jump': 703,
#  'analysis/vtn2_t_before_jump': 703,
#  'analysis/vt2_rate': 1806,
#  'analysis/vt2_jump': 1728,
#  'analysis/vt2_t_before_jump': 1728,
#  'analysis/vtn3_rate': 579,
#  'analysis/vtn3_jump': 573,
#  'analysis/vtn3_t_before_jump': 573,
#  'analysis/vt3_rate': 1541,
#  'analysis/vt3_jump': 1475,
#  'analysis/vt3_t_before_jump': 1475,
#  'analysis/vtn4_rate': 370,
#  'analysis/vtn4_jump': 366,
#  'analysis/vtn4_t_before_jump': 366,
#  'analysis/f_n5': 235,
#  'analysis/bn5_t_min': 235,
#  'analysis/bn5_t_max': 235,
#  'analysis/bn5_abs_min': 235,
#  'analysis/bn5_abs_max': 235,
#  'analysis/bn5_abs_fin': 235,
#  'analysis/bn5_abs_pert': 235,
#  'analysis/f_n6': 185,
#  'analysis/bn6_t_min': 185,
#  'analysis/bn6_t_max': 185,
#  'analysis/bn6_abs_min': 185,
#  'analysis/bn6_abs_max': 185,
#  'analysis/bn6_abs_fin': 185,
#  'analysis/bn6_abs_pert': 185,
#  'analysis/f_n7': 119,
#  'analysis/bn7_t_min': 119,
#  'analysis/bn7_t_max': 119,
#  'analysis/bn7_abs_min': 119,
#  'analysis/bn7_abs_max': 119,
#  'analysis/bn7_abs_fin': 119,
#  'analysis/bn7_abs_pert': 119,
#  'analysis/vtn5_t_min': 235,
#  'analysis/vtn5_t_max': 235,
#  'analysis/vtn5_abs_min': 235,
#  'analysis/vtn5_abs_max': 235,
#  'analysis/vtn5_abs_fin': 235,
#  'analysis/vtn5_abs_pert': 235,
#  'analysis/vtn6_t_min': 185,
#  'analysis/vtn6_t_max': 185,
#  'analysis/vtn6_abs_min': 185,
#  'analysis/vtn6_abs_max': 185,
#  'analysis/vtn6_abs_fin': 185,
#  'analysis/vtn6_abs_pert': 185,
#  'analysis/vtn7_t_min': 119,
#  'analysis/vtn7_t_max': 119,
#  'analysis/vtn7_abs_min': 119,
#  'analysis/vtn7_abs_max': 119,
#  'analysis/vtn7_abs_fin': 119,
#  'analysis/vtn7_abs_pert': 119,
#  'analysis/bn5_abs_sus': 235,
#  'analysis/bn5_abs_sus_var': 235,
#  'analysis/bn5_abs_trans': 235,
#  'analysis/bn5_abs_trans_var': 235,
#  'analysis/bn6_abs_sus': 185,
#  'analysis/bn6_abs_sus_var': 185,
#  'analysis/bn6_abs_trans': 185,
#  'analysis/bn6_abs_trans_var': 185,
#  'analysis/bn7_abs_sus': 119,
#  'analysis/bn7_abs_sus_var': 119,
#  'analysis/bn7_abs_trans': 119,
#  'analysis/bn7_abs_trans_var': 119,
#  'analysis/bn7_trans_rate_pct25': 37,
#  'analysis/bn7_trans_rate_pct50': 37,
#  'analysis/bn7_trans_rate_pct75': 37,
#  'analysis/vtn5_abs_sus': 235,
#  'analysis/vtn5_abs_sus_var': 235,
#  'analysis/vtn5_abs_trans': 235,
#  'analysis/vtn5_abs_trans_var': 235,
#  'analysis/vtn6_abs_sus': 185,
#  'analysis/vtn6_abs_sus_var': 185,
#  'analysis/vtn6_abs_trans': 185,
#  'analysis/vtn6_abs_trans_var': 185,
#  'analysis/vtn7_abs_sus': 119,
#  'analysis/vtn7_abs_sus_var': 119,
#  'analysis/vtn7_abs_trans': 119,
#  'analysis/vtn7_abs_trans_var': 119,
#  'analysis/vtn7_trans_rate_pct25': 37,
#  'analysis/vtn7_trans_rate_pct50': 37,
#  'analysis/vtn7_trans_rate_pct75': 37,
#  'analysis/fbn5_abs_sus': 235,
#  'analysis/fbn5_abs_sus_var': 235,
#  'analysis/fbn5_abs_trans': 235,
#  'analysis/fbn5_abs_trans_var': 235,
#  'analysis/fbn6_abs_sus': 185,
#  'analysis/fbn6_abs_sus_var': 185,
#  'analysis/fbn6_abs_trans': 185,
#  'analysis/fbn6_abs_trans_var': 185,
#  'analysis/fbn7_abs_sus': 119,
#  'analysis/fbn7_abs_sus_var': 119,
#  'analysis/fbn7_abs_trans': 119,
#  'analysis/fbn7_abs_trans_var': 119,
#  'analysis/fvtn5_abs_sus': 235,
#  'analysis/fvtn5_abs_sus_var': 235,
#  'analysis/fvtn5_abs_trans': 235,
#  'analysis/fvtn5_abs_trans_var': 235,
#  'analysis/fvtn6_abs_sus': 185,
#  'analysis/fvtn6_abs_sus_var': 185,
#  'analysis/fvtn6_abs_trans': 185,
#  'analysis/fvtn6_abs_trans_var': 185,
#  'analysis/fvtn7_abs_sus': 119,
#  'analysis/fvtn7_abs_sus_var': 119,
#  'analysis/fvtn7_abs_trans': 119,
#  'analysis/fvtn7_abs_trans_var': 119,
#  'analysis/hratn5_abs_sus': 235,
#  'analysis/hratn5_abs_sus_var': 235,
#  'analysis/hratn5_abs_trans': 235,
#  'analysis/hratn5_abs_trans_var': 235,
#  'analysis/hratn5_abs_fin': 235,
#  'analysis/aratn5_arg_sus': 235,
#  'analysis/aratn5_arg_sus_var': 235,
#  'analysis/aratn5_arg_trans': 235,
#  'analysis/aratn5_arg_trans_var': 235,
#  'analysis/aratn5_arg_trans_trend': 235,
#  'analysis/hratn5_arg_fin': 235,
#  'analysis/hratn5_abs_pert': 235,
#  'analysis/hratn6_abs_sus': 185,
#  'analysis/hratn6_abs_sus_var': 185,
#  'analysis/hratn6_abs_trans': 185,
#  'analysis/hratn6_abs_trans_var': 185,
#  'analysis/hratn6_abs_fin': 185,
#  'analysis/aratn6_arg_sus': 185,
#  'analysis/aratn6_arg_sus_var': 185,
#  'analysis/aratn6_arg_trans': 185,
#  'analysis/aratn6_arg_trans_var': 185,
#  'analysis/aratn6_arg_trans_trend': 185,
#  'analysis/hratn6_arg_fin': 185,
#  'analysis/hratn6_abs_pert': 185,
#  'analysis/hratn7_abs_sus': 119,
#  'analysis/hratn7_abs_sus_var': 119,
#  'analysis/hratn7_abs_trans': 119,
#  'analysis/hratn7_abs_trans_var': 119,
#  'analysis/hratn7_abs_fin': 119,
#  'analysis/aratn7_arg_sus': 119,
#  'analysis/aratn7_arg_sus_var': 119,
#  'analysis/aratn7_arg_trans': 119,
#  'analysis/aratn7_arg_trans_var': 119,
#  'analysis/aratn7_arg_trans_trend': 119,
#  'analysis/hratn7_arg_fin': 119,
#  'analysis/hratn7_abs_pert': 119,
#  'analysis/b0_rate': 777,
#  'analysis/b0_jump': 428,
#  'analysis/b0_t_before_jump': 730,
#  'analysis/bn5_rate': 235,
#  'analysis/bn5_jump': 230,
#  'analysis/bn5_t_before_jump': 230,
#  'analysis/bn6_rate': 185,
#  'analysis/bn6_jump': 182,
#  'analysis/bn6_t_before_jump': 182,
#  'analysis/bn7_rate': 119,
#  'analysis/bn7_jump': 118,
#  'analysis/bn7_t_before_jump': 118,
#  'analysis/vtn5_rate': 235,
#  'analysis/vtn5_jump': 230,
#  'analysis/vtn5_t_before_jump': 230,
#  'analysis/vtn6_rate': 185,
#  'analysis/vtn6_jump': 182,
#  'analysis/vtn6_t_before_jump': 182,
#  'analysis/vtn7_rate': 119,
#  'analysis/vtn7_jump': 118,
#  'analysis/vtn7_t_before_jump': 118,
#  'analysis/b2_trans_rate_pct25': 133,
#  'analysis/b2_trans_rate_pct50': 133,
#  'analysis/b2_trans_rate_pct75': 133,
#  'analysis/vt2_trans_rate_pct25': 133,
#  'analysis/vt2_trans_rate_pct50': 133,
#  'analysis/vt2_trans_rate_pct75': 133,
#  'analysis/f_4': 967,
#  'analysis/b4_t_min': 967,
#  'analysis/b4_t_max': 967,
#  'analysis/b4_abs_min': 967,
#  'analysis/b4_abs_max': 967,
#  'analysis/b4_abs_fin': 967,
#  'analysis/b4_abs_pert': 967,
#  'analysis/vt4_t_min': 967,
#  'analysis/vt4_t_max': 967,
#  'analysis/vt4_abs_min': 967,
#  'analysis/vt4_abs_max': 967,
#  'analysis/vt4_abs_fin': 967,
#  'analysis/vt4_abs_pert': 967,
#  'analysis/b4_abs_sus': 967,
#  'analysis/b4_abs_sus_var': 967,
#  'analysis/b4_abs_trans': 967,
#  'analysis/b4_abs_trans_var': 967,
#  'analysis/b4_trans_rate_pct25': 338,
#  'analysis/b4_trans_rate_pct50': 338,
#  'analysis/b4_trans_rate_pct75': 338,
#  'analysis/vt4_abs_sus': 967,
#  'analysis/vt4_abs_sus_var': 967,
#  'analysis/vt4_abs_trans': 967,
#  'analysis/vt4_abs_trans_var': 967,
#  'analysis/vt4_trans_rate_pct25': 338,
#  'analysis/vt4_trans_rate_pct50': 338,
#  'analysis/vt4_trans_rate_pct75': 338,
#  'analysis/fb4_abs_sus': 967,
#  'analysis/fb4_abs_sus_var': 967,
#  'analysis/fb4_abs_trans': 967,
#  'analysis/fb4_abs_trans_var': 966,
#  'analysis/fvt4_abs_sus': 967,
#  'analysis/fvt4_abs_sus_var': 967,
#  'analysis/fvt4_abs_trans': 967,
#  'analysis/fvt4_abs_trans_var': 966,
#  'analysis/hrat4_abs_sus': 967,
#  'analysis/hrat4_abs_sus_var': 967,
#  'analysis/hrat4_abs_trans': 967,
#  'analysis/hrat4_abs_trans_var': 966,
#  'analysis/hrat4_abs_fin': 967,
#  'analysis/arat4_arg_sus': 967,
#  'analysis/arat4_arg_sus_var': 967,
#  'analysis/arat4_arg_trans': 967,
#  'analysis/arat4_arg_trans_var': 966,
#  'analysis/arat4_arg_trans_trend': 967,
#  'analysis/hrat4_arg_fin': 967,
#  'analysis/hrat4_abs_pert': 967,
#  'analysis/b4_rate': 967,
#  'analysis/b4_jump': 938,
#  'analysis/b4_t_before_jump': 938,
#  'analysis/vt4_rate': 967,
#  'analysis/vt4_jump': 939,
#  'analysis/vt4_t_before_jump': 939,
#  'analysis/bn6_trans_rate_pct25': 66,
#  'analysis/bn6_trans_rate_pct50': 66,
#  'analysis/bn6_trans_rate_pct75': 66,
#  'analysis/vtn6_trans_rate_pct25': 66,
#  'analysis/vtn6_trans_rate_pct50': 66,
#  'analysis/vtn6_trans_rate_pct75': 66,
#  'analysis/vt0_rate': 603,
#  'analysis/vt0_jump': 337,
#  'analysis/vt0_t_before_jump': 504,
#  'analysis/f_5': 605,
#  'analysis/b5_t_min': 605,
#  'analysis/b5_t_max': 605,
#  'analysis/b5_abs_min': 605,
#  'analysis/b5_abs_max': 605,
#  'analysis/b5_abs_fin': 605,
#  'analysis/b5_abs_pert': 605,
#  'analysis/vt5_t_min': 605,
#  'analysis/vt5_t_max': 605,
#  'analysis/vt5_abs_min': 605,
#  'analysis/vt5_abs_max': 605,
#  'analysis/vt5_abs_fin': 605,
#  'analysis/vt5_abs_pert': 605,
#  'analysis/b5_abs_sus': 605,
#  'analysis/b5_abs_sus_var': 605,
#  'analysis/b5_abs_trans': 605,
#  'analysis/b5_abs_trans_var': 605,
#  'analysis/b5_trans_rate_pct25': 256,
#  'analysis/b5_trans_rate_pct50': 256,
#  'analysis/b5_trans_rate_pct75': 256,
#  'analysis/vt5_abs_sus': 605,
#  'analysis/vt5_abs_sus_var': 605,
#  'analysis/vt5_abs_trans': 605,
#  'analysis/vt5_abs_trans_var': 605,
#  'analysis/vt5_trans_rate_pct25': 256,
#  'analysis/vt5_trans_rate_pct50': 256,
#  'analysis/vt5_trans_rate_pct75': 256,
#  'analysis/fb5_abs_sus': 605,
#  'analysis/fb5_abs_sus_var': 605,
#  'analysis/fb5_abs_trans': 605,
#  'analysis/fb5_abs_trans_var': 605,
#  'analysis/fvt5_abs_sus': 605,
#  'analysis/fvt5_abs_sus_var': 605,
#  'analysis/fvt5_abs_trans': 605,
#  'analysis/fvt5_abs_trans_var': 605,
#  'analysis/hrat5_abs_sus': 605,
#  'analysis/hrat5_abs_sus_var': 605,
#  'analysis/hrat5_abs_trans': 605,
#  'analysis/hrat5_abs_trans_var': 605,
#  'analysis/hrat5_abs_fin': 605,
#  'analysis/arat5_arg_sus': 605,
#  'analysis/arat5_arg_sus_var': 605,
#  'analysis/arat5_arg_trans': 605,
#  'analysis/arat5_arg_trans_var': 605,
#  'analysis/arat5_arg_trans_trend': 605,
#  'analysis/hrat5_arg_fin': 605,
#  'analysis/hrat5_abs_pert': 605,
#  'analysis/b5_rate': 605,
#  'analysis/b5_jump': 594,
#  'analysis/b5_t_before_jump': 594,
#  'analysis/vt5_rate': 605,
#  'analysis/vt5_jump': 594,
#  'analysis/vt5_t_before_jump': 594,
#  'analysis/b3_trans_rate_pct25': 496,
#  'analysis/b3_trans_rate_pct50': 496,
#  'analysis/b3_trans_rate_pct75': 496,
#  'analysis/vt3_trans_rate_pct25': 496,
#  'analysis/vt3_trans_rate_pct50': 496,
#  'analysis/vt3_trans_rate_pct75': 496,
#  'analysis/f_7': 225,
#  'analysis/b7_t_min': 225,
#  'analysis/b7_t_max': 225,
#  'analysis/b7_abs_min': 225,
#  'analysis/b7_abs_max': 225,
#  'analysis/b7_abs_fin': 225,
#  'analysis/b7_abs_pert': 225,
#  'analysis/f_8': 128,
#  'analysis/b8_t_min': 128,
#  'analysis/b8_t_max': 128,
#  'analysis/b8_abs_min': 128,
#  'analysis/b8_abs_max': 128,
#  'analysis/b8_abs_fin': 128,
#  'analysis/b8_abs_pert': 128,
#  'analysis/f_9': 72,
#  'analysis/b9_t_min': 72,
#  'analysis/b9_t_max': 72,
#  'analysis/b9_abs_min': 72,
#  'analysis/b9_abs_max': 72,
#  'analysis/b9_abs_fin': 72,
#  'analysis/b9_abs_pert': 72,
#  'analysis/f_11': 23,
#  'analysis/b11_t_min': 23,
#  'analysis/b11_t_max': 23,
#  'analysis/b11_abs_min': 23,
#  'analysis/b11_abs_max': 23,
#  'analysis/b11_abs_fin': 23,
#  'analysis/b11_abs_pert': 23,
#  'analysis/vt7_t_min': 225,
#  'analysis/vt7_t_max': 225,
#  'analysis/vt7_abs_min': 225,
#  'analysis/vt7_abs_max': 225,
#  'analysis/vt7_abs_fin': 225,
#  'analysis/vt7_abs_pert': 225,
#  'analysis/vt8_t_min': 128,
#  'analysis/vt8_t_max': 128,
#  'analysis/vt8_abs_min': 128,
#  'analysis/vt8_abs_max': 128,
#  'analysis/vt8_abs_fin': 128,
#  'analysis/vt8_abs_pert': 128,
#  'analysis/vt9_t_min': 72,
#  'analysis/vt9_t_max': 72,
#  'analysis/vt9_abs_min': 72,
#  'analysis/vt9_abs_max': 72,
#  'analysis/vt9_abs_fin': 72,
#  'analysis/vt9_abs_pert': 72,
#  'analysis/vt11_t_min': 23,
#  'analysis/vt11_t_max': 23,
#  'analysis/vt11_abs_min': 23,
#  'analysis/vt11_abs_max': 23,
#  'analysis/vt11_abs_fin': 23,
#  'analysis/vt11_abs_pert': 23,
#  'analysis/b7_abs_sus': 225,
#  'analysis/b7_abs_sus_var': 225,
#  'analysis/b7_abs_trans': 225,
#  'analysis/b7_abs_trans_var': 225,
#  'analysis/b8_abs_sus': 128,
#  'analysis/b8_abs_sus_var': 128,
#  'analysis/b8_abs_trans': 128,
#  'analysis/b8_abs_trans_var': 128,
#  'analysis/b9_abs_sus': 72,
#  'analysis/b9_abs_sus_var': 72,
#  'analysis/b9_abs_trans': 72,
#  'analysis/b9_abs_trans_var': 72,
#  'analysis/b11_abs_sus': 23,
#  'analysis/b11_abs_sus_var': 23,
#  'analysis/b11_abs_trans': 23,
#  'analysis/b11_abs_trans_var': 23,
#  'analysis/b11_trans_rate_pct25': 17,
#  'analysis/b11_trans_rate_pct50': 17,
#  'analysis/b11_trans_rate_pct75': 17,
#  'analysis/vt7_abs_sus': 225,
#  'analysis/vt7_abs_sus_var': 225,
#  'analysis/vt7_abs_trans': 225,
#  'analysis/vt7_abs_trans_var': 225,
#  'analysis/vt8_abs_sus': 128,
#  'analysis/vt8_abs_sus_var': 128,
#  'analysis/vt8_abs_trans': 128,
#  'analysis/vt8_abs_trans_var': 128,
#  'analysis/vt9_abs_sus': 72,
#  'analysis/vt9_abs_sus_var': 72,
#  'analysis/vt9_abs_trans': 72,
#  'analysis/vt9_abs_trans_var': 72,
#  'analysis/vt11_abs_sus': 23,
#  'analysis/vt11_abs_sus_var': 23,
#  'analysis/vt11_abs_trans': 23,
#  'analysis/vt11_abs_trans_var': 23,
#  'analysis/vt11_trans_rate_pct25': 17,
#  'analysis/vt11_trans_rate_pct50': 17,
#  'analysis/vt11_trans_rate_pct75': 17,
#  'analysis/fb7_abs_sus': 225,
#  'analysis/fb7_abs_sus_var': 225,
#  'analysis/fb7_abs_trans': 225,
#  'analysis/fb7_abs_trans_var': 225,
#  'analysis/fb8_abs_sus': 128,
#  'analysis/fb8_abs_sus_var': 128,
#  'analysis/fb8_abs_trans': 128,
#  'analysis/fb8_abs_trans_var': 128,
#  'analysis/fb9_abs_sus': 72,
#  'analysis/fb9_abs_sus_var': 72,
#  'analysis/fb9_abs_trans': 72,
#  'analysis/fb9_abs_trans_var': 72,
#  'analysis/fb11_abs_sus': 23,
#  'analysis/fb11_abs_sus_var': 23,
#  'analysis/fb11_abs_trans': 23,
#  'analysis/fb11_abs_trans_var': 23,
#  'analysis/fvt7_abs_sus': 225,
#  'analysis/fvt7_abs_sus_var': 225,
#  'analysis/fvt7_abs_trans': 225,
#  'analysis/fvt7_abs_trans_var': 225,
#  'analysis/fvt8_abs_sus': 128,
#  'analysis/fvt8_abs_sus_var': 128,
#  'analysis/fvt8_abs_trans': 128,
#  'analysis/fvt8_abs_trans_var': 128,
#  'analysis/fvt9_abs_sus': 72,
#  'analysis/fvt9_abs_sus_var': 72,
#  'analysis/fvt9_abs_trans': 72,
#  'analysis/fvt9_abs_trans_var': 72,
#  'analysis/fvt11_abs_sus': 23,
#  'analysis/fvt11_abs_sus_var': 23,
#  'analysis/fvt11_abs_trans': 23,
#  'analysis/fvt11_abs_trans_var': 23,
#  'analysis/hrat7_abs_sus': 225,
#  'analysis/hrat7_abs_sus_var': 225,
#  'analysis/hrat7_abs_trans': 225,
#  'analysis/hrat7_abs_trans_var': 225,
#  'analysis/hrat7_abs_fin': 225,
#  'analysis/arat7_arg_sus': 225,
#  'analysis/arat7_arg_sus_var': 225,
#  'analysis/arat7_arg_trans': 225,
#  'analysis/arat7_arg_trans_var': 225,
#  'analysis/arat7_arg_trans_trend': 225,
#  'analysis/hrat7_arg_fin': 225,
#  'analysis/hrat7_abs_pert': 225,
#  'analysis/hrat8_abs_sus': 128,
#  'analysis/hrat8_abs_sus_var': 128,
#  'analysis/hrat8_abs_trans': 128,
#  'analysis/hrat8_abs_trans_var': 128,
#  'analysis/hrat8_abs_fin': 128,
#  'analysis/arat8_arg_sus': 128,
#  'analysis/arat8_arg_sus_var': 128,
#  'analysis/arat8_arg_trans': 128,
#  'analysis/arat8_arg_trans_var': 128,
#  'analysis/arat8_arg_trans_trend': 128,
#  'analysis/hrat8_arg_fin': 128,
#  'analysis/hrat8_abs_pert': 128,
#  'analysis/hrat9_abs_sus': 72,
#  'analysis/hrat9_abs_sus_var': 72,
#  'analysis/hrat9_abs_trans': 72,
#  'analysis/hrat9_abs_trans_var': 72,
#  'analysis/hrat9_abs_fin': 72,
#  'analysis/arat9_arg_sus': 72,
#  'analysis/arat9_arg_sus_var': 72,
#  'analysis/arat9_arg_trans': 72,
#  'analysis/arat9_arg_trans_var': 72,
#  'analysis/arat9_arg_trans_trend': 72,
#  'analysis/hrat9_arg_fin': 72,
#  'analysis/hrat9_abs_pert': 72,
#  'analysis/hrat11_abs_sus': 23,
#  'analysis/hrat11_abs_sus_var': 23,
#  'analysis/hrat11_abs_trans': 23,
#  'analysis/hrat11_abs_trans_var': 23,
#  'analysis/hrat11_abs_fin': 23,
#  'analysis/arat11_arg_sus': 23,
#  'analysis/arat11_arg_sus_var': 23,
#  'analysis/arat11_arg_trans': 23,
#  'analysis/arat11_arg_trans_var': 23,
#  'analysis/arat11_arg_trans_trend': 23,
#  'analysis/hrat11_arg_fin': 23,
#  'analysis/hrat11_abs_pert': 23,
#  'analysis/b7_rate': 225,
#  'analysis/b7_jump': 225,
#  'analysis/b7_t_before_jump': 225,
#  'analysis/b8_rate': 128,
#  'analysis/b8_jump': 128,
#  'analysis/b8_t_before_jump': 128,
#  'analysis/b9_rate': 72,
#  'analysis/b9_jump': 72,
#  'analysis/b9_t_before_jump': 72,
#  'analysis/b11_rate': 23,
#  'analysis/b11_jump': 23,
#  'analysis/b11_t_before_jump': 23,
#  'analysis/vt7_rate': 225,
#  'analysis/vt7_jump': 225,
#  'analysis/vt7_t_before_jump': 225,
#  'analysis/vt8_rate': 128,
#  'analysis/vt8_jump': 128,
#  'analysis/vt8_t_before_jump': 128,
#  'analysis/vt9_rate': 72,
#  'analysis/vt9_jump': 72,
#  'analysis/vt9_t_before_jump': 72,
#  'analysis/vt11_rate': 23,
#  'analysis/vt11_jump': 23,
#  'analysis/vt11_t_before_jump': 23,
#  'analysis/f_6': 354,
#  'analysis/b6_t_min': 354,
#  'analysis/b6_t_max': 354,
#  'analysis/b6_abs_min': 354,
#  'analysis/b6_abs_max': 354,
#  'analysis/b6_abs_fin': 354,
#  'analysis/b6_abs_pert': 354,
#  'analysis/vt6_t_min': 354,
#  'analysis/vt6_t_max': 354,
#  'analysis/vt6_abs_min': 354,
#  'analysis/vt6_abs_max': 354,
#  'analysis/vt6_abs_fin': 354,
#  'analysis/vt6_abs_pert': 354,
#  'analysis/b6_abs_sus': 354,
#  'analysis/b6_abs_sus_var': 354,
#  'analysis/b6_abs_trans': 354,
#  'analysis/b6_abs_trans_var': 354,
#  'analysis/b6_trans_rate_pct25': 130,
#  'analysis/b6_trans_rate_pct50': 130,
#  'analysis/b6_trans_rate_pct75': 130,
#  'analysis/vt6_abs_sus': 354,
#  'analysis/vt6_abs_sus_var': 354,
#  'analysis/vt6_abs_trans': 354,
#  'analysis/vt6_abs_trans_var': 354,
#  'analysis/vt6_trans_rate_pct25': 130,
#  'analysis/vt6_trans_rate_pct50': 130,
#  'analysis/vt6_trans_rate_pct75': 130,
#  'analysis/fb6_abs_sus': 354,
#  'analysis/fb6_abs_sus_var': 354,
#  'analysis/fb6_abs_trans': 354,
#  'analysis/fb6_abs_trans_var': 354,
#  'analysis/fvt6_abs_sus': 354,
#  'analysis/fvt6_abs_sus_var': 354,
#  'analysis/fvt6_abs_trans': 354,
#  'analysis/fvt6_abs_trans_var': 354,
#  'analysis/hrat6_abs_sus': 354,
#  'analysis/hrat6_abs_sus_var': 354,
#  'analysis/hrat6_abs_trans': 354,
#  'analysis/hrat6_abs_trans_var': 354,
#  'analysis/hrat6_abs_fin': 354,
#  'analysis/arat6_arg_sus': 354,
#  'analysis/arat6_arg_sus_var': 354,
#  'analysis/arat6_arg_trans': 354,
#  'analysis/arat6_arg_trans_var': 354,
#  'analysis/arat6_arg_trans_trend': 354,
#  'analysis/hrat6_arg_fin': 354,
#  'analysis/hrat6_abs_pert': 354,
#  'analysis/b6_rate': 354,
#  'analysis/b6_jump': 350,
#  'analysis/b6_t_before_jump': 350,
#  'analysis/vt6_rate': 354,
#  'analysis/vt6_jump': 350,
#  'analysis/vt6_t_before_jump': 350,
#  'analysis/b7_trans_rate_pct25': 88,
#  'analysis/b7_trans_rate_pct50': 88,
#  'analysis/b7_trans_rate_pct75': 88,
#  'analysis/vt7_trans_rate_pct25': 88,
#  'analysis/vt7_trans_rate_pct50': 88,
#  'analysis/vt7_trans_rate_pct75': 88,
#  'analysis/bn3_trans_rate_pct25': 115,
#  'analysis/bn3_trans_rate_pct50': 115,
#  'analysis/bn3_trans_rate_pct75': 115,
#  'analysis/vtn3_trans_rate_pct25': 115,
#  'analysis/vtn3_trans_rate_pct50': 115,
#  'analysis/vtn3_trans_rate_pct75': 115,
#  'analysis/b1_trans_rate_pct25': 13,
#  'analysis/b1_trans_rate_pct50': 13,
#  'analysis/b1_trans_rate_pct75': 13,
#  'analysis/vt1_trans_rate_pct25': 13,
#  'analysis/vt1_trans_rate_pct50': 13,
#  'analysis/vt1_trans_rate_pct75': 13,
#  'analysis/bn1_trans_rate_pct25': 32,
#  'analysis/bn1_trans_rate_pct50': 32,
#  'analysis/bn1_trans_rate_pct75': 32,
#  'analysis/vtn1_trans_rate_pct25': 32,
#  'analysis/vtn1_trans_rate_pct50': 32,
#  'analysis/vtn1_trans_rate_pct75': 32,
#  'analysis/b8_trans_rate_pct25': 52,
#  'analysis/b8_trans_rate_pct50': 52,
#  'analysis/b8_trans_rate_pct75': 52,
#  'analysis/vt8_trans_rate_pct25': 52,
#  'analysis/vt8_trans_rate_pct50': 52,
#  'analysis/vt8_trans_rate_pct75': 52,
#  'analysis/f_10': 59,
#  'analysis/b10_t_min': 59,
#  'analysis/b10_t_max': 59,
#  'analysis/b10_abs_min': 59,
#  'analysis/b10_abs_max': 59,
#  'analysis/b10_abs_fin': 59,
#  'analysis/b10_abs_pert': 59,
#  'analysis/vt10_t_min': 59,
#  'analysis/vt10_t_max': 59,
#  'analysis/vt10_abs_min': 59,
#  'analysis/vt10_abs_max': 59,
#  'analysis/vt10_abs_fin': 59,
#  'analysis/vt10_abs_pert': 59,
#  'analysis/b10_abs_sus': 59,
#  'analysis/b10_abs_sus_var': 59,
#  'analysis/b10_abs_trans': 59,
#  'analysis/b10_abs_trans_var': 59,
#  'analysis/b10_trans_rate_pct25': 31,
#  'analysis/b10_trans_rate_pct50': 31,
#  'analysis/b10_trans_rate_pct75': 31,
#  'analysis/vt10_abs_sus': 59,
#  'analysis/vt10_abs_sus_var': 59,
#  'analysis/vt10_abs_trans': 59,
#  'analysis/vt10_abs_trans_var': 59,
#  'analysis/vt10_trans_rate_pct25': 31,
#  'analysis/vt10_trans_rate_pct50': 31,
#  'analysis/vt10_trans_rate_pct75': 31,
#  'analysis/fb10_abs_sus': 59,
#  'analysis/fb10_abs_sus_var': 59,
#  'analysis/fb10_abs_trans': 59,
#  'analysis/fb10_abs_trans_var': 59,
#  'analysis/fvt10_abs_sus': 59,
#  'analysis/fvt10_abs_sus_var': 59,
#  'analysis/fvt10_abs_trans': 59,
#  'analysis/fvt10_abs_trans_var': 59,
#  'analysis/hrat10_abs_sus': 59,
#  'analysis/hrat10_abs_sus_var': 59,
#  'analysis/hrat10_abs_trans': 59,
#  ...}

# %%
start = datetime.datetime(2020, 1, 1, 0, 0, 0, 0)
#end = datetime.datetime(2012, 2, 2, 6, 55, 3, 381)

    
with SSHTunnelForwarder(    
    MONGO_HOST,
    ssh_username=MONGO_USER,
    ssh_pkey="~/.ssh/id_rsa",
    remote_bind_address=('localhost', 27017),
    local_bind_address=('localhost',local_port)
) as server:
    with pymongo.MongoClient('localhost', local_port) as connection:
        db = connection[MONGO_DB]
        collection = db[MONGO_COLLECTION]

        #for f in os.listdir('.'):
        #    collection.insert_one({'name':f, 'time':os.stat(f).st_mtime, 'size':os.stat(f).st_size})
        for doc in collection.find({'time.modification':{'$gte': start}}):
            print(json.dumps(doc,default=str,indent=2))

# %%
from random_single_mode_vt_bore_reed import ivp_simulate, do_analysis

def simulate_js(js):
    data = ivp_simulate(js)
    analysis = do_analysis(data, impedance=False)
 
    return data,analysis

# %%
import os
import numpy as np
from glob import glob
from pypevoc.Heterodyne import HeterodyneHarmonic
from pypevoc.PVAnalysis import PV
import timeseries as ts
import scipy.signal as sig

def db(x):
    return 20*np.log10(x)

# %%
plt.figure()
sns.distplot(df1['analysis/hrat1_abs_trans']-df1['analysis/hrat1_abs_fin'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-402-610c99ca0912> in <module>
#       1 plt.figure()
# ----> 2 sns.distplot(df1['analysis/hrat1_abs_trans']-df1['analysis/hrat1_abs_fin'])
#
# ~/.pyenv/versions/unsw/lib/python3.7/site-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     213     if hist:
#     214         if bins is None:
# --> 215             bins = min(_freedman_diaconis_bins(a), 50)
#     216         hist_kws.setdefault("alpha", 0.4)
#     217         if LooseVersion(mpl.__version__) < LooseVersion("2.2"):
#
# ~/.pyenv/versions/unsw/lib/python3.7/site-packages/seaborn/distributions.py in _freedman_diaconis_bins(a)
#      37         return int(np.sqrt(a.size))
#      38     else:
# ---> 39         return int(np.ceil((a.max() - a.min()) / h))
#      40
#      41
#
# ValueError: cannot convert float NaN to integer

# %%
import random
from json_object import JSONObject

#row = df[np.abs(-20*np.log10(df['zrat_f0'])-df['analysis/hrat1_abs_fin'])>5].sample().iloc[0]
#row = df[df['analysis/hrat1_abs_fin']<-20].sample().iloc[0]
# row = df1[df1['analysis/hrat1_abs_trans']-df1['analysis/hrat1_abs_fin']<-10].sample().iloc[0]
row = df1.sample().iloc[0]
idx= row.name
print(row['analysis/hrat1_abs_fin'],-20*np.log10(row['zrat_f0']))
data,anal=simulate_js(JSONObject(ll[idx]['simulation']['params']))
# Out:
# -8.18153069663395 -7.75530434512857
# <instr_vt_poleres.nlstiff_parabolic object at 0x7fe65cac3790>
# 2457.6000000000004
# 2457.6000000000004
# 2457.6000000000004
# 2457.6
# 2340.571428571429
# 2457.6000000000004
# 2457.6000000000004
# 2457.6000000000004
# 2457.6
# 2340.571428571429
# Error in exponential estimation in vt0
# Traceback (most recent call last):
#   File "/home/goios/Devel/vocalsims/projects/clarinet_vocal_tract/modal_simulations/simulation_harmonic_transient_analyser.py", line 237, in do_analysis
#     rm=RANSACRegressor().fit(X,y)
#   File "/home/goios/.pyenv/versions/unsw/lib/python3.7/site-packages/sklearn/linear_model/_ransac.py", line 282, in fit
#     "of samples: n_samples = %d." % (X.shape[0]))
# ValueError: `min_samples` may not be larger than number of samples: n_samples = 1.

# %%
figure()
t = np.arange(len(data['p_b']))/data['js']['simulation']['sample rate']
plot(t,data['p_b'])
plot(t,data['p_vt']+data['p_blow'])
axvline(anal['pert_time'],color='m')
axvspan(anal['t_trans_start'],anal['t_trans_end'],color='r',alpha=.2)

# %%
row['analysis/f0']
# Out:
# 962.8379702003683

# %%
close('all')

# %%
t_init=[0.01,0.05]
t_fin=0.1
tsust=0.1

# extract main parameters
res = {}
sr = data['js']['simulation']['sample rate']
pb = data['p_b']
pvt = data['p_vt']
t = np.arange(len(pb))/sr
if data['pert_time']>0:
    res['pert_time']=data['pert_time']
else:
    res['pert_time'] = 0


pbinit = pb[int(t_init[0]*sr):int(t_init[1]*sr)]
res['initial amplitude'] = np.max(pbinit)-np.min(pbinit)
pbfin = pb[-int(t_fin*sr):]
res['final amplitude'] = np.max(pbfin)-np.min(pbfin) 

# fundamental frequency for harmonic analysis
pvpb = PV(pb,sr=sr,progress=False,nfft=1024*16,hop=512*2,pkthresh=1e-10)
pvpb.run_pv()
fts = ts.SampledTimeSeries(pvpb.fundamental_frequency, pvpb.t)

f0 = fts.percentile(50,from_time=fts.t[-1]-0.2)
if f0<20:
    f0 = np.median(fts.v[fts.v>0])
res['f0'] = f0
fw,pbw = sig.welch(pb,nperseg=2**10,nfft=2**12,fs=sr)

mainf = pvpb.f[np.arange(pvpb.f.shape[0]),np.argmin(np.abs(pvpb.f-f0),axis=1)]
mainfts = ts.SampledTimeSeries(mainf, pvpb.t)

# harmonic analysis
try:
    nwind = int(sr/f0*3)
except ValueError:
    nwind = 1024


ha = {}
for lab in ('b', 'vt', 'm'):
    try:
        p = data['p_{}'.format(lab)]
    except KeyError:
        continue

    h = HeterodyneHarmonic(p,sr=sr,tf=[0,max(pvpb.t)],f=[f0,f0],nwind=nwind,nhop=128)
    h_array = [ts.SampledTimeSeries(np.abs(h.camp[:,ii]),h.t,label='h{}{}'.format(lab,ii+1)) for ii in range(h.camp.shape[1])]
    ha[lab] = h_array
    for ii, hts in enumerate(h_array):
        res['{}_t_min'.format(hts.label)]=hts.min_time()
        res['{}_t_max'.format(hts.label)]=hts.max_time()
        res['{}_abs_min'.format(hts.label)]=hts.min()
        res['{}_abs_max'.format(hts.label)]=hts.max()
        res['{}_abs_fin'.format(hts.label)]=hts.v[-1]
        if data['pert_time']>1e-4:
            res['{}_abs_pert'.format(hts.label)]=hts[data['pert_time']]
        else:
            res['{}_abs_pert'.format(hts.label)]=np.nan    

hts_array = ha['b']
vts_array = ha['vt']

# transient detection using one envelope
ats = hts_array[0]

amax = ats.max()

a_trans_end = amax*.7
a_trans_start = amax*.001
try:
    t_trans_end = ats.crossing_times(a_trans_end)[0][0]
except IndexError:
    t_trans_end = ats.v[-1]
try:
    t_trans_start = ats.crossing_times(a_trans_start,to_time=t_trans_end)[0][0]
except IndexError:
    t_trans_start = t_trans_end - ats.dt

atrans, ttrans = ats.apply(db).times_values_in_range(from_time=t_trans_start,to_time=t_trans_end)

# frequency comparison
fsusav = fts.mean(from_time=fts.t[-1]-tsust)
res['t_trans_start']=t_trans_start
res['t_trans_end']=t_trans_end
res['sus_f0_avg']=fts.mean(from_time=fts.t[-1]-tsust)
res['sus_f0_std']=fts.std(from_time=fts.t[-1]-tsust)
res['trans_f0_avg']=fts.mean(from_time=t_trans_start, to_time=t_trans_end)
res['trans_f0_std']=fts.std(from_time=t_trans_start, to_time=t_trans_end)

# harmonic descriptor extraction
for h_array in (hts_array,vts_array):
    for ii, hts in enumerate(h_array):
        res['{}_abs_sus'.format(hts.label)]=hts.percentile(50,from_time=fts.t[-1]-tsust)
        res['{}_abs_sus_var'.format(hts.label)]=np.diff(hts.percentile([75,25],from_time=fts.t[-1]-tsust))[0]
        res['{}_abs_trans'.format(hts.label)]=hts.percentile(50,from_time=t_trans_start, to_time=t_trans_end)
        res['{}_abs_trans_var'.format(hts.label)]=np.diff(hts.percentile([75,25],from_time=t_trans_start, to_time=t_trans_end))[0]

    # growth rate via derivative
    dts = hts.apply(db).diff()
    dts.label = hts.label
    for pct in [25,50,75]:
        res['{}_trans_rate_pct{}'.format(dts.label,pct)]=dts.percentile(pct,from_time=t_trans_start, to_time=t_trans_end)

    res['{}_abs_fin'.format(hts.label)]=hts.v[-1]
    if data['pert_time']>1e-4:
        res['{}_abs_pert'.format(hts.label)]=hts[data['pert_time']]
    else:
        res['{}_abs_pert'.format(hts.label)]=np.nan    

# harmonic ratio descriptors
for ii, hts in enumerate(hts_array):
    vts = vts_array[ii]
    rts = vts.apply(db)-hts.apply(db)
    rts.label = 'hrat{}'.format(ii+1)
    res['{}_abs_sus'.format(rts.label)]=rts.percentile(50,from_time=fts.t[-1]-tsust)
    res['{}_abs_sus_var'.format(rts.label)]=np.diff(rts.percentile([75,25],from_time=fts.t[-1]-tsust))[0]
    res['{}_abs_trans'.format(rts.label)]=rts.percentile(50,from_time=t_trans_start, to_time=t_trans_end)
    res['{}_abs_trans_var'.format(rts.label)]=np.diff(rts.percentile([75,25],from_time=t_trans_start, to_time=t_trans_end))[0]
    res['{}_abs_fin'.format(rts.label)]=rts.v[-1]
    if data['pert_time']>1e-4:
        res['{}_abs_pert'.format(rts.label)]=rts[data['pert_time']]
    else:
        res['{}_abs_pert'.format(rts.label)]=np.nan
# Out:
# WARNING:py.warnings:/home/goios/Devel/pypevoc/pypevoc/PVAnalysis.py:171: RuntimeWarning: divide by zero encountered in true_divide
#   frat = fx / self.oldfft
#
# WARNING:py.warnings:/home/goios/Devel/pypevoc/pypevoc/PVAnalysis.py:171: RuntimeWarning: invalid value encountered in true_divide
#   frat = fx / self.oldfft

# %%
from pypevoc.Heterodyne import heterodyne

def heterodyne_corr(x,sr,f,maxwind=2**14,nhop=2**10,nper=3,dc_cut=50):
    #c1,_ = heterodyne(x,x,wind=np.hanning(nwind),hop=nhop)
    xx = x.copy()
#     newn = int(len(xx)/sr*dc_cut)
#     x2 = np.concatenate((xx,np.zeros(int((newn+1)*sr/dc_cut))))
#     print(newn,x2.shape)
#     xd = sig.resample(x2,newn)
#     xu = sig.resample(xd,len(x2))[:len(xx)]
#     xx -= xu
    t = np.arange(len(x))/sr
    #npts = len(c1)
    nharm = len(f)
    #camp = np.zeros((npts,nharm),dtype='complex')
    ret = []
    part = np.zeros((len(x),nharm))
    for ii,ff in enumerate(f):
        #nwind = int(min(maxwind,sr/ff*nper))
        if ff==0.:
            nwind=maxwind
        foth = np.delete(f,ii)
        nwind = (sr/np.min(np.abs(foth-ff))*nper)
        print(nwind)
        hetsig = np.exp(1j*2*np.pi*ff*t)
        cc,ih = heterodyne(xx,hetsig,wind=np.hanning(nwind),hop=nhop)
        if ff==0.:
            cc/=2
        th=ih/sr
        ret.append(ts.SampledTimeSeries(cc,th,label='%.2f'%ff))
        hf = np.interp(t,th,cc)
        xp = np.real(np.conjugate(hf)*hetsig)
        xx-=xp
        part[:,ii]=xp
    return ret,xx,part

# %%
from scipy.signal import welch,find_peaks

fw,w=welch(pb,fs=sr,nperseg=2**14)

fig,ax=subplots(1)
semilogy(fw,w)
xlim(0,2000)

pks,_=find_peaks(10*np.log10(w),prominence=20)
ff=fw[pks]
ff=ff[(ff<2000)&(ff>100)]
nw=int(sr/np.min(ff)*6)
semilogy(fw[pks],w[pks],'o')

ff=np.insert(ff,0,0)

print(ff)

#nw=nwind
nw=2**16
nper=3
hetpb,pbresid,pbpart=heterodyne_corr(pb,sr,ff,maxwind=nw,nhop=128,nper=nper)
hetpv,pvresid,pvpart=heterodyne_corr(pvt,sr,ff,maxwind=nw,nhop=128,nper=nper)
fig,ax=subplots(1)
for tts in hetpv:
    ax.semilogy(tts.t,np.abs(tts.v),label=tts.label)
    
ax.legend()
ax.set_yscale('log')

figure()
plot(pb,color='k',alpha=.4)
plot(pbpart,alpha=.2)
plot(pbresid,color='k')
# Out:
# [   0.          470.06497389  940.12994778 1410.19492167 1903.76314425]
# 2457.6000000000004
# 2457.6000000000004
# 2457.6000000000004
# 2457.6
# 2340.571428571429
# 2457.6000000000004
# 2457.6000000000004
# 2457.6000000000004
# 2457.6
# 2340.571428571429

# %%
thr=.05
f0r = f0
for f in ff:
    if f==0:
        continue
    frat = f/f0r
    hno = np.round(frat)
    fdev = np.abs(frat-hno)
    print(f,frat,fdev,fdev<thr,hno)
    #if fdev<thr:
    #    f0r=np.mean([f0r,f/hno])
# Out:
# 470.064973889271 0.9962451700685894 0.0037548299314106304 True 1.0
# 940.129947778542 1.9924903401371787 0.007509659862821261 True 2.0
# 1410.194921667813 2.988735510205768 0.011264489794232002 True 3.0
# 1903.7631442515476 4.0347929387777866 0.03479293877778655 True 4.0

# %%
np.diff(fw)[0]
# Out:
# 23.50324869446355

# %%
f0r
# Out:
# 471.83664022873813

# %%
def semilogabsy(x,y,*args,**kwargs):
    return semilogy(x,np.abs(y),*args,**kwargs)
figure()
plot(np.arange(len(pb)),pb-np.sum(pbpart[:,0:2],axis=1))
plot(np.arange(len(pb)),pvt-np.sum(pvpart[:,0:2],axis=1))

# %%
mainidx = np.argmin(np.abs(np.array(ff)-f0))
print( f0,ff[mainidx])
fig,ax=subplots(1)
plot(hetpb[mainidx].t,np.abs(hetpb[mainidx].v))
plot(hetpv[mainidx].t,np.abs(hetpv[mainidx].v))
ax.set_yscale('log')
ax.axvline(data['pert_time'],color='r')
# Out:
# 471.83664022873813 470.064973889271

# %%
pvt
# Out:
# array([-1.30389796e-05, -3.07466910e-05, -4.95537285e-05, ...,
#        -3.96089878e-01, -3.93927180e-01, -3.91744561e-01])

# %%
fig,ax=subplots(1)
hb = hetpb[mainidx].apply(np.abs)
hb.plot(ax=ax)
hv = hetpv[mainidx].apply(np.abs)
hv.plot(ax=ax)
ax.axvline(data['pert_time'],color='r')
ax.set_yscale('log')

# %%
print(row['analysis/hrat1_abs_trans'],row['analysis/hrat1_abs_fin'],-20*np.log10(row['zrat_f0']))
# Out:
# -7.065084625383953 -8.18153069663395 -7.75530434512857

# %%
fig,ax = plt.subplots(3,sharex=True)
hb1 = hb.copy()
hb1.label= 'bore'
hb1.plot(ax=ax[0])
hv1 = hv.copy()
hv1.label='vocal tract'
hv1.plot(ax=ax[0])
ax[0].set_yscale('log')
ax[0].set_ylabel('$p_{RMS}/(k H_0)$')
ax[0].legend()
(hb1/hv1).plot(ax=ax[1])
ax[1].set_yscale('log')
ax[1].set_ylabel('ratio bore to VT')
zts = mainfts.apply(lambda x: impedance(x,fvec = [row['simulation/params/bore/frequencies/0']],
         qvec = [row['simulation/params/bore/qs/0']],
         avec=[row['simulation/params/bore/amplitudes/0']])/impedance(x,fvec = [row['simulation/params/vocal/frequencies/0']],
         qvec = [row['simulation/params/vocal/qs/0']],
         avec=[row['simulation/params/vocal/amplitudes/0']]))
zts.plot(ax=ax[1])
ax[1].legend(['p','Z'])

mainfts.plot(ax=ax[2])
ax[2].set_ylabel('freq (Hz)')

for axi in ax:
    axi.axvline(data['pert_time'],color='k',alpha=.3)
# Out:
# WARNING:py.warnings:/home/goios/.pyenv/versions/unsw/lib/python3.7/site-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in true_divide

# %%
fig,ax = subplots(1)
ax.specgram(data['p_b'],Fs=sr,NFFT=2**13,cmap='gray')
pvpb.plot_time_freq(ax=ax)
ax.plot(pvpb.t,pvpb.fundamental_frequency)
ax.plot(pvpb.t,mainf)
ax.set_ylim(0,2000)
fig,ax = subplots(1)
ax.specgram(data['p_vt'],Fs=sr,NFFT=2**13,cmap='gray')
#pvpb.plot_time_freq(ax=ax)
# ax.plot(pvpb.t,pvpb.fundamental_frequency)
# ax.plot(pvpb.t,mainf)
ax.set_ylim(0,2000)
# Out:
# WARNING:py.warnings:/home/goios/Devel/pypevoc/pypevoc/PVAnalysis.py:335: RuntimeWarning: divide by zero encountered in log10
#   mag = 20*np.log10(self.mag)
# (0.0, 2000.0)

# %%
from sklearn.linear_model import RANSACRegressor
fig,ax=subplots(1)
for hh in [hb1,hv1]:
    print(hh.label)
    hbl1=hh.apply(db)
    vals=hbl1.percentile([5,99])
    ted=hbl1.crossing_times(vals[1]-6)[0][0]
    tst=hbl1.crossing_times(vals[1]-46,to_time=ted)[0][-1]
    print(tst,ted)
    x,y=hbl1.times_values_in_range(tst,ted)
    X = np.array([x]).T
    rm=RANSACRegressor().fit(X,y)
    print(rm.estimator_.intercept_,rm.estimator_.coef_)
    fig,ax=hbl1.plot(ax=ax)
    xpred,ytrue = hbl1.times_values_in_range(data['pert_time']-.05,ted)
    Xpred = np.array([xpred]).T
    ypred = rm.predict(Xpred)
    ax.plot(xpred,ypred)
    print (np.max(ypred-ytrue))
# Out:
# bore
# 0.11198310603970671 0.12384521414513472
# -447.3216819031485 [3389.38984661]
# 0.06951079970991003
# vocal tract
# 0.11458515311367044 0.12702887597619275
# -430.1161407820746 [3314.14153846]
# 1.2056518199179038

# %%
y
# Out:
# array([-50.6789116 , -49.59884463, -48.46268233, -47.3579719 ,
#        -46.27152024, -45.12744632, -44.01243063, -42.91800328,
#        -41.76745415, -40.64662238, -39.5507265 , -38.39973777,
#        -37.27733542, -36.18084644, -35.02806816, -33.9012993 ,
#        -32.80287403, -31.64756894, -30.5157917 , -29.41281681,
#        -28.25429838, -27.11948966, -26.01843779, -24.86019   ,
#        -23.71950594, -22.61391701, -21.46399887, -20.34294466,
#        -19.27288406, -18.17695977, -17.11896527, -16.12413858,
#        -15.13022796, -14.18881172, -13.32293387, -12.47097656,
#        -11.66921824, -10.94054889])

# %%
row.to_dict()
# Out:
# {'_id': ObjectId('5f96925b98b40108a64ec6f6'),
#  'simulation/start': Timestamp('2020-10-26 20:09:20.661000'),
#  'simulation/params/tmax': 0.5,
#  'simulation/params/gamma/sustain_val': 0.6233710773350962,
#  'simulation/params/gamma/time_const': 0.05,
#  'simulation/params/gamma/exp_limit_multiplier': 1.1,
#  'simulation/params/zeta': 0.5,
#  'simulation/params/reed/frequency': 3850.772266100908,
#  'simulation/params/reed/q': 2.8328228051701805,
#  'simulation/params/reed/amplitude': 2.8328228051701805,
#  'simulation/params/bore/frequencies/0': 726.1581554762913,
#  'simulation/params/bore/qs/0': 13.492181731950268,
#  'simulation/params/bore/amplitudes/0': 13.492181731950268,
#  'simulation/params/vocal/frequencies/0': 500,
#  'simulation/params/vocal/qs/0': 15,
#  'simulation/params/vocal/amplitudes/0': 15,
#  'simulation/params/nlfunc/nl_start': 0.75,
#  'simulation/params/nlfunc/nl_ev': 1.1,
#  'simulation/params/perturbation/multiplier': 1.1,
#  'simulation/params/perturbation/duration': 0.39816598338508535,
#  'simulation/params/simulation/sample rate': 385077.2266100908,
#  'simulation/end': Timestamp('2020-10-26 20:09:46.104000'),
#  'analysis/pert_time': 0.11989543086315138,
#  'analysis/initial amplitude': 0.002409465303274145,
#  'analysis/final amplitude': 0.37969661845436664,
#  'analysis/f0': 962.8379702003683,
#  'analysis/f_0': 0.0,
#  'analysis/b0_t_min': 0.1338251042619569,
#  'analysis/b0_t_max': 0.03410484726820248,
#  'analysis/b0_abs_min': 0.006363547248243773,
#  'analysis/b0_abs_max': 0.014263581174493159,
#  'analysis/b0_abs_fin': 0.008335175438840091,
#  'analysis/b0_abs_pert': 0.01145554662834613,
#  'analysis/f_1': 940.129947778542,
#  'analysis/b1_t_min': 0.05670810552012015,
#  'analysis/b1_t_max': 0.49414763286605623,
#  'analysis/b1_abs_min': 1.2432754896981734e-10,
#  'analysis/b1_abs_max': 0.10937887452995207,
#  'analysis/b1_abs_fin': 0.10937045812081576,
#  'analysis/b1_abs_pert': 0.00017793202943336387,
#  'analysis/f_2': 1903.7631442515476,
#  'analysis/b2_t_min': 0.08447656145851119,
#  'analysis/b2_t_max': 0.3031963251314792,
#  'analysis/b2_abs_min': 9.914317893753216e-11,
#  'analysis/b2_abs_max': 0.012483477105626186,
#  'analysis/b2_abs_fin': 0.01214987157274705,
#  'analysis/b2_abs_pert': 1.193841899559215e-06,
#  'analysis/f_3': nan,
#  'analysis/b3_t_min': nan,
#  'analysis/b3_t_max': nan,
#  'analysis/b3_abs_min': nan,
#  'analysis/b3_abs_max': nan,
#  'analysis/b3_abs_fin': nan,
#  'analysis/b3_abs_pert': nan,
#  'analysis/f_4': nan,
#  'analysis/b4_t_min': nan,
#  'analysis/b4_t_max': nan,
#  'analysis/b4_abs_min': nan,
#  'analysis/b4_abs_max': nan,
#  'analysis/b4_abs_fin': nan,
#  'analysis/b4_abs_pert': nan,
#  'analysis/vt0_t_min': 0.13116589740879012,
#  'analysis/vt0_t_max': 0.0314456404150357,
#  'analysis/vt0_abs_min': 0.003372128128640096,
#  'analysis/vt0_abs_max': 0.012867187075197505,
#  'analysis/vt0_abs_fin': 0.007562903166160819,
#  'analysis/vt0_abs_pert': 0.010561424470382165,
#  'analysis/vt1_t_min': 0.05670810552012015,
#  'analysis/vt1_t_max': 0.38877656130932237,
#  'analysis/vt1_abs_min': 1.1743499797356181e-10,
#  'analysis/vt1_abs_max': 0.04272868076779015,
#  'analysis/vt1_abs_fin': 0.042640618591849075,
#  'analysis/vt1_abs_pert': 3.5371309879450344e-05,
#  'analysis/vt2_t_min': 0.08447656145851119,
#  'analysis/vt2_t_max': 0.3031963251314792,
#  'analysis/vt2_abs_min': 5.05401536933991e-11,
#  'analysis/vt2_abs_max': 0.007882289004952069,
#  'analysis/vt2_abs_fin': 0.0076595356227973505,
#  'analysis/vt2_abs_pert': 2.610373841806339e-06,
#  'analysis/vt3_t_min': nan,
#  'analysis/vt3_t_max': nan,
#  'analysis/vt3_abs_min': nan,
#  'analysis/vt3_abs_max': nan,
#  'analysis/vt3_abs_fin': nan,
#  'analysis/vt3_abs_pert': nan,
#  'analysis/vt4_t_min': nan,
#  'analysis/vt4_t_max': nan,
#  'analysis/vt4_abs_min': nan,
#  'analysis/vt4_abs_max': nan,
#  'analysis/vt4_abs_fin': nan,
#  'analysis/vt4_abs_pert': nan,
#  'analysis/t_trans_start': 0.11898496825255839,
#  'analysis/t_trans_end': 0.13192533113680155,
#  'analysis/sus_f0_avg': 961.3166232147433,
#  'analysis/sus_f0_std': 75.24266001745733,
#  'analysis/trans_f0_avg': 356.83339424621994,
#  'analysis/trans_f0_std': 220.38989589299518,
#  'analysis/b0_abs_sus': 0.008141281364034195,
#  'analysis/b0_abs_sus_var': 0.00018649340075263011,
#  'analysis/b0_abs_trans': 0.010057285454365907,
#  'analysis/b0_abs_trans_var': 0.0030649412318748404,
#  'analysis/b1_abs_sus': 0.1091242843944361,
#  'analysis/b1_abs_sus_var': 0.0003151542280654951,
#  'analysis/b1_abs_trans': 0.006608225800641096,
#  'analysis/b1_abs_trans_var': 0.02947410654252046,
#  'analysis/b2_abs_sus': 0.012266565124181221,
#  'analysis/b2_abs_sus_var': 0.0001148017614431094,
#  'analysis/b2_abs_trans': 0.0003466425174876261,
#  'analysis/b2_abs_trans_var': 0.0021184776489865257,
#  'analysis/b3_abs_sus': nan,
#  'analysis/b3_abs_sus_var': nan,
#  'analysis/b3_abs_trans': nan,
#  'analysis/b3_abs_trans_var': nan,
#  'analysis/b4_abs_sus': nan,
#  'analysis/b4_abs_sus_var': nan,
#  'analysis/b4_abs_trans': nan,
#  'analysis/b4_abs_trans_var': nan,
#  'analysis/b4_trans_rate_pct25': nan,
#  'analysis/b4_trans_rate_pct50': nan,
#  'analysis/b4_trans_rate_pct75': nan,
#  'analysis/vt0_abs_sus': 0.007351187303554618,
#  'analysis/vt0_abs_sus_var': 0.00014368964609807154,
#  'analysis/vt0_abs_trans': 0.008786431909547854,
#  'analysis/vt0_abs_trans_var': 0.003357027409646978,
#  'analysis/vt1_abs_sus': 0.042694010520818435,
#  'analysis/vt1_abs_sus_var': 4.2457335123737006e-05,
#  'analysis/vt1_abs_trans': 0.0032894446430296225,
#  'analysis/vt1_abs_trans_var': 0.01218663741643892,
#  'analysis/vt2_abs_sus': 0.007735775350534975,
#  'analysis/vt2_abs_sus_var': 7.538345775703718e-05,
#  'analysis/vt2_abs_trans': 0.00021852094262575018,
#  'analysis/vt2_abs_trans_var': 0.0013444217125839534,
#  'analysis/vt3_abs_sus': nan,
#  'analysis/vt3_abs_sus_var': nan,
#  'analysis/vt3_abs_trans': nan,
#  'analysis/vt3_abs_trans_var': nan,
#  'analysis/vt4_abs_sus': nan,
#  'analysis/vt4_abs_sus_var': nan,
#  'analysis/vt4_abs_trans': nan,
#  'analysis/vt4_abs_trans_var': nan,
#  'analysis/vt4_trans_rate_pct25': nan,
#  'analysis/vt4_trans_rate_pct50': nan,
#  'analysis/vt4_trans_rate_pct75': nan,
#  'analysis/fb0_abs_sus': 0.0,
#  'analysis/fb0_abs_sus_var': 0.0,
#  'analysis/fb0_abs_trans': 0.0,
#  'analysis/fb0_abs_trans_var': 0.0,
#  'analysis/fb1_abs_sus': 941.1803524215519,
#  'analysis/fb1_abs_sus_var': 1.7419481495074933,
#  'analysis/fb1_abs_trans': 979.8231251278925,
#  'analysis/fb1_abs_trans_var': 44.60158108435269,
#  'analysis/fb2_abs_sus': 1882.5482222336582,
#  'analysis/fb2_abs_sus_var': 4.143129286128897,
#  'analysis/fb2_abs_trans': 1928.4255497020522,
#  'analysis/fb2_abs_trans_var': 231.3474044452205,
#  'analysis/fb3_abs_sus': nan,
#  'analysis/fb3_abs_sus_var': nan,
#  'analysis/fb3_abs_trans': nan,
#  'analysis/fb3_abs_trans_var': nan,
#  'analysis/fb4_abs_sus': nan,
#  'analysis/fb4_abs_sus_var': nan,
#  'analysis/fb4_abs_trans': nan,
#  'analysis/fb4_abs_trans_var': nan,
#  'analysis/fvt0_abs_sus': 0.0,
#  'analysis/fvt0_abs_sus_var': 0.0,
#  'analysis/fvt0_abs_trans': 0.0,
#  'analysis/fvt0_abs_trans_var': 0.0,
#  'analysis/fvt1_abs_sus': 941.1853781389478,
#  'analysis/fvt1_abs_sus_var': 1.7515083421307054,
#  'analysis/fvt1_abs_trans': 979.2879899243441,
#  'analysis/fvt1_abs_trans_var': 51.96081521617771,
#  'analysis/fvt2_abs_sus': 1882.5925398159889,
#  'analysis/fvt2_abs_sus_var': 4.173551772279552,
#  'analysis/fvt2_abs_trans': 1934.2391987808985,
#  'analysis/fvt2_abs_trans_var': 117.6990597819256,
#  'analysis/fvt3_abs_sus': nan,
#  'analysis/fvt3_abs_sus_var': nan,
#  'analysis/fvt3_abs_trans': nan,
#  'analysis/fvt3_abs_trans_var': nan,
#  'analysis/fvt4_abs_sus': nan,
#  'analysis/fvt4_abs_sus_var': nan,
#  'analysis/fvt4_abs_trans': nan,
#  'analysis/fvt4_abs_trans_var': nan,
#  'analysis/hrat0_abs_sus': -0.9127646839881507,
#  'analysis/hrat0_abs_sus_var': 0.06897480876578754,
#  'analysis/hrat0_abs_trans': -0.9711596542959313,
#  'analysis/hrat0_abs_trans_var': 2.2275878480553573,
#  'analysis/hrat0_abs_fin': -0.8445241095701803,
#  'analysis/hrat0_abs_pert': -0.7058085401465082,
#  'analysis/hrat1_abs_sus': -8.151098334440894,
#  'analysis/hrat1_abs_sus_var': 0.033968010104601376,
#  'analysis/hrat1_abs_trans': -7.065084625383953,
#  'analysis/hrat1_abs_trans_var': 1.9478909321669562,
#  'analysis/hrat1_abs_fin': -8.18153069663395,
#  'analysis/hrat1_abs_pert': -14.428794976214318,
#  'analysis/hrat2_abs_sus': -4.003924903377538,
#  'analysis/hrat2_abs_sus_var': 0.0033076386454560236,
#  'analysis/hrat2_abs_trans': -3.92311525649221,
#  'analysis/hrat2_abs_trans_var': 2.807320042116558,
#  'analysis/hrat2_abs_fin': -4.007384940787482,
#  'analysis/hrat2_abs_pert': 7.711186084835495,
#  'analysis/hrat3_abs_sus': nan,
#  'analysis/hrat3_abs_sus_var': nan,
#  'analysis/hrat3_abs_trans': nan,
#  'analysis/hrat3_abs_trans_var': nan,
#  'analysis/hrat3_abs_fin': nan,
#  'analysis/hrat3_abs_pert': nan,
#  'analysis/hrat4_abs_sus': nan,
#  'analysis/hrat4_abs_sus_var': nan,
#  'analysis/hrat4_abs_trans': nan,
#  'analysis/hrat4_abs_trans_var': nan,
#  'analysis/hrat4_abs_fin': nan,
#  'analysis/hrat4_abs_pert': nan,
#  'analysis/b0_rate': 202.31322247886814,
#  'analysis/b0_jump': 0.1823245241836986,
#  'analysis/b0_t_before_jump': 0.1338251042619569,
#  'analysis/b1_rate': 4184.422396225787,
#  'analysis/b1_jump': 34.54218060039233,
#  'analysis/b1_t_before_jump': 0.11421345371985187,
#  'analysis/b2_rate': 3807.2157152941636,
#  'analysis/b2_jump': 43.04074909039676,
#  'analysis/b2_t_before_jump': 0.11904625054967939,
#  'analysis/b3_rate': nan,
#  'analysis/b3_jump': nan,
#  'analysis/b3_t_before_jump': nan,
#  'analysis/b4_rate': nan,
#  'analysis/b4_jump': nan,
#  'analysis/b4_t_before_jump': nan,
#  'analysis/vt0_rate': nan,
#  'analysis/vt0_jump': nan,
#  'analysis/vt0_t_before_jump': nan,
#  'analysis/vt1_rate': 4240.935597490215,
#  'analysis/vt1_jump': 16.18096142215073,
#  'analysis/vt1_t_before_jump': 0.11986426828283128,
#  'analysis/vt2_rate': 3817.5974163916867,
#  'analysis/vt2_jump': 30.53262873790979,
#  'analysis/vt2_t_before_jump': 0.12237025911613787,
#  'analysis/vt3_rate': nan,
#  'analysis/vt3_jump': nan,
#  'analysis/vt3_t_before_jump': nan,
#  'analysis/vt4_rate': nan,
#  'analysis/vt4_jump': nan,
#  'analysis/vt4_t_before_jump': nan,
#  'analysis/f_n1': 470.064973889271,
#  'analysis/bn1_t_min': 0.07133374321253746,
#  'analysis/bn1_t_max': 0.12784188884233164,
#  'analysis/bn1_abs_min': 3.643742151810262e-10,
#  'analysis/bn1_abs_max': 0.08612664159356523,
#  'analysis/bn1_abs_fin': 0.08262587489229054,
#  'analysis/bn1_abs_pert': 0.008868312208760614,
#  'analysis/f_5': nan,
#  'analysis/b5_t_min': nan,
#  'analysis/b5_t_max': nan,
#  'analysis/b5_abs_min': nan,
#  'analysis/b5_abs_max': nan,
#  'analysis/b5_abs_fin': nan,
#  'analysis/b5_abs_pert': nan,
#  'analysis/f_6': nan,
#  'analysis/b6_t_min': nan,
#  'analysis/b6_t_max': nan,
#  'analysis/b6_abs_min': nan,
#  'analysis/b6_abs_max': nan,
#  'analysis/b6_abs_fin': nan,
#  'analysis/b6_abs_pert': nan,
#  'analysis/vtn1_t_min': 0.0660153295062039,
#  'analysis/vtn1_t_max': 0.13548710854518614,
#  'analysis/vtn1_abs_min': 1.0035560447122465e-09,
#  'analysis/vtn1_abs_max': 0.5931655837193609,
#  'analysis/vtn1_abs_fin': 0.524627511024802,
#  'analysis/vtn1_abs_pert': 0.022882101535395646,
#  'analysis/vt5_t_min': nan,
#  'analysis/vt5_t_max': nan,
#  'analysis/vt5_abs_min': nan,
#  'analysis/vt5_abs_max': nan,
#  'analysis/vt5_abs_fin': nan,
#  'analysis/vt5_abs_pert': nan,
#  'analysis/vt6_t_min': nan,
#  'analysis/vt6_t_max': nan,
#  'analysis/vt6_abs_min': nan,
#  'analysis/vt6_abs_max': nan,
#  'analysis/vt6_abs_fin': nan,
#  'analysis/vt6_abs_pert': nan,
#  'analysis/bn1_abs_sus': 0.08249996769385026,
#  'analysis/bn1_abs_sus_var': 0.00017417354679837016,
#  'analysis/bn1_abs_trans': 0.0651263038383749,
#  'analysis/bn1_abs_trans_var': 0.05884495535837883,
#  'analysis/b5_abs_sus': nan,
#  'analysis/b5_abs_sus_var': nan,
#  'analysis/b5_abs_trans': nan,
#  'analysis/b5_abs_trans_var': nan,
#  'analysis/b6_abs_sus': nan,
#  'analysis/b6_abs_sus_var': nan,
#  'analysis/b6_abs_trans': nan,
#  'analysis/b6_abs_trans_var': nan,
#  'analysis/b6_trans_rate_pct25': nan,
#  'analysis/b6_trans_rate_pct50': nan,
#  'analysis/b6_trans_rate_pct75': nan,
#  'analysis/vtn1_abs_sus': 0.5337836186140499,
#  'analysis/vtn1_abs_sus_var': 0.009126279446337593,
#  'analysis/vtn1_abs_trans': 0.18306137186803456,
#  'analysis/vtn1_abs_trans_var': 0.3483480501284066,
#  'analysis/vt5_abs_sus': nan,
#  'analysis/vt5_abs_sus_var': nan,
#  'analysis/vt5_abs_trans': nan,
#  'analysis/vt5_abs_trans_var': nan,
#  'analysis/vt6_abs_sus': nan,
#  'analysis/vt6_abs_sus_var': nan,
#  'analysis/vt6_abs_trans': nan,
#  'analysis/vt6_abs_trans_var': nan,
#  'analysis/vt6_trans_rate_pct25': nan,
#  'analysis/vt6_trans_rate_pct50': nan,
#  'analysis/vt6_trans_rate_pct75': nan,
#  'analysis/fbn1_abs_sus': 470.5374986798916,
#  'analysis/fbn1_abs_sus_var': 0.8312554667719496,
#  'analysis/fbn1_abs_trans': 497.23161198497615,
#  'analysis/fbn1_abs_trans_var': 21.019116208028493,
#  'analysis/fb5_abs_sus': nan,
#  'analysis/fb5_abs_sus_var': nan,
#  'analysis/fb5_abs_trans': nan,
#  'analysis/fb5_abs_trans_var': nan,
#  'analysis/fb6_abs_sus': nan,
#  'analysis/fb6_abs_sus_var': nan,
#  'analysis/fb6_abs_trans': nan,
#  'analysis/fb6_abs_trans_var': nan,
#  'analysis/fvtn1_abs_sus': 470.60082858202,
#  'analysis/fvtn1_abs_sus_var': 0.8808272336434584,
#  'analysis/fvtn1_abs_trans': 495.83382894859983,
#  'analysis/fvtn1_abs_trans_var': 7.224974486870224,
#  'analysis/fvt5_abs_sus': nan,
#  'analysis/fvt5_abs_sus_var': nan,
#  'analysis/fvt5_abs_trans': nan,
#  'analysis/fvt5_abs_trans_var': nan,
#  'analysis/fvt6_abs_sus': nan,
#  'analysis/fvt6_abs_sus_var': nan,
#  'analysis/fvt6_abs_trans': nan,
#  'analysis/fvt6_abs_trans_var': nan,
#  'analysis/hratn1_abs_sus': 16.216998159332626,
#  'analysis/hratn1_abs_sus_var': 0.16653291286190353,
#  'analysis/hratn1_abs_trans': 9.093097751330369,
#  'analysis/hratn1_abs_trans_var': 5.514727320444246,
#  'analysis/hratn1_abs_fin': 16.054699795999614,
#  'analysis/hratn1_abs_pert': 8.23269075164417,
#  'analysis/hrat5_abs_sus': nan,
#  'analysis/hrat5_abs_sus_var': nan,
#  'analysis/hrat5_abs_trans': nan,
#  'analysis/hrat5_abs_trans_var': nan,
#  'analysis/hrat5_abs_fin': nan,
#  'analysis/hrat5_abs_pert': nan,
#  'analysis/hrat6_abs_sus': nan,
#  'analysis/hrat6_abs_sus_var': nan,
#  'analysis/hrat6_abs_trans': nan,
#  'analysis/hrat6_abs_trans_var': nan,
#  'analysis/hrat6_abs_fin': nan,
#  'analysis/hrat6_abs_pert': nan,
#  'analysis/bn1_rate': 3388.7765370294987,
#  'analysis/bn1_jump': 0.0757277565444312,
#  'analysis/bn1_t_before_jump': 0.12385307856258146,
#  'analysis/b5_rate': nan,
#  'analysis/b5_jump': nan,
#  'analysis/b5_t_before_jump': nan,
#  'analysis/b6_rate': nan,
#  'analysis/vtn1_rate': 3316.615186403682,
#  'analysis/vtn1_jump': 1.1822621312040162,
#  'analysis/vtn1_t_before_jump': 0.1268446862723941,
#  'analysis/vt5_rate': nan,
#  'analysis/vt5_jump': nan,
#  'analysis/vt5_t_before_jump': nan,
#  'analysis/vt6_rate': nan,
#  'analysis/b6_jump': nan,
#  'analysis/b6_t_before_jump': nan,
#  'analysis/vt6_jump': nan,
#  'analysis/vt6_t_before_jump': nan,
#  'analysis/f_n2': 1410.194921667813,
#  'analysis/bn2_t_min': 0.04075286440111944,
#  'analysis/bn2_t_max': 0.49414763286605623,
#  'analysis/bn2_abs_min': 1.2301523629517922e-10,
#  'analysis/bn2_abs_max': 0.017712499684570133,
#  'analysis/bn2_abs_fin': 0.017706679378053352,
#  'analysis/bn2_abs_pert': 5.827496203107459e-06,
#  'analysis/vtn2_t_min': 0.04075286440111944,
#  'analysis/vtn2_t_max': 0.49414763286605623,
#  'analysis/vtn2_abs_min': 5.668669026483445e-11,
#  'analysis/vtn2_abs_max': 0.010253946281972296,
#  'analysis/vtn2_abs_fin': 0.010241891660270702,
#  'analysis/vtn2_abs_pert': 8.335416152159076e-06,
#  'analysis/bn2_abs_sus': 0.017423561812235158,
#  'analysis/bn2_abs_sus_var': 0.00029158666415069964,
#  'analysis/bn2_abs_trans': 0.0015246523876597717,
#  'analysis/bn2_abs_trans_var': 0.005888366308450737,
#  'analysis/b2_trans_rate_pct25': 2507.6724348424855,
#  'analysis/b2_trans_rate_pct50': 3555.4152325313926,
#  'analysis/b2_trans_rate_pct75': 11258.128140977331,
#  'analysis/vtn2_abs_sus': 0.010094912618709779,
#  'analysis/vtn2_abs_sus_var': 0.00015996635363437102,
#  'analysis/vtn2_abs_trans': 0.0008975907090311764,
#  'analysis/vtn2_abs_trans_var': 0.0034423886086535948,
#  'analysis/vt2_trans_rate_pct25': 2772.953438700755,
#  'analysis/vt2_trans_rate_pct50': 3611.858857197388,
#  'analysis/vt2_trans_rate_pct75': 6834.616672369419,
#  'analysis/fbn2_abs_sus': 1411.9012651217965,
#  'analysis/fbn2_abs_sus_var': 2.588552291167389,
#  'analysis/fbn2_abs_trans': 1433.4811317188003,
#  'analysis/fbn2_abs_trans_var': 285.9738409551212,
#  'analysis/fvtn2_abs_sus': 1411.88994806016,
#  'analysis/fvtn2_abs_sus_var': 2.599428055246335,
#  'analysis/fvtn2_abs_trans': 1441.7457653458096,
#  'analysis/fvtn2_abs_trans_var': 328.62067645476327,
#  'analysis/hratn2_abs_sus': -4.741159236602446,
#  'analysis/hratn2_abs_sus_var': 0.007023477542615453,
#  'analysis/hratn2_abs_trans': -4.54695435924863,
#  'analysis/hratn2_abs_trans_var': 0.5370162743410063,
#  'analysis/hratn2_abs_fin': -4.755138918025999,
#  'analysis/hratn2_abs_pert': 3.274679254687655,
#  'analysis/bn2_rate': 3547.6032972402522,
#  'analysis/bn2_jump': 38.25333870940557,
#  'analysis/bn2_t_before_jump': 0.11554305714643526,
#  'analysis/vtn2_rate': 3699.580322583837,
#  'analysis/vtn2_jump': 27.878600568874646,
#  'analysis/vtn2_t_before_jump': 0.12119387170941467,
#  'analysis/f_7': nan,
#  'analysis/b7_t_min': nan,
#  'analysis/b7_t_max': nan,
#  'analysis/b7_abs_min': nan,
#  'analysis/b7_abs_max': nan,
#  'analysis/b7_abs_fin': nan,
#  'analysis/b7_abs_pert': nan,
#  'analysis/vt7_t_min': nan,
#  'analysis/vt7_t_max': nan,
#  'analysis/vt7_abs_min': nan,
#  'analysis/vt7_abs_max': nan,
#  'analysis/vt7_abs_fin': nan,
#  'analysis/vt7_abs_pert': nan,
#  'analysis/b7_abs_sus': nan,
#  'analysis/b7_abs_sus_var': nan,
#  'analysis/b7_abs_trans': nan,
#  'analysis/b7_abs_trans_var': nan,
#  'analysis/b7_trans_rate_pct25': nan,
#  'analysis/b7_trans_rate_pct50': nan,
#  'analysis/b7_trans_rate_pct75': nan,
#  'analysis/vt7_abs_sus': nan,
#  'analysis/vt7_abs_sus_var': nan,
#  'analysis/vt7_abs_trans': nan,
#  'analysis/vt7_abs_trans_var': nan,
#  'analysis/vt7_trans_rate_pct25': nan,
#  'analysis/vt7_trans_rate_pct50': nan,
#  'analysis/vt7_trans_rate_pct75': nan,
#  'analysis/fb7_abs_sus': nan,
#  'analysis/fb7_abs_sus_var': nan,
#  'analysis/fb7_abs_trans': nan,
#  'analysis/fb7_abs_trans_var': nan,
#  'analysis/fvt7_abs_sus': nan,
#  'analysis/fvt7_abs_sus_var': nan,
#  'analysis/fvt7_abs_trans': nan,
#  'analysis/fvt7_abs_trans_var': nan,
#  'analysis/hrat7_abs_sus': nan,
#  'analysis/hrat7_abs_sus_var': nan,
#  'analysis/hrat7_abs_trans': nan,
#  'analysis/hrat7_abs_trans_var': nan,
#  'analysis/hrat7_abs_fin': nan,
#  'analysis/hrat7_abs_pert': nan,
#  'analysis/b7_rate': nan,
#  'analysis/b7_jump': nan,
#  'analysis/b7_t_before_jump': nan,
#  'analysis/vt7_rate': nan,
#  'analysis/vt7_jump': nan,
#  'analysis/vt7_t_before_jump': nan,
#  'analysis/b5_trans_rate_pct25': nan,
#  'analysis/b5_trans_rate_pct50': nan,
#  'analysis/b5_trans_rate_pct75': nan,
#  'analysis/vt5_trans_rate_pct25': nan,
#  'analysis/vt5_trans_rate_pct50': nan,
#  'analysis/vt5_trans_rate_pct75': nan,
#  'analysis/bn1_trans_rate_pct25': nan,
#  'analysis/bn1_trans_rate_pct50': nan,
#  'analysis/bn1_trans_rate_pct75': nan,
#  'analysis/vtn1_trans_rate_pct25': nan,
#  'analysis/vtn1_trans_rate_pct50': nan,
#  'analysis/vtn1_trans_rate_pct75': nan,
#  'analysis/bn2_trans_rate_pct25': nan,
#  'analysis/bn2_trans_rate_pct50': nan,
#  'analysis/bn2_trans_rate_pct75': nan,
#  'analysis/vtn2_trans_rate_pct25': nan,
#  'analysis/vtn2_trans_rate_pct50': nan,
#  'analysis/vtn2_trans_rate_pct75': nan,
#  'analysis/f_n3': nan,
#  'analysis/bn3_t_min': nan,
#  'analysis/bn3_t_max': nan,
#  'analysis/bn3_abs_min': nan,
#  'analysis/bn3_abs_max': nan,
#  'analysis/bn3_abs_fin': nan,
#  'analysis/bn3_abs_pert': nan,
#  'analysis/vtn3_t_min': nan,
#  'analysis/vtn3_t_max': nan,
#  'analysis/vtn3_abs_min': nan,
#  'analysis/vtn3_abs_max': nan,
#  'analysis/vtn3_abs_fin': nan,
#  'analysis/vtn3_abs_pert': nan,
#  'analysis/bn3_abs_sus': nan,
#  'analysis/bn3_abs_sus_var': nan,
#  'analysis/bn3_abs_trans': nan,
#  'analysis/bn3_abs_trans_var': nan,
#  'analysis/bn3_trans_rate_pct25': nan,
#  'analysis/bn3_trans_rate_pct50': nan,
#  'analysis/bn3_trans_rate_pct75': nan,
#  'analysis/vtn3_abs_sus': nan,
#  'analysis/vtn3_abs_sus_var': nan,
#  'analysis/vtn3_abs_trans': nan,
#  'analysis/vtn3_abs_trans_var': nan,
#  'analysis/vtn3_trans_rate_pct25': nan,
#  'analysis/vtn3_trans_rate_pct50': nan,
#  'analysis/vtn3_trans_rate_pct75': nan,
#  'analysis/fbn3_abs_sus': nan,
#  'analysis/fbn3_abs_sus_var': nan,
#  'analysis/fbn3_abs_trans': nan,
#  'analysis/fbn3_abs_trans_var': nan,
#  'analysis/fvtn3_abs_sus': nan,
#  'analysis/fvtn3_abs_sus_var': nan,
#  'analysis/fvtn3_abs_trans': nan,
#  'analysis/fvtn3_abs_trans_var': nan,
#  'analysis/hratn3_abs_sus': nan,
#  'analysis/hratn3_abs_sus_var': nan,
#  'analysis/hratn3_abs_trans': nan,
#  'analysis/hratn3_abs_trans_var': nan,
#  'analysis/hratn3_abs_fin': nan,
#  'analysis/hratn3_abs_pert': nan,
#  'analysis/bn3_rate': nan,
#  'analysis/bn3_jump': nan,
#  'analysis/bn3_t_before_jump': nan,
#  'analysis/vtn3_rate': nan,
#  'analysis/vtn3_jump': nan,
#  'analysis/vtn3_t_before_jump': nan,
#  'analysis/f_n4': nan,
#  'analysis/bn4_t_min': nan,
#  'analysis/bn4_t_max': nan,
#  'analysis/bn4_abs_min': nan,
#  'analysis/bn4_abs_max': nan,
#  'analysis/bn4_abs_fin': nan,
#  'analysis/bn4_abs_pert': nan,
#  'analysis/vtn4_t_min': nan,
#  'analysis/vtn4_t_max': nan,
#  'analysis/vtn4_abs_min': nan,
#  'analysis/vtn4_abs_max': nan,
#  'analysis/vtn4_abs_fin': nan,
#  'analysis/vtn4_abs_pert': nan,
#  'analysis/bn4_abs_sus': nan,
#  'analysis/bn4_abs_sus_var': nan,
#  'analysis/bn4_abs_trans': nan,
#  'analysis/bn4_abs_trans_var': nan,
#  'analysis/bn4_trans_rate_pct25': nan,
#  'analysis/bn4_trans_rate_pct50': nan,
#  'analysis/bn4_trans_rate_pct75': nan,
#  'analysis/vtn4_abs_sus': nan,
#  'analysis/vtn4_abs_sus_var': nan,
#  'analysis/vtn4_abs_trans': nan,
#  'analysis/vtn4_abs_trans_var': nan,
#  'analysis/vtn4_trans_rate_pct25': nan,
#  'analysis/vtn4_trans_rate_pct50': nan,
#  'analysis/vtn4_trans_rate_pct75': nan,
#  'analysis/fbn4_abs_sus': nan,
#  'analysis/fbn4_abs_sus_var': nan,
#  'analysis/fbn4_abs_trans': nan,
#  'analysis/fbn4_abs_trans_var': nan,
#  'analysis/fvtn4_abs_sus': nan,
#  'analysis/fvtn4_abs_sus_var': nan,
#  'analysis/fvtn4_abs_trans': nan,
#  'analysis/fvtn4_abs_trans_var': nan,
#  'analysis/hratn4_abs_sus': nan,
#  'analysis/hratn4_abs_sus_var': nan,
#  'analysis/hratn4_abs_trans': nan,
#  'analysis/hratn4_abs_trans_var': nan,
#  'analysis/hratn4_abs_fin': nan,
#  'analysis/hratn4_abs_pert': nan,
#  'analysis/bn4_rate': nan,
#  'analysis/bn4_jump': nan,
#  'analysis/bn4_t_before_jump': nan,
#  'analysis/vtn4_rate': nan,
#  'analysis/vtn4_jump': nan,
#  'analysis/vtn4_t_before_jump': nan,
#  'analysis/f_8': nan,
#  'analysis/b8_t_min': nan,
#  'analysis/b8_t_max': nan,
#  'analysis/b8_abs_min': nan,
#  'analysis/b8_abs_max': nan,
#  'analysis/b8_abs_fin': nan,
#  'analysis/b8_abs_pert': nan,
#  'analysis/vt8_t_min': nan,
#  'analysis/vt8_t_max': nan,
#  'analysis/vt8_abs_min': nan,
#  'analysis/vt8_abs_max': nan,
#  'analysis/vt8_abs_fin': nan,
#  'analysis/vt8_abs_pert': nan,
#  'analysis/b8_abs_sus': nan,
#  'analysis/b8_abs_sus_var': nan,
#  'analysis/b8_abs_trans': nan,
#  'analysis/b8_abs_trans_var': nan,
#  'analysis/b8_trans_rate_pct25': nan,
#  'analysis/b8_trans_rate_pct50': nan,
#  'analysis/b8_trans_rate_pct75': nan,
#  'analysis/vt8_abs_sus': nan,
#  'analysis/vt8_abs_sus_var': nan,
#  'analysis/vt8_abs_trans': nan,
#  'analysis/vt8_abs_trans_var': nan,
#  'analysis/vt8_trans_rate_pct25': nan,
#  'analysis/vt8_trans_rate_pct50': nan,
#  'analysis/vt8_trans_rate_pct75': nan,
#  'analysis/fb8_abs_sus': nan,
#  'analysis/fb8_abs_sus_var': nan,
#  'analysis/fb8_abs_trans': nan,
#  'analysis/fb8_abs_trans_var': nan,
#  'analysis/fvt8_abs_sus': nan,
#  'analysis/fvt8_abs_sus_var': nan,
#  'analysis/fvt8_abs_trans': nan,
#  'analysis/fvt8_abs_trans_var': nan,
#  'analysis/hrat8_abs_sus': nan,
#  'analysis/hrat8_abs_sus_var': nan,
#  'analysis/hrat8_abs_trans': nan,
#  'analysis/hrat8_abs_trans_var': nan,
#  'analysis/hrat8_abs_fin': nan,
#  'analysis/hrat8_abs_pert': nan,
#  'analysis/b8_rate': nan,
#  'analysis/b8_jump': nan,
#  'analysis/b8_t_before_jump': nan,
#  'analysis/vt8_rate': nan,
#  'analysis/vt8_jump': nan,
#  'analysis/vt8_t_before_jump': nan,
#  'analysis/f_n5': nan,
#  'analysis/bn5_t_min': nan,
#  'analysis/bn5_t_max': nan,
#  'analysis/bn5_abs_min': nan,
#  'analysis/bn5_abs_max': nan,
#  'analysis/bn5_abs_fin': nan,
#  'analysis/bn5_abs_pert': nan,
#  'analysis/f_n6': nan,
#  'analysis/bn6_t_min': nan,
#  'analysis/bn6_t_max': nan,
#  'analysis/bn6_abs_min': nan,
#  'analysis/bn6_abs_max': nan,
#  'analysis/bn6_abs_fin': nan,
#  'analysis/bn6_abs_pert': nan,
#  'analysis/f_n7': nan,
#  'analysis/bn7_t_min': nan,
#  'analysis/bn7_t_max': nan,
#  'analysis/bn7_abs_min': nan,
#  'analysis/bn7_abs_max': nan,
#  'analysis/bn7_abs_fin': nan,
#  'analysis/bn7_abs_pert': nan,
#  'analysis/f_n8': nan,
#  'analysis/bn8_t_min': nan,
#  'analysis/bn8_t_max': nan,
#  'analysis/bn8_abs_min': nan,
#  'analysis/bn8_abs_max': nan,
#  'analysis/bn8_abs_fin': nan,
#  'analysis/bn8_abs_pert': nan,
#  'analysis/f_n9': nan,
#  'analysis/bn9_t_min': nan,
#  'analysis/bn9_t_max': nan,
#  'analysis/bn9_abs_min': nan,
#  'analysis/bn9_abs_max': nan,
#  'analysis/bn9_abs_fin': nan,
#  'analysis/bn9_abs_pert': nan,
#  'analysis/f_n10': nan,
#  'analysis/bn10_t_min': nan,
#  'analysis/bn10_t_max': nan,
#  'analysis/bn10_abs_min': nan,
#  'analysis/bn10_abs_max': nan,
#  'analysis/bn10_abs_fin': nan,
#  'analysis/bn10_abs_pert': nan,
#  'analysis/vtn5_t_min': nan,
#  'analysis/vtn5_t_max': nan,
#  'analysis/vtn5_abs_min': nan,
#  'analysis/vtn5_abs_max': nan,
#  'analysis/vtn5_abs_fin': nan,
#  'analysis/vtn5_abs_pert': nan,
#  'analysis/vtn6_t_min': nan,
#  'analysis/vtn6_t_max': nan,
#  'analysis/vtn6_abs_min': nan,
#  'analysis/vtn6_abs_max': nan,
#  'analysis/vtn6_abs_fin': nan,
#  'analysis/vtn6_abs_pert': nan,
#  'analysis/vtn7_t_min': nan,
#  'analysis/vtn7_t_max': nan,
#  'analysis/vtn7_abs_min': nan,
#  'analysis/vtn7_abs_max': nan,
#  'analysis/vtn7_abs_fin': nan,
#  'analysis/vtn7_abs_pert': nan,
#  'analysis/vtn8_t_min': nan,
#  'analysis/vtn8_t_max': nan,
#  'analysis/vtn8_abs_min': nan,
#  'analysis/vtn8_abs_max': nan,
#  'analysis/vtn8_abs_fin': nan,
#  'analysis/vtn8_abs_pert': nan,
#  'analysis/vtn9_t_min': nan,
#  'analysis/vtn9_t_max': nan,
#  'analysis/vtn9_abs_min': nan,
#  'analysis/vtn9_abs_max': nan,
#  'analysis/vtn9_abs_fin': nan,
#  'analysis/vtn9_abs_pert': nan,
#  'analysis/vtn10_t_min': nan,
#  'analysis/vtn10_t_max': nan,
#  'analysis/vtn10_abs_min': nan,
#  'analysis/vtn10_abs_max': nan,
#  'analysis/vtn10_abs_fin': nan,
#  'analysis/vtn10_abs_pert': nan,
#  'analysis/bn5_abs_sus': nan,
#  'analysis/bn5_abs_sus_var': nan,
#  'analysis/bn5_abs_trans': nan,
#  'analysis/bn5_abs_trans_var': nan,
#  'analysis/bn6_abs_sus': nan,
#  'analysis/bn6_abs_sus_var': nan,
#  'analysis/bn6_abs_trans': nan,
#  'analysis/bn6_abs_trans_var': nan,
#  'analysis/bn7_abs_sus': nan,
#  'analysis/bn7_abs_sus_var': nan,
#  'analysis/bn7_abs_trans': nan,
#  'analysis/bn7_abs_trans_var': nan,
#  'analysis/bn8_abs_sus': nan,
#  'analysis/bn8_abs_sus_var': nan,
#  'analysis/bn8_abs_trans': nan,
#  'analysis/bn8_abs_trans_var': nan,
#  'analysis/bn9_abs_sus': nan,
#  'analysis/bn9_abs_sus_var': nan,
#  'analysis/bn9_abs_trans': nan,
#  'analysis/bn9_abs_trans_var': nan,
#  'analysis/bn10_abs_sus': nan,
#  'analysis/bn10_abs_sus_var': nan,
#  'analysis/bn10_abs_trans': nan,
#  'analysis/bn10_abs_trans_var': nan,
#  'analysis/bn10_trans_rate_pct25': nan,
#  'analysis/bn10_trans_rate_pct50': nan,
#  'analysis/bn10_trans_rate_pct75': nan,
#  'analysis/vtn5_abs_sus': nan,
#  'analysis/vtn5_abs_sus_var': nan,
#  'analysis/vtn5_abs_trans': nan,
#  'analysis/vtn5_abs_trans_var': nan,
#  'analysis/vtn6_abs_sus': nan,
#  'analysis/vtn6_abs_sus_var': nan,
#  'analysis/vtn6_abs_trans': nan,
#  'analysis/vtn6_abs_trans_var': nan,
#  'analysis/vtn7_abs_sus': nan,
#  'analysis/vtn7_abs_sus_var': nan,
#  'analysis/vtn7_abs_trans': nan,
#  'analysis/vtn7_abs_trans_var': nan,
#  'analysis/vtn8_abs_sus': nan,
#  'analysis/vtn8_abs_sus_var': nan,
#  'analysis/vtn8_abs_trans': nan,
#  'analysis/vtn8_abs_trans_var': nan,
#  'analysis/vtn9_abs_sus': nan,
#  'analysis/vtn9_abs_sus_var': nan,
#  'analysis/vtn9_abs_trans': nan,
#  'analysis/vtn9_abs_trans_var': nan,
#  'analysis/vtn10_abs_sus': nan,
#  'analysis/vtn10_abs_sus_var': nan,
#  'analysis/vtn10_abs_trans': nan,
#  'analysis/vtn10_abs_trans_var': nan,
#  'analysis/vtn10_trans_rate_pct25': nan,
#  'analysis/vtn10_trans_rate_pct50': nan,
#  'analysis/vtn10_trans_rate_pct75': nan,
#  'analysis/fbn5_abs_sus': nan,
#  'analysis/fbn5_abs_sus_var': nan,
#  'analysis/fbn5_abs_trans': nan,
#  'analysis/fbn5_abs_trans_var': nan,
#  'analysis/fbn6_abs_sus': nan,
#  'analysis/fbn6_abs_sus_var': nan,
#  'analysis/fbn6_abs_trans': nan,
#  'analysis/fbn6_abs_trans_var': nan,
#  'analysis/fbn7_abs_sus': nan,
#  'analysis/fbn7_abs_sus_var': nan,
#  'analysis/fbn7_abs_trans': nan,
#  'analysis/fbn7_abs_trans_var': nan,
#  'analysis/fbn8_abs_sus': nan,
#  'analysis/fbn8_abs_sus_var': nan,
#  'analysis/fbn8_abs_trans': nan,
#  'analysis/fbn8_abs_trans_var': nan,
#  'analysis/fbn9_abs_sus': nan,
#  'analysis/fbn9_abs_sus_var': nan,
#  'analysis/fbn9_abs_trans': nan,
#  'analysis/fbn9_abs_trans_var': nan,
#  'analysis/fbn10_abs_sus': nan,
#  'analysis/fbn10_abs_sus_var': nan,
#  'analysis/fbn10_abs_trans': nan,
#  'analysis/fbn10_abs_trans_var': nan,
#  'analysis/fvtn5_abs_sus': nan,
#  'analysis/fvtn5_abs_sus_var': nan,
#  'analysis/fvtn5_abs_trans': nan,
#  'analysis/fvtn5_abs_trans_var': nan,
#  'analysis/fvtn6_abs_sus': nan,
#  'analysis/fvtn6_abs_sus_var': nan,
#  'analysis/fvtn6_abs_trans': nan,
#  'analysis/fvtn6_abs_trans_var': nan,
#  'analysis/fvtn7_abs_sus': nan,
#  'analysis/fvtn7_abs_sus_var': nan,
#  'analysis/fvtn7_abs_trans': nan,
#  'analysis/fvtn7_abs_trans_var': nan,
#  'analysis/fvtn8_abs_sus': nan,
#  'analysis/fvtn8_abs_sus_var': nan,
#  'analysis/fvtn8_abs_trans': nan,
#  'analysis/fvtn8_abs_trans_var': nan,
#  'analysis/fvtn9_abs_sus': nan,
#  'analysis/fvtn9_abs_sus_var': nan,
#  'analysis/fvtn9_abs_trans': nan,
#  'analysis/fvtn9_abs_trans_var': nan,
#  'analysis/fvtn10_abs_sus': nan,
#  'analysis/fvtn10_abs_sus_var': nan,
#  'analysis/fvtn10_abs_trans': nan,
#  'analysis/fvtn10_abs_trans_var': nan,
#  'analysis/hratn5_abs_sus': nan,
#  'analysis/hratn5_abs_sus_var': nan,
#  'analysis/hratn5_abs_trans': nan,
#  'analysis/hratn5_abs_trans_var': nan,
#  'analysis/hratn5_abs_fin': nan,
#  'analysis/hratn5_abs_pert': nan,
#  'analysis/hratn6_abs_sus': nan,
#  'analysis/hratn6_abs_sus_var': nan,
#  'analysis/hratn6_abs_trans': nan,
#  'analysis/hratn6_abs_trans_var': nan,
#  'analysis/hratn6_abs_fin': nan,
#  'analysis/hratn6_abs_pert': nan,
#  'analysis/hratn7_abs_sus': nan,
#  'analysis/hratn7_abs_sus_var': nan,
#  'analysis/hratn7_abs_trans': nan,
#  'analysis/hratn7_abs_trans_var': nan,
#  'analysis/hratn7_abs_fin': nan,
#  'analysis/hratn7_abs_pert': nan,
#  'analysis/hratn8_abs_sus': nan,
#  'analysis/hratn8_abs_sus_var': nan,
#  'analysis/hratn8_abs_trans': nan,
#  'analysis/hratn8_abs_trans_var': nan,
#  'analysis/hratn8_abs_fin': nan,
#  'analysis/hratn8_abs_pert': nan,
#  'analysis/hratn9_abs_sus': nan,
#  'analysis/hratn9_abs_sus_var': nan,
#  'analysis/hratn9_abs_trans': nan,
#  'analysis/hratn9_abs_trans_var': nan,
#  'analysis/hratn9_abs_fin': nan,
#  'analysis/hratn9_abs_pert': nan,
#  'analysis/hratn10_abs_sus': nan,
#  'analysis/hratn10_abs_sus_var': nan,
#  'analysis/hratn10_abs_trans': nan,
#  'analysis/hratn10_abs_trans_var': nan,
#  'analysis/hratn10_abs_fin': nan,
#  'analysis/hratn10_abs_pert': nan,
#  'analysis/bn5_rate': nan,
#  'analysis/bn5_jump': nan,
#  'analysis/bn5_t_before_jump': nan,
#  'analysis/bn6_rate': nan,
#  'analysis/bn6_jump': nan,
#  'analysis/bn6_t_before_jump': nan,
#  'analysis/bn7_rate': nan,
#  'analysis/bn7_jump': nan,
#  'analysis/bn7_t_before_jump': nan,
#  'analysis/bn8_rate': nan,
#  'analysis/bn8_jump': nan,
#  'analysis/bn8_t_before_jump': nan,
#  'analysis/bn9_rate': nan,
#  'analysis/bn9_jump': nan,
#  'analysis/bn9_t_before_jump': nan,
#  'analysis/bn10_rate': nan,
#  'analysis/bn10_jump': nan,
#  'analysis/bn10_t_before_jump': nan,
#  'analysis/vtn5_rate': nan,
#  'analysis/vtn5_jump': nan,
#  'analysis/vtn5_t_before_jump': nan,
#  'analysis/vtn6_rate': nan,
#  'analysis/vtn6_jump': nan,
#  'analysis/vtn6_t_before_jump': nan,
#  'analysis/vtn7_rate': nan,
#  'analysis/vtn7_jump': nan,
#  'analysis/vtn7_t_before_jump': nan,
#  'analysis/vtn8_rate': nan,
#  'analysis/vtn8_jump': nan,
#  'analysis/vtn8_t_before_jump': nan,
#  'analysis/vtn9_rate': nan,
#  'analysis/vtn9_jump': nan,
#  'analysis/vtn9_t_before_jump': nan,
#  'analysis/vtn10_rate': nan,
#  'analysis/vtn10_jump': nan,
#  'analysis/vtn10_t_before_jump': nan,
#  'analysis/bn5_trans_rate_pct25': nan,
#  'analysis/bn5_trans_rate_pct50': nan,
#  'analysis/bn5_trans_rate_pct75': nan,
#  'analysis/vtn5_trans_rate_pct25': nan,
#  'analysis/vtn5_trans_rate_pct50': nan,
#  'analysis/vtn5_trans_rate_pct75': nan,
#  'analysis/bn6_trans_rate_pct25': nan,
#  'analysis/bn6_trans_rate_pct50': nan,
#  'analysis/bn6_trans_rate_pct75': nan,
#  'analysis/vtn6_trans_rate_pct25': nan,
#  'analysis/vtn6_trans_rate_pct50': nan,
#  'analysis/vtn6_trans_rate_pct75': nan,
#  'analysis/f_11': nan,
#  'analysis/b11_t_min': nan,
#  'analysis/b11_t_max': nan,
#  'analysis/b11_abs_min': nan,
#  'analysis/b11_abs_max': nan,
#  'analysis/b11_abs_fin': nan,
#  'analysis/b11_abs_pert': nan,
#  'analysis/vt11_t_min': nan,
#  'analysis/vt11_t_max': nan,
#  'analysis/vt11_abs_min': nan,
#  'analysis/vt11_abs_max': nan,
#  'analysis/vt11_abs_fin': nan,
#  'analysis/vt11_abs_pert': nan,
#  'analysis/b11_abs_sus': nan,
#  'analysis/b11_abs_sus_var': nan,
#  'analysis/b11_abs_trans': nan,
#  'analysis/b11_abs_trans_var': nan,
#  'analysis/b11_trans_rate_pct25': nan,
#  'analysis/b11_trans_rate_pct50': nan,
#  'analysis/b11_trans_rate_pct75': nan,
#  'analysis/vt11_abs_sus': nan,
#  'analysis/vt11_abs_sus_var': nan,
#  'analysis/vt11_abs_trans': nan,
#  'analysis/vt11_abs_trans_var': nan,
#  'analysis/vt11_trans_rate_pct25': nan,
#  'analysis/vt11_trans_rate_pct50': nan,
#  'analysis/vt11_trans_rate_pct75': nan,
#  'analysis/fb11_abs_sus': nan,
#  'analysis/fb11_abs_sus_var': nan,
#  'analysis/fb11_abs_trans': nan,
#  'analysis/fb11_abs_trans_var': nan,
#  'analysis/fvt11_abs_sus': nan,
#  'analysis/fvt11_abs_sus_var': nan,
#  'analysis/fvt11_abs_trans': nan,
#  'analysis/fvt11_abs_trans_var': nan,
#  'analysis/hrat11_abs_sus': nan,
#  'analysis/hrat11_abs_sus_var': nan,
#  'analysis/hrat11_abs_trans': nan,
#  'analysis/hrat11_abs_trans_var': nan,
#  'analysis/hrat11_abs_fin': nan,
#  'analysis/hrat11_abs_pert': nan,
#  'analysis/b11_rate': nan,
#  'analysis/b11_jump': nan,
#  'analysis/b11_t_before_jump': nan,
#  'analysis/vt11_rate': nan,
#  'analysis/vt11_jump': nan,
#  'analysis/vt11_t_before_jump': nan,
#  'analysis/f_10': nan,
#  'analysis/b10_t_min': nan,
#  'analysis/b10_t_max': nan,
#  'analysis/b10_abs_min': nan,
#  'analysis/b10_abs_max': nan,
#  'analysis/b10_abs_fin': nan,
#  'analysis/b10_abs_pert': nan,
#  'analysis/vt10_t_min': nan,
#  'analysis/vt10_t_max': nan,
#  'analysis/vt10_abs_min': nan,
#  'analysis/vt10_abs_max': nan,
#  'analysis/vt10_abs_fin': nan,
#  'analysis/vt10_abs_pert': nan,
#  'analysis/b10_abs_sus': nan,
#  'analysis/b10_abs_sus_var': nan,
#  'analysis/b10_abs_trans': nan,
#  'analysis/b10_abs_trans_var': nan,
#  'analysis/b10_trans_rate_pct25': nan,
#  'analysis/b10_trans_rate_pct50': nan,
#  'analysis/b10_trans_rate_pct75': nan,
#  'analysis/vt10_abs_sus': nan,
#  'analysis/vt10_abs_sus_var': nan,
#  'analysis/vt10_abs_trans': nan,
#  'analysis/vt10_abs_trans_var': nan,
#  'analysis/vt10_trans_rate_pct25': nan,
#  'analysis/vt10_trans_rate_pct50': nan,
#  'analysis/vt10_trans_rate_pct75': nan,
#  'analysis/fb10_abs_sus': nan,
#  'analysis/fb10_abs_sus_var': nan,
#  'analysis/fb10_abs_trans': nan,
#  'analysis/fb10_abs_trans_var': nan,
#  'analysis/fvt10_abs_sus': nan,
#  'analysis/fvt10_abs_sus_var': nan,
#  'analysis/fvt10_abs_trans': nan,
#  'analysis/fvt10_abs_trans_var': nan,
#  'analysis/hrat10_abs_sus': nan,
#  'analysis/hrat10_abs_sus_var': nan,
#  'analysis/hrat10_abs_trans': nan,
#  'analysis/hrat10_abs_trans_var': nan,
#  'analysis/hrat10_abs_fin': nan,
#  'analysis/hrat10_abs_pert': nan,
#  'analysis/b10_rate': nan,
#  'analysis/b10_jump': nan,
#  'analysis/b10_t_before_jump': nan,
#  'analysis/vt10_rate': nan,
#  'analysis/vt10_jump': nan,
#  'analysis/vt10_t_before_jump': nan,
#  'analysis/f_9': nan,
#  'analysis/b9_t_min': nan,
#  'analysis/b9_t_max': nan,
#  'analysis/b9_abs_min': nan,
#  'analysis/b9_abs_max': nan,
#  'analysis/b9_abs_fin': nan,
#  'analysis/b9_abs_pert': nan,
#  'analysis/vt9_t_min': nan,
#  'analysis/vt9_t_max': nan,
#  'analysis/vt9_abs_min': nan,
#  'analysis/vt9_abs_max': nan,
#  'analysis/vt9_abs_fin': nan,
#  'analysis/vt9_abs_pert': nan,
#  'analysis/b9_abs_sus': nan,
#  'analysis/b9_abs_sus_var': nan,
#  'analysis/b9_abs_trans': nan,
#  'analysis/b9_abs_trans_var': nan,
#  ...}

# %%
ll[idx]['simulation']['params']
# Out:
# {'description': 'Reed simulation with modal tracts and reed dynamics and non-linear reed force var gamma',
#  'version': '20201026',
#  'db': 'modal-vt-bore-jumps-2',
#  'tmax': 0.5,
#  'gamma': {'sustain_val': 0.6233710773350962,
#   'time_const': 0.05,
#   'exp_limit_multiplier': 1.1},
#  'zeta': 0.5,
#  'reed': {'frequency': 3850.772266100908,
#   'q': 2.8328228051701805,
#   'amplitude': 2.8328228051701805},
#  'bore': {'frequencies': [726.1581554762913],
#   'qs': [13.492181731950268],
#   'amplitudes': [13.492181731950268]},
#  'vocal': {'frequencies': [500], 'qs': [15], 'amplitudes': [15]},
#  'nlfunc': {'type': 'parabolic', 'nl_start': 0.75, 'nl_ev': 1.1},
#  'perturbation': {'multiplier': 1.1, 'duration': 0.39816598338508535},
#  'simulation': {'sample rate': 385077.2266100908}}

# %%
df1
# Out:
#                            _id        simulation/start  \
# 2     5f96816bde90143886205ad6 2020-10-26 18:57:22.119
# 3     5f96816d38fc214bc2db578d 2020-10-26 18:57:21.972
# 4     5f96816d4ccf2f9e0281e2f6 2020-10-26 18:57:22.010
# 5     5f96817198b40108a64ec51e 2020-10-26 18:57:30.732
# 15    5f968191aa30f2a1b96201cf 2020-10-26 18:58:00.855
# ...                        ...                     ...
# 2145  5f9697a9de90143886205d28 2020-10-26 20:32:10.552
# 2146  5f9697b698b40108a64ec788 2020-10-26 20:32:22.800
# 2147  5f9697b64ccf2f9e0281e55c 2020-10-26 20:32:22.090
# 2153  5f9697c5aa30f2a1b962042b 2020-10-26 20:32:41.360
# 2156  5f9697c84ccf2f9e0281e55e 2020-10-26 20:32:38.956
#
#       simulation/params/tmax  simulation/params/gamma/sustain_val  \
# 2                        0.5                             0.547244
# 3                        0.5                             0.516500
# 4                        0.5                             0.534211
# 5                        0.5                             0.559761
# 15                       0.5                             0.438412
# ...                      ...                                  ...
# 2145                     0.5                             0.416989
# 2146                     0.5                             0.469871
# 2147                     0.5                             0.433706
# 2153                     0.5                             0.588387
# 2156                     0.5                             0.497249
#
#       simulation/params/gamma/time_const  \
# 2                                   0.05
# 3                                   0.05
# 4                                   0.05
# 5                                   0.05
# 15                                  0.05
# ...                                  ...
# 2145                                0.05
# 2146                                0.05
# 2147                                0.05
# 2153                                0.05
# 2156                                0.05
#
#       simulation/params/gamma/exp_limit_multiplier  simulation/params/zeta  \
# 2                                              1.1                     0.5
# 3                                              1.1                     0.5
# 4                                              1.1                     0.5
# 5                                              1.1                     0.5
# 15                                             1.1                     0.5
# ...                                            ...                     ...
# 2145                                           1.1                     0.5
# 2146                                           1.1                     0.5
# 2147                                           1.1                     0.5
# 2153                                           1.1                     0.5
# 2156                                           1.1                     0.5
#
#       simulation/params/reed/frequency  simulation/params/reed/q  \
# 2                           997.343877                  1.473394
# 3                          1506.802297                  4.522170
# 4                          1567.810588                  3.645420
# 5                           776.622893                  4.917501
# 15                         1363.375177                  1.500606
# ...                                ...                       ...
# 2145                       2486.109985                  4.674511
# 2146                       2359.754848                  1.711813
# 2147                       2957.621210                  4.208605
# 2153                       1723.124358                  0.576899
# 2156                       2531.034123                  0.774287
#
#       simulation/params/reed/amplitude  ...  analysis/vt3_trans_rate_pct25  \
# 2                             1.473394  ...                            NaN
# 3                             4.522170  ...                            NaN
# 4                             3.645420  ...                            NaN
# 5                             4.917501  ...                            NaN
# 15                            1.500606  ...                            NaN
# ...                                ...  ...                            ...
# 2145                          4.674511  ...                            NaN
# 2146                          1.711813  ...                            NaN
# 2147                          4.208605  ...                            NaN
# 2153                          0.576899  ...                            NaN
# 2156                          0.774287  ...                            NaN
#
#       analysis/vt3_trans_rate_pct50  analysis/vt3_trans_rate_pct75  \
# 2                               NaN                            NaN
# 3                               NaN                            NaN
# 4                               NaN                            NaN
# 5                               NaN                            NaN
# 15                              NaN                            NaN
# ...                             ...                            ...
# 2145                            NaN                            NaN
# 2146                            NaN                            NaN
# 2147                            NaN                            NaN
# 2153                            NaN                            NaN
# 2156                            NaN                            NaN
#
#       gets larger than perturbation  finishes close to max  trans dur  \
# 2                              True                   True   0.023151
# 3                              True                   True   0.043094
# 4                              True                   True   0.016470
# 5                              True                   True   0.046048
# 15                             True                   True   0.110910
# ...                             ...                    ...        ...
# 2145                           True                   True   0.063021
# 2146                           True                   True   0.168794
# 2147                           True                   True   0.227235
# 2153                           True                   True   0.037490
# 2156                           True                   True   0.034068
#
#       starts after pert    zb_max_f  zb_max_val    zrat_f0
# 2                  True  570.232768    1.877528   0.508897
# 3                  True  318.074157    5.971391   6.697684
# 4                  True  749.239235    2.386723   3.106167
# 5                  True  276.941600    5.333157   7.858359
# 15                 True  660.351405    1.347252   0.243778
# ...                 ...         ...         ...        ...
# 2145               True  529.991134    4.146139   0.577922
# 2146               True  270.588676    6.139113   9.096843
# 2147               True  333.516538   12.342120  11.045948
# 2153               True  201.994942    0.517409   0.061792
# 2156               True  636.083053    1.601712   0.232359
#
# [350 rows x 1161 columns]

# %%
dfo.loc[idx]
# Out:
# _id                                      5f96925b98b40108a64ec6f6
# simulation/start                       2020-10-26 20:09:20.661000
# simulation/params/tmax                                        0.5
# simulation/params/gamma/sustain_val                      0.623371
# simulation/params/gamma/time_const                           0.05
#                                                   ...
# analysis/vt3_trans_rate_pct75                                 NaN
# gets larger than perturbation                                True
# finishes close to max                                        True
# trans dur                                               0.0129404
# starts after pert                                            True
# Name: 1626, Length: 1158, dtype: object

# %%
ll[idx]
# Out:
# {'_id': ObjectId('5f96925b98b40108a64ec6f6'),
#  'simulation': {'start': datetime.datetime(2020, 10, 26, 20, 9, 20, 661000),
#   'params': {'description': 'Reed simulation with modal tracts and reed dynamics and non-linear reed force var gamma',
#    'version': '20201026',
#    'db': 'modal-vt-bore-jumps-2',
#    'tmax': 0.5,
#    'gamma': {'sustain_val': 0.6233710773350962,
#     'time_const': 0.05,
#     'exp_limit_multiplier': 1.1},
#    'zeta': 0.5,
#    'reed': {'frequency': 3850.772266100908,
#     'q': 2.8328228051701805,
#     'amplitude': 2.8328228051701805},
#    'bore': {'frequencies': [726.1581554762913],
#     'qs': [13.492181731950268],
#     'amplitudes': [13.492181731950268]},
#    'vocal': {'frequencies': [500], 'qs': [15], 'amplitudes': [15]},
#    'nlfunc': {'type': 'parabolic', 'nl_start': 0.75, 'nl_ev': 1.1},
#    'perturbation': {'multiplier': 1.1, 'duration': 0.39816598338508535},
#    'simulation': {'sample rate': 385077.2266100908}},
#   'end': datetime.datetime(2020, 10, 26, 20, 9, 46, 104000)},
#  'analysis': {'pert_time': 0.11989543086315138,
#   'initial amplitude': 0.002409465303274145,
#   'final amplitude': 0.37969661845436664,
#   'f0': 962.8379702003683,
#   'f_0': 0.0,
#   'b0_t_min': 0.1338251042619569,
#   'b0_t_max': 0.03410484726820248,
#   'b0_abs_min': 0.006363547248243773,
#   'b0_abs_max': 0.014263581174493159,
#   'b0_abs_fin': 0.008335175438840091,
#   'b0_abs_pert': 0.01145554662834613,
#   'f_n1': 470.064973889271,
#   'bn1_t_min': 0.07133374321253746,
#   'bn1_t_max': 0.12784188884233164,
#   'bn1_abs_min': 3.643742151810262e-10,
#   'bn1_abs_max': 0.08612664159356523,
#   'bn1_abs_fin': 0.08262587489229054,
#   'bn1_abs_pert': 0.008868312208760614,
#   'f_1': 940.129947778542,
#   'b1_t_min': 0.05670810552012015,
#   'b1_t_max': 0.49414763286605623,
#   'b1_abs_min': 1.2432754896981734e-10,
#   'b1_abs_max': 0.10937887452995207,
#   'b1_abs_fin': 0.10937045812081576,
#   'b1_abs_pert': 0.00017793202943336387,
#   'f_n2': 1410.194921667813,
#   'bn2_t_min': 0.04075286440111944,
#   'bn2_t_max': 0.49414763286605623,
#   'bn2_abs_min': 1.2301523629517922e-10,
#   'bn2_abs_max': 0.017712499684570133,
#   'bn2_abs_fin': 0.017706679378053352,
#   'bn2_abs_pert': 5.827496203107459e-06,
#   'f_2': 1903.7631442515476,
#   'b2_t_min': 0.08447656145851119,
#   'b2_t_max': 0.3031963251314792,
#   'b2_abs_min': 9.914317893753216e-11,
#   'b2_abs_max': 0.012483477105626186,
#   'b2_abs_fin': 0.01214987157274705,
#   'b2_abs_pert': 1.193841899559215e-06,
#   'vt0_t_min': 0.13116589740879012,
#   'vt0_t_max': 0.0314456404150357,
#   'vt0_abs_min': 0.003372128128640096,
#   'vt0_abs_max': 0.012867187075197505,
#   'vt0_abs_fin': 0.007562903166160819,
#   'vt0_abs_pert': 0.010561424470382165,
#   'vtn1_t_min': 0.0660153295062039,
#   'vtn1_t_max': 0.13548710854518614,
#   'vtn1_abs_min': 1.0035560447122465e-09,
#   'vtn1_abs_max': 0.5931655837193609,
#   'vtn1_abs_fin': 0.524627511024802,
#   'vtn1_abs_pert': 0.022882101535395646,
#   'vt1_t_min': 0.05670810552012015,
#   'vt1_t_max': 0.38877656130932237,
#   'vt1_abs_min': 1.1743499797356181e-10,
#   'vt1_abs_max': 0.04272868076779015,
#   'vt1_abs_fin': 0.042640618591849075,
#   'vt1_abs_pert': 3.5371309879450344e-05,
#   'vtn2_t_min': 0.04075286440111944,
#   'vtn2_t_max': 0.49414763286605623,
#   'vtn2_abs_min': 5.668669026483445e-11,
#   'vtn2_abs_max': 0.010253946281972296,
#   'vtn2_abs_fin': 0.010241891660270702,
#   'vtn2_abs_pert': 8.335416152159076e-06,
#   'vt2_t_min': 0.08447656145851119,
#   'vt2_t_max': 0.3031963251314792,
#   'vt2_abs_min': 5.05401536933991e-11,
#   'vt2_abs_max': 0.007882289004952069,
#   'vt2_abs_fin': 0.0076595356227973505,
#   'vt2_abs_pert': 2.610373841806339e-06,
#   't_trans_start': 0.11898496825255839,
#   't_trans_end': 0.13192533113680155,
#   'sus_f0_avg': 961.3166232147433,
#   'sus_f0_std': 75.24266001745733,
#   'trans_f0_avg': 356.83339424621994,
#   'trans_f0_std': 220.38989589299518,
#   'b0_abs_sus': 0.008141281364034195,
#   'b0_abs_sus_var': 0.00018649340075263011,
#   'b0_abs_trans': 0.010057285454365907,
#   'b0_abs_trans_var': 0.0030649412318748404,
#   'bn1_abs_sus': 0.08249996769385026,
#   'bn1_abs_sus_var': 0.00017417354679837016,
#   'bn1_abs_trans': 0.0651263038383749,
#   'bn1_abs_trans_var': 0.05884495535837883,
#   'b1_abs_sus': 0.1091242843944361,
#   'b1_abs_sus_var': 0.0003151542280654951,
#   'b1_abs_trans': 0.006608225800641096,
#   'b1_abs_trans_var': 0.02947410654252046,
#   'bn2_abs_sus': 0.017423561812235158,
#   'bn2_abs_sus_var': 0.00029158666415069964,
#   'bn2_abs_trans': 0.0015246523876597717,
#   'bn2_abs_trans_var': 0.005888366308450737,
#   'b2_abs_sus': 0.012266565124181221,
#   'b2_abs_sus_var': 0.0001148017614431094,
#   'b2_abs_trans': 0.0003466425174876261,
#   'b2_abs_trans_var': 0.0021184776489865257,
#   'b2_trans_rate_pct25': 2507.6724348424855,
#   'b2_trans_rate_pct50': 3555.4152325313926,
#   'b2_trans_rate_pct75': 11258.128140977331,
#   'vt0_abs_sus': 0.007351187303554618,
#   'vt0_abs_sus_var': 0.00014368964609807154,
#   'vt0_abs_trans': 0.008786431909547854,
#   'vt0_abs_trans_var': 0.003357027409646978,
#   'vtn1_abs_sus': 0.5337836186140499,
#   'vtn1_abs_sus_var': 0.009126279446337593,
#   'vtn1_abs_trans': 0.18306137186803456,
#   'vtn1_abs_trans_var': 0.3483480501284066,
#   'vt1_abs_sus': 0.042694010520818435,
#   'vt1_abs_sus_var': 4.2457335123737006e-05,
#   'vt1_abs_trans': 0.0032894446430296225,
#   'vt1_abs_trans_var': 0.01218663741643892,
#   'vtn2_abs_sus': 0.010094912618709779,
#   'vtn2_abs_sus_var': 0.00015996635363437102,
#   'vtn2_abs_trans': 0.0008975907090311764,
#   'vtn2_abs_trans_var': 0.0034423886086535948,
#   'vt2_abs_sus': 0.007735775350534975,
#   'vt2_abs_sus_var': 7.538345775703718e-05,
#   'vt2_abs_trans': 0.00021852094262575018,
#   'vt2_abs_trans_var': 0.0013444217125839534,
#   'vt2_trans_rate_pct25': 2772.953438700755,
#   'vt2_trans_rate_pct50': 3611.858857197388,
#   'vt2_trans_rate_pct75': 6834.616672369419,
#   'fb0_abs_sus': 0.0,
#   'fb0_abs_sus_var': 0.0,
#   'fb0_abs_trans': 0.0,
#   'fb0_abs_trans_var': 0.0,
#   'fbn1_abs_sus': 470.5374986798916,
#   'fbn1_abs_sus_var': 0.8312554667719496,
#   'fbn1_abs_trans': 497.23161198497615,
#   'fbn1_abs_trans_var': 21.019116208028493,
#   'fb1_abs_sus': 941.1803524215519,
#   'fb1_abs_sus_var': 1.7419481495074933,
#   'fb1_abs_trans': 979.8231251278925,
#   'fb1_abs_trans_var': 44.60158108435269,
#   'fbn2_abs_sus': 1411.9012651217965,
#   'fbn2_abs_sus_var': 2.588552291167389,
#   'fbn2_abs_trans': 1433.4811317188003,
#   'fbn2_abs_trans_var': 285.9738409551212,
#   'fb2_abs_sus': 1882.5482222336582,
#   'fb2_abs_sus_var': 4.143129286128897,
#   'fb2_abs_trans': 1928.4255497020522,
#   'fb2_abs_trans_var': 231.3474044452205,
#   'fvt0_abs_sus': 0.0,
#   'fvt0_abs_sus_var': 0.0,
#   'fvt0_abs_trans': 0.0,
#   'fvt0_abs_trans_var': 0.0,
#   'fvtn1_abs_sus': 470.60082858202,
#   'fvtn1_abs_sus_var': 0.8808272336434584,
#   'fvtn1_abs_trans': 495.83382894859983,
#   'fvtn1_abs_trans_var': 7.224974486870224,
#   'fvt1_abs_sus': 941.1853781389478,
#   'fvt1_abs_sus_var': 1.7515083421307054,
#   'fvt1_abs_trans': 979.2879899243441,
#   'fvt1_abs_trans_var': 51.96081521617771,
#   'fvtn2_abs_sus': 1411.88994806016,
#   'fvtn2_abs_sus_var': 2.599428055246335,
#   'fvtn2_abs_trans': 1441.7457653458096,
#   'fvtn2_abs_trans_var': 328.62067645476327,
#   'fvt2_abs_sus': 1882.5925398159889,
#   'fvt2_abs_sus_var': 4.173551772279552,
#   'fvt2_abs_trans': 1934.2391987808985,
#   'fvt2_abs_trans_var': 117.6990597819256,
#   'hrat0_abs_sus': -0.9127646839881507,
#   'hrat0_abs_sus_var': 0.06897480876578754,
#   'hrat0_abs_trans': -0.9711596542959313,
#   'hrat0_abs_trans_var': 2.2275878480553573,
#   'hrat0_abs_fin': -0.8445241095701803,
#   'hrat0_abs_pert': -0.7058085401465082,
#   'hratn1_abs_sus': 16.216998159332626,
#   'hratn1_abs_sus_var': 0.16653291286190353,
#   'hratn1_abs_trans': 9.093097751330369,
#   'hratn1_abs_trans_var': 5.514727320444246,
#   'hratn1_abs_fin': 16.054699795999614,
#   'hratn1_abs_pert': 8.23269075164417,
#   'hrat1_abs_sus': -8.151098334440894,
#   'hrat1_abs_sus_var': 0.033968010104601376,
#   'hrat1_abs_trans': -7.065084625383953,
#   'hrat1_abs_trans_var': 1.9478909321669562,
#   'hrat1_abs_fin': -8.18153069663395,
#   'hrat1_abs_pert': -14.428794976214318,
#   'hratn2_abs_sus': -4.741159236602446,
#   'hratn2_abs_sus_var': 0.007023477542615453,
#   'hratn2_abs_trans': -4.54695435924863,
#   'hratn2_abs_trans_var': 0.5370162743410063,
#   'hratn2_abs_fin': -4.755138918025999,
#   'hratn2_abs_pert': 3.274679254687655,
#   'hrat2_abs_sus': -4.003924903377538,
#   'hrat2_abs_sus_var': 0.0033076386454560236,
#   'hrat2_abs_trans': -3.92311525649221,
#   'hrat2_abs_trans_var': 2.807320042116558,
#   'hrat2_abs_fin': -4.007384940787482,
#   'hrat2_abs_pert': 7.711186084835495,
#   'b0_rate': 202.31322247886814,
#   'b0_jump': 0.1823245241836986,
#   'b0_t_before_jump': 0.1338251042619569,
#   'bn1_rate': 3388.7765370294987,
#   'bn1_jump': 0.0757277565444312,
#   'bn1_t_before_jump': 0.12385307856258146,
#   'b1_rate': 4184.422396225787,
#   'b1_jump': 34.54218060039233,
#   'b1_t_before_jump': 0.11421345371985187,
#   'bn2_rate': 3547.6032972402522,
#   'bn2_jump': 38.25333870940557,
#   'bn2_t_before_jump': 0.11554305714643526,
#   'b2_rate': 3807.2157152941636,
#   'b2_jump': 43.04074909039676,
#   'b2_t_before_jump': 0.11904625054967939,
#   'vtn1_rate': 3316.615186403682,
#   'vtn1_jump': 1.1822621312040162,
#   'vtn1_t_before_jump': 0.1268446862723941,
#   'vt1_rate': 4240.935597490215,
#   'vt1_jump': 16.18096142215073,
#   'vt1_t_before_jump': 0.11986426828283128,
#   'vtn2_rate': 3699.580322583837,
#   'vtn2_jump': 27.878600568874646,
#   'vtn2_t_before_jump': 0.12119387170941467,
#   'vt2_rate': 3817.5974163916867,
#   'vt2_jump': 30.53262873790979,
#   'vt2_t_before_jump': 0.12237025911613787}}

# %%
row.name
# Out:
# 1626

# %%
idx
# Out:
# 1626

# %%
df1.loc[idx]
# Out:
# _id                                      5f96925b98b40108a64ec6f6
# simulation/start                       2020-10-26 20:09:20.661000
# simulation/params/tmax                                        0.5
# simulation/params/gamma/sustain_val                      0.623371
# simulation/params/gamma/time_const                           0.05
#                                                   ...
# trans dur                                               0.0129404
# starts after pert                                            True
# zb_max_f                                                  726.158
# zb_max_val                                                1.73451
# zrat_f0                                                   2.44211
# Name: 1626, Length: 1161, dtype: object

# %%
df.columns.to_list()
# Out:
# ['_id',
#  'simulation/start',
#  'simulation/params/tmax',
#  'simulation/params/gamma/sustain_val',
#  'simulation/params/gamma/time_const',
#  'simulation/params/gamma/exp_limit_multiplier',
#  'simulation/params/zeta',
#  'simulation/params/reed/frequency',
#  'simulation/params/reed/q',
#  'simulation/params/reed/amplitude',
#  'simulation/params/bore/frequencies/0',
#  'simulation/params/bore/qs/0',
#  'simulation/params/bore/amplitudes/0',
#  'simulation/params/vocal/frequencies/0',
#  'simulation/params/vocal/qs/0',
#  'simulation/params/vocal/amplitudes/0',
#  'simulation/params/nlfunc/nl_start',
#  'simulation/params/nlfunc/nl_ev',
#  'simulation/params/perturbation/multiplier',
#  'simulation/params/perturbation/duration',
#  'simulation/params/simulation/sample rate',
#  'simulation/end',
#  'analysis/pert_time',
#  'analysis/initial amplitude',
#  'analysis/final amplitude',
#  'analysis/f0',
#  'analysis/f_0',
#  'analysis/b0_t_min',
#  'analysis/b0_t_max',
#  'analysis/b0_abs_min',
#  'analysis/b0_abs_max',
#  'analysis/b0_abs_fin',
#  'analysis/b0_abs_pert',
#  'analysis/f_1',
#  'analysis/b1_t_min',
#  'analysis/b1_t_max',
#  'analysis/b1_abs_min',
#  'analysis/b1_abs_max',
#  'analysis/b1_abs_fin',
#  'analysis/b1_abs_pert',
#  'analysis/f_2',
#  'analysis/b2_t_min',
#  'analysis/b2_t_max',
#  'analysis/b2_abs_min',
#  'analysis/b2_abs_max',
#  'analysis/b2_abs_fin',
#  'analysis/b2_abs_pert',
#  'analysis/f_3',
#  'analysis/b3_t_min',
#  'analysis/b3_t_max',
#  'analysis/b3_abs_min',
#  'analysis/b3_abs_max',
#  'analysis/b3_abs_fin',
#  'analysis/b3_abs_pert',
#  'analysis/f_4',
#  'analysis/b4_t_min',
#  'analysis/b4_t_max',
#  'analysis/b4_abs_min',
#  'analysis/b4_abs_max',
#  'analysis/b4_abs_fin',
#  'analysis/b4_abs_pert',
#  'analysis/vt0_t_min',
#  'analysis/vt0_t_max',
#  'analysis/vt0_abs_min',
#  'analysis/vt0_abs_max',
#  'analysis/vt0_abs_fin',
#  'analysis/vt0_abs_pert',
#  'analysis/vt1_t_min',
#  'analysis/vt1_t_max',
#  'analysis/vt1_abs_min',
#  'analysis/vt1_abs_max',
#  'analysis/vt1_abs_fin',
#  'analysis/vt1_abs_pert',
#  'analysis/vt2_t_min',
#  'analysis/vt2_t_max',
#  'analysis/vt2_abs_min',
#  'analysis/vt2_abs_max',
#  'analysis/vt2_abs_fin',
#  'analysis/vt2_abs_pert',
#  'analysis/vt3_t_min',
#  'analysis/vt3_t_max',
#  'analysis/vt3_abs_min',
#  'analysis/vt3_abs_max',
#  'analysis/vt3_abs_fin',
#  'analysis/vt3_abs_pert',
#  'analysis/vt4_t_min',
#  'analysis/vt4_t_max',
#  'analysis/vt4_abs_min',
#  'analysis/vt4_abs_max',
#  'analysis/vt4_abs_fin',
#  'analysis/vt4_abs_pert',
#  'analysis/t_trans_start',
#  'analysis/t_trans_end',
#  'analysis/sus_f0_avg',
#  'analysis/sus_f0_std',
#  'analysis/trans_f0_avg',
#  'analysis/trans_f0_std',
#  'analysis/b0_abs_sus',
#  'analysis/b0_abs_sus_var',
#  'analysis/b0_abs_trans',
#  'analysis/b0_abs_trans_var',
#  'analysis/b1_abs_sus',
#  'analysis/b1_abs_sus_var',
#  'analysis/b1_abs_trans',
#  'analysis/b1_abs_trans_var',
#  'analysis/b2_abs_sus',
#  'analysis/b2_abs_sus_var',
#  'analysis/b2_abs_trans',
#  'analysis/b2_abs_trans_var',
#  'analysis/b3_abs_sus',
#  'analysis/b3_abs_sus_var',
#  'analysis/b3_abs_trans',
#  'analysis/b3_abs_trans_var',
#  'analysis/b4_abs_sus',
#  'analysis/b4_abs_sus_var',
#  'analysis/b4_abs_trans',
#  'analysis/b4_abs_trans_var',
#  'analysis/b4_trans_rate_pct25',
#  'analysis/b4_trans_rate_pct50',
#  'analysis/b4_trans_rate_pct75',
#  'analysis/vt0_abs_sus',
#  'analysis/vt0_abs_sus_var',
#  'analysis/vt0_abs_trans',
#  'analysis/vt0_abs_trans_var',
#  'analysis/vt1_abs_sus',
#  'analysis/vt1_abs_sus_var',
#  'analysis/vt1_abs_trans',
#  'analysis/vt1_abs_trans_var',
#  'analysis/vt2_abs_sus',
#  'analysis/vt2_abs_sus_var',
#  'analysis/vt2_abs_trans',
#  'analysis/vt2_abs_trans_var',
#  'analysis/vt3_abs_sus',
#  'analysis/vt3_abs_sus_var',
#  'analysis/vt3_abs_trans',
#  'analysis/vt3_abs_trans_var',
#  'analysis/vt4_abs_sus',
#  'analysis/vt4_abs_sus_var',
#  'analysis/vt4_abs_trans',
#  'analysis/vt4_abs_trans_var',
#  'analysis/vt4_trans_rate_pct25',
#  'analysis/vt4_trans_rate_pct50',
#  'analysis/vt4_trans_rate_pct75',
#  'analysis/fb0_abs_sus',
#  'analysis/fb0_abs_sus_var',
#  'analysis/fb0_abs_trans',
#  'analysis/fb0_abs_trans_var',
#  'analysis/fb1_abs_sus',
#  'analysis/fb1_abs_sus_var',
#  'analysis/fb1_abs_trans',
#  'analysis/fb1_abs_trans_var',
#  'analysis/fb2_abs_sus',
#  'analysis/fb2_abs_sus_var',
#  'analysis/fb2_abs_trans',
#  'analysis/fb2_abs_trans_var',
#  'analysis/fb3_abs_sus',
#  'analysis/fb3_abs_sus_var',
#  'analysis/fb3_abs_trans',
#  'analysis/fb3_abs_trans_var',
#  'analysis/fb4_abs_sus',
#  'analysis/fb4_abs_sus_var',
#  'analysis/fb4_abs_trans',
#  'analysis/fb4_abs_trans_var',
#  'analysis/fvt0_abs_sus',
#  'analysis/fvt0_abs_sus_var',
#  'analysis/fvt0_abs_trans',
#  'analysis/fvt0_abs_trans_var',
#  'analysis/fvt1_abs_sus',
#  'analysis/fvt1_abs_sus_var',
#  'analysis/fvt1_abs_trans',
#  'analysis/fvt1_abs_trans_var',
#  'analysis/fvt2_abs_sus',
#  'analysis/fvt2_abs_sus_var',
#  'analysis/fvt2_abs_trans',
#  'analysis/fvt2_abs_trans_var',
#  'analysis/fvt3_abs_sus',
#  'analysis/fvt3_abs_sus_var',
#  'analysis/fvt3_abs_trans',
#  'analysis/fvt3_abs_trans_var',
#  'analysis/fvt4_abs_sus',
#  'analysis/fvt4_abs_sus_var',
#  'analysis/fvt4_abs_trans',
#  'analysis/fvt4_abs_trans_var',
#  'analysis/hrat0_abs_sus',
#  'analysis/hrat0_abs_sus_var',
#  'analysis/hrat0_abs_trans',
#  'analysis/hrat0_abs_trans_var',
#  'analysis/hrat0_abs_fin',
#  'analysis/hrat0_abs_pert',
#  'analysis/hrat1_abs_sus',
#  'analysis/hrat1_abs_sus_var',
#  'analysis/hrat1_abs_trans',
#  'analysis/hrat1_abs_trans_var',
#  'analysis/hrat1_abs_fin',
#  'analysis/hrat1_abs_pert',
#  'analysis/hrat2_abs_sus',
#  'analysis/hrat2_abs_sus_var',
#  'analysis/hrat2_abs_trans',
#  'analysis/hrat2_abs_trans_var',
#  'analysis/hrat2_abs_fin',
#  'analysis/hrat2_abs_pert',
#  'analysis/hrat3_abs_sus',
#  'analysis/hrat3_abs_sus_var',
#  'analysis/hrat3_abs_trans',
#  'analysis/hrat3_abs_trans_var',
#  'analysis/hrat3_abs_fin',
#  'analysis/hrat3_abs_pert',
#  'analysis/hrat4_abs_sus',
#  'analysis/hrat4_abs_sus_var',
#  'analysis/hrat4_abs_trans',
#  'analysis/hrat4_abs_trans_var',
#  'analysis/hrat4_abs_fin',
#  'analysis/hrat4_abs_pert',
#  'analysis/b0_rate',
#  'analysis/b0_jump',
#  'analysis/b0_t_before_jump',
#  'analysis/b1_rate',
#  'analysis/b1_jump',
#  'analysis/b1_t_before_jump',
#  'analysis/b2_rate',
#  'analysis/b2_jump',
#  'analysis/b2_t_before_jump',
#  'analysis/b3_rate',
#  'analysis/b3_jump',
#  'analysis/b3_t_before_jump',
#  'analysis/b4_rate',
#  'analysis/b4_jump',
#  'analysis/b4_t_before_jump',
#  'analysis/vt0_rate',
#  'analysis/vt0_jump',
#  'analysis/vt0_t_before_jump',
#  'analysis/vt1_rate',
#  'analysis/vt1_jump',
#  'analysis/vt1_t_before_jump',
#  'analysis/vt2_rate',
#  'analysis/vt2_jump',
#  'analysis/vt2_t_before_jump',
#  'analysis/vt3_rate',
#  'analysis/vt3_jump',
#  'analysis/vt3_t_before_jump',
#  'analysis/vt4_rate',
#  'analysis/vt4_jump',
#  'analysis/vt4_t_before_jump',
#  'analysis/f_n1',
#  'analysis/bn1_t_min',
#  'analysis/bn1_t_max',
#  'analysis/bn1_abs_min',
#  'analysis/bn1_abs_max',
#  'analysis/bn1_abs_fin',
#  'analysis/bn1_abs_pert',
#  'analysis/f_5',
#  'analysis/b5_t_min',
#  'analysis/b5_t_max',
#  'analysis/b5_abs_min',
#  'analysis/b5_abs_max',
#  'analysis/b5_abs_fin',
#  'analysis/b5_abs_pert',
#  'analysis/f_6',
#  'analysis/b6_t_min',
#  'analysis/b6_t_max',
#  'analysis/b6_abs_min',
#  'analysis/b6_abs_max',
#  'analysis/b6_abs_fin',
#  'analysis/b6_abs_pert',
#  'analysis/vtn1_t_min',
#  'analysis/vtn1_t_max',
#  'analysis/vtn1_abs_min',
#  'analysis/vtn1_abs_max',
#  'analysis/vtn1_abs_fin',
#  'analysis/vtn1_abs_pert',
#  'analysis/vt5_t_min',
#  'analysis/vt5_t_max',
#  'analysis/vt5_abs_min',
#  'analysis/vt5_abs_max',
#  'analysis/vt5_abs_fin',
#  'analysis/vt5_abs_pert',
#  'analysis/vt6_t_min',
#  'analysis/vt6_t_max',
#  'analysis/vt6_abs_min',
#  'analysis/vt6_abs_max',
#  'analysis/vt6_abs_fin',
#  'analysis/vt6_abs_pert',
#  'analysis/bn1_abs_sus',
#  'analysis/bn1_abs_sus_var',
#  'analysis/bn1_abs_trans',
#  'analysis/bn1_abs_trans_var',
#  'analysis/b5_abs_sus',
#  'analysis/b5_abs_sus_var',
#  'analysis/b5_abs_trans',
#  'analysis/b5_abs_trans_var',
#  'analysis/b6_abs_sus',
#  'analysis/b6_abs_sus_var',
#  'analysis/b6_abs_trans',
#  'analysis/b6_abs_trans_var',
#  'analysis/b6_trans_rate_pct25',
#  'analysis/b6_trans_rate_pct50',
#  'analysis/b6_trans_rate_pct75',
#  'analysis/vtn1_abs_sus',
#  'analysis/vtn1_abs_sus_var',
#  'analysis/vtn1_abs_trans',
#  'analysis/vtn1_abs_trans_var',
#  'analysis/vt5_abs_sus',
#  'analysis/vt5_abs_sus_var',
#  'analysis/vt5_abs_trans',
#  'analysis/vt5_abs_trans_var',
#  'analysis/vt6_abs_sus',
#  'analysis/vt6_abs_sus_var',
#  'analysis/vt6_abs_trans',
#  'analysis/vt6_abs_trans_var',
#  'analysis/vt6_trans_rate_pct25',
#  'analysis/vt6_trans_rate_pct50',
#  'analysis/vt6_trans_rate_pct75',
#  'analysis/fbn1_abs_sus',
#  'analysis/fbn1_abs_sus_var',
#  'analysis/fbn1_abs_trans',
#  'analysis/fbn1_abs_trans_var',
#  'analysis/fb5_abs_sus',
#  'analysis/fb5_abs_sus_var',
#  'analysis/fb5_abs_trans',
#  'analysis/fb5_abs_trans_var',
#  'analysis/fb6_abs_sus',
#  'analysis/fb6_abs_sus_var',
#  'analysis/fb6_abs_trans',
#  'analysis/fb6_abs_trans_var',
#  'analysis/fvtn1_abs_sus',
#  'analysis/fvtn1_abs_sus_var',
#  'analysis/fvtn1_abs_trans',
#  'analysis/fvtn1_abs_trans_var',
#  'analysis/fvt5_abs_sus',
#  'analysis/fvt5_abs_sus_var',
#  'analysis/fvt5_abs_trans',
#  'analysis/fvt5_abs_trans_var',
#  'analysis/fvt6_abs_sus',
#  'analysis/fvt6_abs_sus_var',
#  'analysis/fvt6_abs_trans',
#  'analysis/fvt6_abs_trans_var',
#  'analysis/hratn1_abs_sus',
#  'analysis/hratn1_abs_sus_var',
#  'analysis/hratn1_abs_trans',
#  'analysis/hratn1_abs_trans_var',
#  'analysis/hratn1_abs_fin',
#  'analysis/hratn1_abs_pert',
#  'analysis/hrat5_abs_sus',
#  'analysis/hrat5_abs_sus_var',
#  'analysis/hrat5_abs_trans',
#  'analysis/hrat5_abs_trans_var',
#  'analysis/hrat5_abs_fin',
#  'analysis/hrat5_abs_pert',
#  'analysis/hrat6_abs_sus',
#  'analysis/hrat6_abs_sus_var',
#  'analysis/hrat6_abs_trans',
#  'analysis/hrat6_abs_trans_var',
#  'analysis/hrat6_abs_fin',
#  'analysis/hrat6_abs_pert',
#  'analysis/bn1_rate',
#  'analysis/bn1_jump',
#  'analysis/bn1_t_before_jump',
#  'analysis/b5_rate',
#  'analysis/b5_jump',
#  'analysis/b5_t_before_jump',
#  'analysis/b6_rate',
#  'analysis/vtn1_rate',
#  'analysis/vtn1_jump',
#  'analysis/vtn1_t_before_jump',
#  'analysis/vt5_rate',
#  'analysis/vt5_jump',
#  'analysis/vt5_t_before_jump',
#  'analysis/vt6_rate',
#  'analysis/b6_jump',
#  'analysis/b6_t_before_jump',
#  'analysis/vt6_jump',
#  'analysis/vt6_t_before_jump',
#  'analysis/f_n2',
#  'analysis/bn2_t_min',
#  'analysis/bn2_t_max',
#  'analysis/bn2_abs_min',
#  'analysis/bn2_abs_max',
#  'analysis/bn2_abs_fin',
#  'analysis/bn2_abs_pert',
#  'analysis/vtn2_t_min',
#  'analysis/vtn2_t_max',
#  'analysis/vtn2_abs_min',
#  'analysis/vtn2_abs_max',
#  'analysis/vtn2_abs_fin',
#  'analysis/vtn2_abs_pert',
#  'analysis/bn2_abs_sus',
#  'analysis/bn2_abs_sus_var',
#  'analysis/bn2_abs_trans',
#  'analysis/bn2_abs_trans_var',
#  'analysis/b2_trans_rate_pct25',
#  'analysis/b2_trans_rate_pct50',
#  'analysis/b2_trans_rate_pct75',
#  'analysis/vtn2_abs_sus',
#  'analysis/vtn2_abs_sus_var',
#  'analysis/vtn2_abs_trans',
#  'analysis/vtn2_abs_trans_var',
#  'analysis/vt2_trans_rate_pct25',
#  'analysis/vt2_trans_rate_pct50',
#  'analysis/vt2_trans_rate_pct75',
#  'analysis/fbn2_abs_sus',
#  'analysis/fbn2_abs_sus_var',
#  'analysis/fbn2_abs_trans',
#  'analysis/fbn2_abs_trans_var',
#  'analysis/fvtn2_abs_sus',
#  'analysis/fvtn2_abs_sus_var',
#  'analysis/fvtn2_abs_trans',
#  'analysis/fvtn2_abs_trans_var',
#  'analysis/hratn2_abs_sus',
#  'analysis/hratn2_abs_sus_var',
#  'analysis/hratn2_abs_trans',
#  'analysis/hratn2_abs_trans_var',
#  'analysis/hratn2_abs_fin',
#  'analysis/hratn2_abs_pert',
#  'analysis/bn2_rate',
#  'analysis/bn2_jump',
#  'analysis/bn2_t_before_jump',
#  'analysis/vtn2_rate',
#  'analysis/vtn2_jump',
#  'analysis/vtn2_t_before_jump',
#  'analysis/f_7',
#  'analysis/b7_t_min',
#  'analysis/b7_t_max',
#  'analysis/b7_abs_min',
#  'analysis/b7_abs_max',
#  'analysis/b7_abs_fin',
#  'analysis/b7_abs_pert',
#  'analysis/vt7_t_min',
#  'analysis/vt7_t_max',
#  'analysis/vt7_abs_min',
#  'analysis/vt7_abs_max',
#  'analysis/vt7_abs_fin',
#  'analysis/vt7_abs_pert',
#  'analysis/b7_abs_sus',
#  'analysis/b7_abs_sus_var',
#  'analysis/b7_abs_trans',
#  'analysis/b7_abs_trans_var',
#  'analysis/b7_trans_rate_pct25',
#  'analysis/b7_trans_rate_pct50',
#  'analysis/b7_trans_rate_pct75',
#  'analysis/vt7_abs_sus',
#  'analysis/vt7_abs_sus_var',
#  'analysis/vt7_abs_trans',
#  'analysis/vt7_abs_trans_var',
#  'analysis/vt7_trans_rate_pct25',
#  'analysis/vt7_trans_rate_pct50',
#  'analysis/vt7_trans_rate_pct75',
#  'analysis/fb7_abs_sus',
#  'analysis/fb7_abs_sus_var',
#  'analysis/fb7_abs_trans',
#  'analysis/fb7_abs_trans_var',
#  'analysis/fvt7_abs_sus',
#  'analysis/fvt7_abs_sus_var',
#  'analysis/fvt7_abs_trans',
#  'analysis/fvt7_abs_trans_var',
#  'analysis/hrat7_abs_sus',
#  'analysis/hrat7_abs_sus_var',
#  'analysis/hrat7_abs_trans',
#  'analysis/hrat7_abs_trans_var',
#  'analysis/hrat7_abs_fin',
#  'analysis/hrat7_abs_pert',
#  'analysis/b7_rate',
#  'analysis/b7_jump',
#  'analysis/b7_t_before_jump',
#  'analysis/vt7_rate',
#  'analysis/vt7_jump',
#  'analysis/vt7_t_before_jump',
#  'analysis/b5_trans_rate_pct25',
#  'analysis/b5_trans_rate_pct50',
#  'analysis/b5_trans_rate_pct75',
#  'analysis/vt5_trans_rate_pct25',
#  'analysis/vt5_trans_rate_pct50',
#  'analysis/vt5_trans_rate_pct75',
#  'analysis/bn1_trans_rate_pct25',
#  'analysis/bn1_trans_rate_pct50',
#  'analysis/bn1_trans_rate_pct75',
#  'analysis/vtn1_trans_rate_pct25',
#  'analysis/vtn1_trans_rate_pct50',
#  'analysis/vtn1_trans_rate_pct75',
#  'analysis/bn2_trans_rate_pct25',
#  'analysis/bn2_trans_rate_pct50',
#  'analysis/bn2_trans_rate_pct75',
#  'analysis/vtn2_trans_rate_pct25',
#  'analysis/vtn2_trans_rate_pct50',
#  'analysis/vtn2_trans_rate_pct75',
#  'analysis/f_n3',
#  'analysis/bn3_t_min',
#  'analysis/bn3_t_max',
#  'analysis/bn3_abs_min',
#  'analysis/bn3_abs_max',
#  'analysis/bn3_abs_fin',
#  'analysis/bn3_abs_pert',
#  'analysis/vtn3_t_min',
#  'analysis/vtn3_t_max',
#  'analysis/vtn3_abs_min',
#  'analysis/vtn3_abs_max',
#  'analysis/vtn3_abs_fin',
#  'analysis/vtn3_abs_pert',
#  'analysis/bn3_abs_sus',
#  'analysis/bn3_abs_sus_var',
#  'analysis/bn3_abs_trans',
#  'analysis/bn3_abs_trans_var',
#  'analysis/bn3_trans_rate_pct25',
#  'analysis/bn3_trans_rate_pct50',
#  'analysis/bn3_trans_rate_pct75',
#  'analysis/vtn3_abs_sus',
#  'analysis/vtn3_abs_sus_var',
#  'analysis/vtn3_abs_trans',
#  'analysis/vtn3_abs_trans_var',
#  'analysis/vtn3_trans_rate_pct25',
#  'analysis/vtn3_trans_rate_pct50',
#  'analysis/vtn3_trans_rate_pct75',
#  'analysis/fbn3_abs_sus',
#  'analysis/fbn3_abs_sus_var',
#  'analysis/fbn3_abs_trans',
#  'analysis/fbn3_abs_trans_var',
#  'analysis/fvtn3_abs_sus',
#  'analysis/fvtn3_abs_sus_var',
#  'analysis/fvtn3_abs_trans',
#  'analysis/fvtn3_abs_trans_var',
#  'analysis/hratn3_abs_sus',
#  'analysis/hratn3_abs_sus_var',
#  'analysis/hratn3_abs_trans',
#  'analysis/hratn3_abs_trans_var',
#  'analysis/hratn3_abs_fin',
#  'analysis/hratn3_abs_pert',
#  'analysis/bn3_rate',
#  'analysis/bn3_jump',
#  'analysis/bn3_t_before_jump',
#  'analysis/vtn3_rate',
#  'analysis/vtn3_jump',
#  'analysis/vtn3_t_before_jump',
#  'analysis/f_n4',
#  'analysis/bn4_t_min',
#  'analysis/bn4_t_max',
#  'analysis/bn4_abs_min',
#  'analysis/bn4_abs_max',
#  'analysis/bn4_abs_fin',
#  'analysis/bn4_abs_pert',
#  'analysis/vtn4_t_min',
#  'analysis/vtn4_t_max',
#  'analysis/vtn4_abs_min',
#  'analysis/vtn4_abs_max',
#  'analysis/vtn4_abs_fin',
#  'analysis/vtn4_abs_pert',
#  'analysis/bn4_abs_sus',
#  'analysis/bn4_abs_sus_var',
#  'analysis/bn4_abs_trans',
#  'analysis/bn4_abs_trans_var',
#  'analysis/bn4_trans_rate_pct25',
#  'analysis/bn4_trans_rate_pct50',
#  'analysis/bn4_trans_rate_pct75',
#  'analysis/vtn4_abs_sus',
#  'analysis/vtn4_abs_sus_var',
#  'analysis/vtn4_abs_trans',
#  'analysis/vtn4_abs_trans_var',
#  'analysis/vtn4_trans_rate_pct25',
#  'analysis/vtn4_trans_rate_pct50',
#  'analysis/vtn4_trans_rate_pct75',
#  'analysis/fbn4_abs_sus',
#  'analysis/fbn4_abs_sus_var',
#  'analysis/fbn4_abs_trans',
#  'analysis/fbn4_abs_trans_var',
#  'analysis/fvtn4_abs_sus',
#  'analysis/fvtn4_abs_sus_var',
#  'analysis/fvtn4_abs_trans',
#  'analysis/fvtn4_abs_trans_var',
#  'analysis/hratn4_abs_sus',
#  'analysis/hratn4_abs_sus_var',
#  'analysis/hratn4_abs_trans',
#  'analysis/hratn4_abs_trans_var',
#  'analysis/hratn4_abs_fin',
#  'analysis/hratn4_abs_pert',
#  'analysis/bn4_rate',
#  'analysis/bn4_jump',
#  'analysis/bn4_t_before_jump',
#  'analysis/vtn4_rate',
#  'analysis/vtn4_jump',
#  'analysis/vtn4_t_before_jump',
#  'analysis/f_8',
#  'analysis/b8_t_min',
#  'analysis/b8_t_max',
#  'analysis/b8_abs_min',
#  'analysis/b8_abs_max',
#  'analysis/b8_abs_fin',
#  'analysis/b8_abs_pert',
#  'analysis/vt8_t_min',
#  'analysis/vt8_t_max',
#  'analysis/vt8_abs_min',
#  'analysis/vt8_abs_max',
#  'analysis/vt8_abs_fin',
#  'analysis/vt8_abs_pert',
#  'analysis/b8_abs_sus',
#  'analysis/b8_abs_sus_var',
#  'analysis/b8_abs_trans',
#  'analysis/b8_abs_trans_var',
#  'analysis/b8_trans_rate_pct25',
#  'analysis/b8_trans_rate_pct50',
#  'analysis/b8_trans_rate_pct75',
#  'analysis/vt8_abs_sus',
#  'analysis/vt8_abs_sus_var',
#  'analysis/vt8_abs_trans',
#  'analysis/vt8_abs_trans_var',
#  'analysis/vt8_trans_rate_pct25',
#  'analysis/vt8_trans_rate_pct50',
#  'analysis/vt8_trans_rate_pct75',
#  'analysis/fb8_abs_sus',
#  'analysis/fb8_abs_sus_var',
#  'analysis/fb8_abs_trans',
#  'analysis/fb8_abs_trans_var',
#  'analysis/fvt8_abs_sus',
#  'analysis/fvt8_abs_sus_var',
#  'analysis/fvt8_abs_trans',
#  'analysis/fvt8_abs_trans_var',
#  'analysis/hrat8_abs_sus',
#  'analysis/hrat8_abs_sus_var',
#  'analysis/hrat8_abs_trans',
#  'analysis/hrat8_abs_trans_var',
#  'analysis/hrat8_abs_fin',
#  'analysis/hrat8_abs_pert',
#  'analysis/b8_rate',
#  'analysis/b8_jump',
#  'analysis/b8_t_before_jump',
#  'analysis/vt8_rate',
#  'analysis/vt8_jump',
#  'analysis/vt8_t_before_jump',
#  'analysis/f_n5',
#  'analysis/bn5_t_min',
#  'analysis/bn5_t_max',
#  'analysis/bn5_abs_min',
#  'analysis/bn5_abs_max',
#  'analysis/bn5_abs_fin',
#  'analysis/bn5_abs_pert',
#  'analysis/f_n6',
#  'analysis/bn6_t_min',
#  'analysis/bn6_t_max',
#  'analysis/bn6_abs_min',
#  'analysis/bn6_abs_max',
#  'analysis/bn6_abs_fin',
#  'analysis/bn6_abs_pert',
#  'analysis/f_n7',
#  'analysis/bn7_t_min',
#  'analysis/bn7_t_max',
#  'analysis/bn7_abs_min',
#  'analysis/bn7_abs_max',
#  'analysis/bn7_abs_fin',
#  'analysis/bn7_abs_pert',
#  'analysis/f_n8',
#  'analysis/bn8_t_min',
#  'analysis/bn8_t_max',
#  'analysis/bn8_abs_min',
#  'analysis/bn8_abs_max',
#  'analysis/bn8_abs_fin',
#  'analysis/bn8_abs_pert',
#  'analysis/f_n9',
#  'analysis/bn9_t_min',
#  'analysis/bn9_t_max',
#  'analysis/bn9_abs_min',
#  'analysis/bn9_abs_max',
#  'analysis/bn9_abs_fin',
#  'analysis/bn9_abs_pert',
#  'analysis/f_n10',
#  'analysis/bn10_t_min',
#  'analysis/bn10_t_max',
#  'analysis/bn10_abs_min',
#  'analysis/bn10_abs_max',
#  'analysis/bn10_abs_fin',
#  'analysis/bn10_abs_pert',
#  'analysis/vtn5_t_min',
#  'analysis/vtn5_t_max',
#  'analysis/vtn5_abs_min',
#  'analysis/vtn5_abs_max',
#  'analysis/vtn5_abs_fin',
#  'analysis/vtn5_abs_pert',
#  'analysis/vtn6_t_min',
#  'analysis/vtn6_t_max',
#  'analysis/vtn6_abs_min',
#  'analysis/vtn6_abs_max',
#  'analysis/vtn6_abs_fin',
#  'analysis/vtn6_abs_pert',
#  'analysis/vtn7_t_min',
#  'analysis/vtn7_t_max',
#  'analysis/vtn7_abs_min',
#  'analysis/vtn7_abs_max',
#  'analysis/vtn7_abs_fin',
#  'analysis/vtn7_abs_pert',
#  'analysis/vtn8_t_min',
#  'analysis/vtn8_t_max',
#  'analysis/vtn8_abs_min',
#  'analysis/vtn8_abs_max',
#  'analysis/vtn8_abs_fin',
#  'analysis/vtn8_abs_pert',
#  'analysis/vtn9_t_min',
#  'analysis/vtn9_t_max',
#  'analysis/vtn9_abs_min',
#  'analysis/vtn9_abs_max',
#  'analysis/vtn9_abs_fin',
#  'analysis/vtn9_abs_pert',
#  'analysis/vtn10_t_min',
#  'analysis/vtn10_t_max',
#  'analysis/vtn10_abs_min',
#  'analysis/vtn10_abs_max',
#  'analysis/vtn10_abs_fin',
#  'analysis/vtn10_abs_pert',
#  'analysis/bn5_abs_sus',
#  'analysis/bn5_abs_sus_var',
#  'analysis/bn5_abs_trans',
#  'analysis/bn5_abs_trans_var',
#  'analysis/bn6_abs_sus',
#  'analysis/bn6_abs_sus_var',
#  'analysis/bn6_abs_trans',
#  'analysis/bn6_abs_trans_var',
#  'analysis/bn7_abs_sus',
#  'analysis/bn7_abs_sus_var',
#  'analysis/bn7_abs_trans',
#  'analysis/bn7_abs_trans_var',
#  'analysis/bn8_abs_sus',
#  'analysis/bn8_abs_sus_var',
#  'analysis/bn8_abs_trans',
#  'analysis/bn8_abs_trans_var',
#  'analysis/bn9_abs_sus',
#  'analysis/bn9_abs_sus_var',
#  'analysis/bn9_abs_trans',
#  'analysis/bn9_abs_trans_var',
#  'analysis/bn10_abs_sus',
#  'analysis/bn10_abs_sus_var',
#  'analysis/bn10_abs_trans',
#  'analysis/bn10_abs_trans_var',
#  'analysis/bn10_trans_rate_pct25',
#  'analysis/bn10_trans_rate_pct50',
#  'analysis/bn10_trans_rate_pct75',
#  'analysis/vtn5_abs_sus',
#  'analysis/vtn5_abs_sus_var',
#  'analysis/vtn5_abs_trans',
#  'analysis/vtn5_abs_trans_var',
#  'analysis/vtn6_abs_sus',
#  'analysis/vtn6_abs_sus_var',
#  'analysis/vtn6_abs_trans',
#  'analysis/vtn6_abs_trans_var',
#  'analysis/vtn7_abs_sus',
#  'analysis/vtn7_abs_sus_var',
#  'analysis/vtn7_abs_trans',
#  'analysis/vtn7_abs_trans_var',
#  'analysis/vtn8_abs_sus',
#  'analysis/vtn8_abs_sus_var',
#  'analysis/vtn8_abs_trans',
#  'analysis/vtn8_abs_trans_var',
#  'analysis/vtn9_abs_sus',
#  'analysis/vtn9_abs_sus_var',
#  'analysis/vtn9_abs_trans',
#  'analysis/vtn9_abs_trans_var',
#  'analysis/vtn10_abs_sus',
#  'analysis/vtn10_abs_sus_var',
#  'analysis/vtn10_abs_trans',
#  'analysis/vtn10_abs_trans_var',
#  'analysis/vtn10_trans_rate_pct25',
#  'analysis/vtn10_trans_rate_pct50',
#  'analysis/vtn10_trans_rate_pct75',
#  'analysis/fbn5_abs_sus',
#  'analysis/fbn5_abs_sus_var',
#  'analysis/fbn5_abs_trans',
#  'analysis/fbn5_abs_trans_var',
#  'analysis/fbn6_abs_sus',
#  'analysis/fbn6_abs_sus_var',
#  'analysis/fbn6_abs_trans',
#  'analysis/fbn6_abs_trans_var',
#  'analysis/fbn7_abs_sus',
#  'analysis/fbn7_abs_sus_var',
#  'analysis/fbn7_abs_trans',
#  'analysis/fbn7_abs_trans_var',
#  'analysis/fbn8_abs_sus',
#  'analysis/fbn8_abs_sus_var',
#  'analysis/fbn8_abs_trans',
#  'analysis/fbn8_abs_trans_var',
#  'analysis/fbn9_abs_sus',
#  'analysis/fbn9_abs_sus_var',
#  'analysis/fbn9_abs_trans',
#  'analysis/fbn9_abs_trans_var',
#  'analysis/fbn10_abs_sus',
#  'analysis/fbn10_abs_sus_var',
#  'analysis/fbn10_abs_trans',
#  'analysis/fbn10_abs_trans_var',
#  'analysis/fvtn5_abs_sus',
#  'analysis/fvtn5_abs_sus_var',
#  'analysis/fvtn5_abs_trans',
#  'analysis/fvtn5_abs_trans_var',
#  'analysis/fvtn6_abs_sus',
#  'analysis/fvtn6_abs_sus_var',
#  'analysis/fvtn6_abs_trans',
#  'analysis/fvtn6_abs_trans_var',
#  'analysis/fvtn7_abs_sus',
#  'analysis/fvtn7_abs_sus_var',
#  'analysis/fvtn7_abs_trans',
#  'analysis/fvtn7_abs_trans_var',
#  'analysis/fvtn8_abs_sus',
#  'analysis/fvtn8_abs_sus_var',
#  'analysis/fvtn8_abs_trans',
#  'analysis/fvtn8_abs_trans_var',
#  'analysis/fvtn9_abs_sus',
#  'analysis/fvtn9_abs_sus_var',
#  'analysis/fvtn9_abs_trans',
#  'analysis/fvtn9_abs_trans_var',
#  'analysis/fvtn10_abs_sus',
#  'analysis/fvtn10_abs_sus_var',
#  'analysis/fvtn10_abs_trans',
#  'analysis/fvtn10_abs_trans_var',
#  'analysis/hratn5_abs_sus',
#  'analysis/hratn5_abs_sus_var',
#  'analysis/hratn5_abs_trans',
#  'analysis/hratn5_abs_trans_var',
#  'analysis/hratn5_abs_fin',
#  'analysis/hratn5_abs_pert',
#  'analysis/hratn6_abs_sus',
#  'analysis/hratn6_abs_sus_var',
#  'analysis/hratn6_abs_trans',
#  'analysis/hratn6_abs_trans_var',
#  'analysis/hratn6_abs_fin',
#  'analysis/hratn6_abs_pert',
#  'analysis/hratn7_abs_sus',
#  'analysis/hratn7_abs_sus_var',
#  'analysis/hratn7_abs_trans',
#  'analysis/hratn7_abs_trans_var',
#  'analysis/hratn7_abs_fin',
#  'analysis/hratn7_abs_pert',
#  'analysis/hratn8_abs_sus',
#  'analysis/hratn8_abs_sus_var',
#  'analysis/hratn8_abs_trans',
#  'analysis/hratn8_abs_trans_var',
#  'analysis/hratn8_abs_fin',
#  'analysis/hratn8_abs_pert',
#  'analysis/hratn9_abs_sus',
#  'analysis/hratn9_abs_sus_var',
#  'analysis/hratn9_abs_trans',
#  'analysis/hratn9_abs_trans_var',
#  'analysis/hratn9_abs_fin',
#  'analysis/hratn9_abs_pert',
#  'analysis/hratn10_abs_sus',
#  'analysis/hratn10_abs_sus_var',
#  'analysis/hratn10_abs_trans',
#  'analysis/hratn10_abs_trans_var',
#  'analysis/hratn10_abs_fin',
#  'analysis/hratn10_abs_pert',
#  'analysis/bn5_rate',
#  'analysis/bn5_jump',
#  'analysis/bn5_t_before_jump',
#  'analysis/bn6_rate',
#  'analysis/bn6_jump',
#  'analysis/bn6_t_before_jump',
#  'analysis/bn7_rate',
#  'analysis/bn7_jump',
#  'analysis/bn7_t_before_jump',
#  'analysis/bn8_rate',
#  'analysis/bn8_jump',
#  'analysis/bn8_t_before_jump',
#  'analysis/bn9_rate',
#  'analysis/bn9_jump',
#  'analysis/bn9_t_before_jump',
#  'analysis/bn10_rate',
#  'analysis/bn10_jump',
#  'analysis/bn10_t_before_jump',
#  'analysis/vtn5_rate',
#  'analysis/vtn5_jump',
#  'analysis/vtn5_t_before_jump',
#  'analysis/vtn6_rate',
#  'analysis/vtn6_jump',
#  'analysis/vtn6_t_before_jump',
#  'analysis/vtn7_rate',
#  'analysis/vtn7_jump',
#  'analysis/vtn7_t_before_jump',
#  'analysis/vtn8_rate',
#  'analysis/vtn8_jump',
#  'analysis/vtn8_t_before_jump',
#  'analysis/vtn9_rate',
#  'analysis/vtn9_jump',
#  'analysis/vtn9_t_before_jump',
#  'analysis/vtn10_rate',
#  'analysis/vtn10_jump',
#  'analysis/vtn10_t_before_jump',
#  'analysis/bn5_trans_rate_pct25',
#  'analysis/bn5_trans_rate_pct50',
#  'analysis/bn5_trans_rate_pct75',
#  'analysis/vtn5_trans_rate_pct25',
#  'analysis/vtn5_trans_rate_pct50',
#  'analysis/vtn5_trans_rate_pct75',
#  'analysis/bn6_trans_rate_pct25',
#  'analysis/bn6_trans_rate_pct50',
#  'analysis/bn6_trans_rate_pct75',
#  'analysis/vtn6_trans_rate_pct25',
#  'analysis/vtn6_trans_rate_pct50',
#  'analysis/vtn6_trans_rate_pct75',
#  'analysis/f_11',
#  'analysis/b11_t_min',
#  'analysis/b11_t_max',
#  'analysis/b11_abs_min',
#  'analysis/b11_abs_max',
#  'analysis/b11_abs_fin',
#  'analysis/b11_abs_pert',
#  'analysis/vt11_t_min',
#  'analysis/vt11_t_max',
#  'analysis/vt11_abs_min',
#  'analysis/vt11_abs_max',
#  'analysis/vt11_abs_fin',
#  'analysis/vt11_abs_pert',
#  'analysis/b11_abs_sus',
#  'analysis/b11_abs_sus_var',
#  'analysis/b11_abs_trans',
#  'analysis/b11_abs_trans_var',
#  'analysis/b11_trans_rate_pct25',
#  'analysis/b11_trans_rate_pct50',
#  'analysis/b11_trans_rate_pct75',
#  'analysis/vt11_abs_sus',
#  'analysis/vt11_abs_sus_var',
#  'analysis/vt11_abs_trans',
#  'analysis/vt11_abs_trans_var',
#  'analysis/vt11_trans_rate_pct25',
#  'analysis/vt11_trans_rate_pct50',
#  'analysis/vt11_trans_rate_pct75',
#  'analysis/fb11_abs_sus',
#  'analysis/fb11_abs_sus_var',
#  'analysis/fb11_abs_trans',
#  'analysis/fb11_abs_trans_var',
#  'analysis/fvt11_abs_sus',
#  'analysis/fvt11_abs_sus_var',
#  'analysis/fvt11_abs_trans',
#  'analysis/fvt11_abs_trans_var',
#  'analysis/hrat11_abs_sus',
#  'analysis/hrat11_abs_sus_var',
#  'analysis/hrat11_abs_trans',
#  'analysis/hrat11_abs_trans_var',
#  'analysis/hrat11_abs_fin',
#  'analysis/hrat11_abs_pert',
#  'analysis/b11_rate',
#  'analysis/b11_jump',
#  'analysis/b11_t_before_jump',
#  'analysis/vt11_rate',
#  'analysis/vt11_jump',
#  'analysis/vt11_t_before_jump',
#  'analysis/f_10',
#  'analysis/b10_t_min',
#  'analysis/b10_t_max',
#  'analysis/b10_abs_min',
#  'analysis/b10_abs_max',
#  'analysis/b10_abs_fin',
#  'analysis/b10_abs_pert',
#  'analysis/vt10_t_min',
#  'analysis/vt10_t_max',
#  'analysis/vt10_abs_min',
#  'analysis/vt10_abs_max',
#  'analysis/vt10_abs_fin',
#  'analysis/vt10_abs_pert',
#  'analysis/b10_abs_sus',
#  'analysis/b10_abs_sus_var',
#  'analysis/b10_abs_trans',
#  'analysis/b10_abs_trans_var',
#  'analysis/b10_trans_rate_pct25',
#  'analysis/b10_trans_rate_pct50',
#  'analysis/b10_trans_rate_pct75',
#  'analysis/vt10_abs_sus',
#  'analysis/vt10_abs_sus_var',
#  'analysis/vt10_abs_trans',
#  'analysis/vt10_abs_trans_var',
#  'analysis/vt10_trans_rate_pct25',
#  'analysis/vt10_trans_rate_pct50',
#  'analysis/vt10_trans_rate_pct75',
#  'analysis/fb10_abs_sus',
#  'analysis/fb10_abs_sus_var',
#  'analysis/fb10_abs_trans',
#  'analysis/fb10_abs_trans_var',
#  'analysis/fvt10_abs_sus',
#  'analysis/fvt10_abs_sus_var',
#  'analysis/fvt10_abs_trans',
#  'analysis/fvt10_abs_trans_var',
#  'analysis/hrat10_abs_sus',
#  'analysis/hrat10_abs_sus_var',
#  'analysis/hrat10_abs_trans',
#  'analysis/hrat10_abs_trans_var',
#  'analysis/hrat10_abs_fin',
#  'analysis/hrat10_abs_pert',
#  'analysis/b10_rate',
#  'analysis/b10_jump',
#  'analysis/b10_t_before_jump',
#  'analysis/vt10_rate',
#  'analysis/vt10_jump',
#  'analysis/vt10_t_before_jump',
#  'analysis/f_9',
#  'analysis/b9_t_min',
#  'analysis/b9_t_max',
#  'analysis/b9_abs_min',
#  'analysis/b9_abs_max',
#  'analysis/b9_abs_fin',
#  'analysis/b9_abs_pert',
#  'analysis/vt9_t_min',
#  'analysis/vt9_t_max',
#  'analysis/vt9_abs_min',
#  'analysis/vt9_abs_max',
#  'analysis/vt9_abs_fin',
#  'analysis/vt9_abs_pert',
#  'analysis/b9_abs_sus',
#  'analysis/b9_abs_sus_var',
#  'analysis/b9_abs_trans',
#  'analysis/b9_abs_trans_var',
#  ...]
